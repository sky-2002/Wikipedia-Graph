# %%
start_links = ['https://en.wikipedia.org/wiki/Antiderivative',
'https://en.wikipedia.org/wiki/Hyperbola',
'https://en.wikipedia.org/wiki/Area_under_the_curve_(pharmacokinetics)',
'https://en.wikipedia.org/wiki/Vector_(mathematics_and_physics)',
'https://en.wikipedia.org/wiki/Parabola',
'https://en.wikipedia.org/wiki/Logarithm',
'https://en.wikipedia.org/wiki/Harmonic_progression',
'https://en.wikipedia.org/wiki/De_Morgan%27s_laws',
'https://en.wikipedia.org/wiki/Even_and_odd_functions',
'https://en.wikipedia.org/wiki/Floor_and_ceiling_functions',
'https://en.wikipedia.org/wiki/Transpose',
'https://en.wikipedia.org/wiki/Chord_(geometry)',
'https://en.wikipedia.org/wiki/Inverse_trigonometric_functions',
'https://en.wikipedia.org/wiki/Parametric_equation',
'https://en.wikipedia.org/wiki/Director_circle',
'https://en.wikipedia.org/wiki/Coplanarity',
'https://en.wikipedia.org/wiki/Centroid',
'https://en.wikipedia.org/wiki/Altitude_(triangle)',
'https://en.wikipedia.org/wiki/Function_composition',
'https://en.wikipedia.org/wiki/Periodic_function',
'https://en.wikipedia.org/wiki/Dihedral_angle',
'https://en.wikipedia.org/wiki/Diophantine_geometry',
'https://en.wikipedia.org/wiki/Sampling_(statistics)#Simple_random_sampling',
'https://en.wikipedia.org/wiki/Minimax',
'https://en.wikipedia.org/wiki/Quantile_function',
'https://en.wikipedia.org/wiki/Karl_Weierstrass',
'https://en.wikipedia.org/wiki/Augustin-Louis_Cauchy']

start_labels = [3,3,3,1,2,1,1,1,1,1,2,1,3,2,2,2,1,3,3,2,3,0,0,0,0,0,0]
# 1 is beginner, 2 is intermediate, 3 is advanced

# %%
from bs4 import BeautifulSoup
import requests
import re
from urllib.request import urlopen

# %%
class Node:
  def __init__(self,link,text,label=None):
    self.id = None
    self.link = link # to store the link 
    self.label = label # to store the label
    self.text = text # to store the text
    self.neighbours = [] # to store the neighbours
    # to store the labels that come to this node in propagation step
    # and then assign to it the most frequent one
    self.label_options = [] 
    self.embedding = None # we will assign this later

    self.name = link.split('/')[-1] # can be useful if we are displaying the nodes
    # neighbours is a list of nodes

unique_links = {} # to store all unique links and their nodes

# %%
# !pip install wikipedia
# Out:
# Collecting wikipedia
#   Downloading wikipedia-1.4.0.tar.gz (27 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from wikipedia) (4.6.3)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from wikipedia) (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.10)
# Building wheels for collected packages: wikipedia
#   Building wheel for wikipedia (setup.py) ... done
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11695 sha256=9e8877ab59d3f0b404a770d34b136bbf420aba8030bce944e345800cdaee9142
#   Stored in directory: /root/.cache/pip/wheels/15/93/6d/5b2c68b8a64c7a7a04947b4ed6d89fb557dcc6bc27d1d7f3ba
# Successfully built wikipedia
# Installing collected packages: wikipedia
# Successfully installed wikipedia-1.4.0

# %%
import re
# some cleaning of the text data so as to get good embeddings
CLEANR = re.compile('<.*?>') 
CLEANB = re.compile('{.*?}')
CLEANN = re.compile('\n')
def cleanhtml(raw_html):
  cleantext = re.sub(CLEANR, '', raw_html)
  cleantext = re.sub(CLEANB,'',cleantext)
  cleantext = re.sub(CLEANN,'',cleantext)
  cleantext = re.sub('}',' ',cleantext)
  return cleantext

# %%
r = requests.get(start_links[0])
soup = BeautifulSoup(r.content)
para = soup.find_all('p')
#cleanhtml(str(para[5]))
#str(para[1])

# %%
cleanhtml((" ").join([str(p) for p in soup.find_all('p')]))
# Out:
# 'In calculus, an antiderivative, inverse derivative, primitive function, primitive integral or indefinite integral[Note 1] of a function f is a differentiable function F whose derivative is equal to the original function f. This can be stated symbolically as F\'  = f.[1][2] The process of solving for antiderivatives is called antidifferentiation (or indefinite integration), and its opposite operation is called differentiation, which is the process of finding a derivative. Antiderivatives are often denoted by capital Roman letters such as F and G. Antiderivatives are related to definite integrals through the second fundamental theorem of calculus: the definite integral of a function over a closed interval where the function is Riemann integrable is equal to the difference between the values of an antiderivative evaluated at the endpoints of the interval. In physics, antiderivatives arise in the context of rectilinear motion (e.g., in explaining the relationship between position, velocity and acceleration).[3] The discrete equivalent of the notion of antiderivative is antidifference. The function F(x)=x33    is an antiderivative of f(x)=x2 , since the derivative of x33    is x2 , and since the derivative of a constant is zero, x2  will have an infinite number of antiderivatives, such as x33,x33+1,x33−2  ,  +1,  -2 , etc. Thus, all the antiderivatives of x2  can be obtained by changing the value of c in F(x)=x33+c  +c , where c is an arbitrary constant known as the constant of integration. Essentially, the graphs of antiderivatives of a given function are vertical translations of each other, with each graph\'s vertical location depending upon the value c. More generally, the power function f(x)=xn  has antiderivative F(x)=xn+1n+1+c  +c  if n ≠ −1, and F(x)=ln\u2061|x|+c if n = −1. In physics, the integration of acceleration yields velocity plus a constant. The constant is the initial velocity term that would be lost upon taking the derivative of velocity, because the derivative of a constant term is zero. This same pattern applies to further integrations and derivatives of motion (position, velocity, acceleration, and so on).[3] Antiderivatives can be used to compute definite integrals, using the fundamental theorem of calculus: if F is an antiderivative of the integrable function f over the interval [a,b], then: Because of this, each of the infinitely many antiderivatives of a given function f may be called the "indefinite integral" of f and written using the integral symbol with no bounds: If F is an antiderivative of f, and the function f is defined on some interval, then every other antiderivative G of f differs from F by a constant: there exists a number c such that G(x)=F(x)+c for all x. c is called the constant of integration. If the domain of F is a disjoint union of two or more (open) intervals, then a different constant of integration may be chosen for each of the intervals. For instance is the most general antiderivative of f(x)=1/x2  on its natural domain (−∞,0)∪(0,∞). Every continuous function f has an antiderivative, and one antiderivative F is given by the definite integral of f with variable upper boundary: Varying the lower boundary produces other antiderivatives (but not necessarily all possible antiderivatives). This is another formulation of the fundamental theorem of calculus. There are many functions whose antiderivatives, even though they exist, cannot be expressed in terms of elementary functions (like polynomials, exponential functions, logarithms, trigonometric functions, inverse trigonometric functions and their combinations). Examples of these are From left to right, the functions are the error function, the Fresnel function, the sine integral, the logarithmic integral function and Sophomore\'s dream. For a more detailed discussion, see also Differential Galois theory. Finding antiderivatives of elementary functions is often considerably harder than finding their derivatives (indeed, there is no pre-de ...

# %%
para[5]
# Out:
# <p>In <a href="/wiki/Physics" title="Physics">physics</a>, the integration of <a href="/wiki/Acceleration" title="Acceleration">acceleration</a> yields <a href="/wiki/Velocity" title="Velocity">velocity</a> plus a constant. The constant is the initial velocity term that would be lost upon taking the derivative of velocity, because the derivative of a constant term is zero. This same pattern applies to further integrations and derivatives of motion (position, velocity, acceleration, and so on).<sup class="reference" id="cite_ref-:1_4-1"><a href="#cite_note-:1-4">[3]</a></sup>
# </p>

# %%
# helper function
# def wiki_to_text(link):
#     source = urlopen(link)
#     soup = BeautifulSoup(source,'lxml')
#     paras = []
#     for paragraph in soup.find_all('p'):
#       paras.append(str(paragraph.text))

#     heads = []
#     for head in soup.find_all('span', attrs = {'mw-headline'}):
#       heads.append(str(head.text))

#     text = [val for pair in zip(paras, heads) for val in pair]
#     text = ' '.join(text)
#     text = re.sub(r"\[.*?\]+", '', text)
#     text = text.replace('\n','')
#     return text

# %%
# creating and storing initial nodes
start_soups = [BeautifulSoup(requests.get(lnk).content) for lnk in start_links]
start_nodes = [Node(lnk,cleanhtml((" ").join([str(p) for p in soup.find_all('p')])),lbl) for lnk,soup,lbl in zip(start_links,start_soups,start_labels)]
for n in start_nodes:
  unique_links[n.link] = n

# helper function
def getLinks(link):
  # returns a list of all links present on the page of the passed link
  r = requests.get(link)
  soup = BeautifulSoup(r.content, 'html5lib')
  return ['https://en.wikipedia.org/'+i['href'] for i in soup.find_all('a',href=True) if i['href'].startswith("/wiki")]

# %%
import random
bfs_queue = [] # Queue to carry out bfs

# add the initial nodes to the queue
for s in start_nodes:
  bfs_queue.append(s) 

# testing on 1000 counts first -----------------> 10 minutes time, 76,162 nodes collected
# testing on 1500 counts first -----------------> 13 minutes time, 1,26,584 nodes collected
count = 3 # took 5 minutes for 5 count, this wiki_to_text takes time 🙄, I could just collect 874 nodes
for node in random.sample(bfs_queue,5):

  count-=1 # testing
  if count==0:break # testing
  #if len(bfs_queue)==100000:break

  links = getLinks(node.link)
  neighbours = [] # store neighbours of the node
  for lnk in links:
    if lnk in unique_links:
      # Do nothing if link already explored
      #print("Already present")
      pass
    else:
      r = requests.get(lnk)
      soup = BeautifulSoup(r.content)
      new = Node(lnk,cleanhtml((" ").join([str(p) for p in soup.find_all('p')])))
      bfs_queue.append(new) # add this node to queue
      unique_links[lnk] = new # also add to unique_links dictionary
    # here I am ensuring that no link is repeated but neighbours can be repeated
      
  for lk in links:
    neighbours.append(unique_links[lk])
  node.neighbours = neighbours

# %%
for e,n in enumerate(bfs_queue):
  n.id = e+1

# %%
# helper function
def stat():
  global bfs_queue,unique_links
  print("Length of bfs_queue:",len(bfs_queue))
  print("Length of unique_links:",len(unique_links))

# %%
stat()
# Out:
# Length of bfs_queue: 437
# Length of unique_links: 437

# %%
# Using library to get embeddings of document as my own implementation is taking too much time
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

documents = [TaggedDocument(doc.text.split(), [i]) for i, doc in enumerate(bfs_queue)]
model = Doc2Vec(documents, vector_size=300, window=2, min_count=1, workers=4)

# %%
#model.wv.most_similar(['integration','of','function'])
# Out:
# [('has', 0.9994925260543823),
#  ('or', 0.9994825720787048),
#  ('that', 0.9994738101959229),
#  ('a', 0.9994684457778931),
#  ('the', 0.9994664192199707),
#  ('and', 0.9994654655456543),
#  ('In', 0.9994615316390991),
#  ('for', 0.99946129322052),
#  ('in', 0.9994605779647827),
#  ('to', 0.9994600415229797)]

# %%
import numpy as np
# def mostSimilarSentence(given_sentence):
#   myvec = model.infer_vector(given_sentence.split())
#   #print(myvec)
#   mind = -np.Inf
#   mins = None
#   for d in documents:
#     vec = model.infer_vector(d[0])
#     dot = np.dot(vec,myvec)
#     if dot>mind:
#       mind = dot
#       mins = (" ").join(d[0])
#   return mind,mins

# %%
#documents[0][0] , is a list

# %%
for node in bfs_queue:
  node.embedding = model.infer_vector(node.text.split())
# took 12 seconds for 874 nodes
# 1 second for 27 nodes

# %%
import pandas as pd
pages = pd.read_csv("/content/drive/MyDrive/Semester4/DS250/Wikipedia/pages.csv")
df = pages.copy()
for n in bfs_queue:
  if n.label == None:
    n.label = df.loc[df['Link']==n.link]['Label'].values[0]

# %%
import numpy as np
check = bfs_queue[0]
print(check.link,check.label)
m = 0
j = None
for n in bfs_queue:
  if n!=check:
    if np.dot(n.embedding,check.embedding)>m:
      m = np.dot(n.embedding,check.embedding)
      j = n
print(j.link,j.label,m)

# here we have found the most similar page to Antiderivative in this subgraph

# using this embedding and the cosine similarity we can classify the unlabeled nodes
# Out:
# https://en.wikipedia.org/wiki/Antiderivative 3
# https://en.wikipedia.org//wiki/Linearity_of_integration None 62.79174

# %%
# Generating query for Neo4j visualization

st = "CREATE "

for h in bfs_queue:
  st+="(n"+str(h.id)+":NODE{link:'"+h.link+"'"+", label:'"+str(h.label)+"'}"+"),"+"\n"
st = st.rstrip(",")
st+="\n"
#print(st)
rel = 0
for n in bfs_queue:
  for nn in n.neighbours:
    rel+=1
    st+="(n"+str(nn.id)+")"+"-[r"+str(rel)+":NEIGHBOR_OF]->"+"(n"+str(n.id)+"),"+"\n"
st = st.rstrip(",")
st+=";"
print(st)
# Out:
# CREATE (n1:NODE{link:'https://en.wikipedia.org/wiki/Antiderivative', label:'3'}),
# (n2:NODE{link:'https://en.wikipedia.org/wiki/Hyperbola', label:'3'}),
# (n3:NODE{link:'https://en.wikipedia.org/wiki/Area_under_the_curve_(pharmacokinetics)', label:'3'}),
# (n4:NODE{link:'https://en.wikipedia.org/wiki/Vector_(mathematics_and_physics)', label:'1'}),
# (n5:NODE{link:'https://en.wikipedia.org/wiki/Parabola', label:'2'}),
# (n6:NODE{link:'https://en.wikipedia.org/wiki/Logarithm', label:'1'}),
# (n7:NODE{link:'https://en.wikipedia.org/wiki/Harmonic_progression', label:'1'}),
# (n8:NODE{link:'https://en.wikipedia.org/wiki/De_Morgan%27s_laws', label:'1'}),
# (n9:NODE{link:'https://en.wikipedia.org/wiki/Even_and_odd_functions', label:'1'}),
# (n10:NODE{link:'https://en.wikipedia.org/wiki/Floor_and_ceiling_functions', label:'1'}),
# (n11:NODE{link:'https://en.wikipedia.org/wiki/Transpose', label:'2'}),
# (n12:NODE{link:'https://en.wikipedia.org/wiki/Chord_(geometry)', label:'1'}),
# (n13:NODE{link:'https://en.wikipedia.org/wiki/Inverse_trigonometric_functions', label:'3'}),
# (n14:NODE{link:'https://en.wikipedia.org/wiki/Parametric_equation', label:'2'}),
# (n15:NODE{link:'https://en.wikipedia.org/wiki/Director_circle', label:'2'}),
# (n16:NODE{link:'https://en.wikipedia.org/wiki/Coplanarity', label:'2'}),
# (n17:NODE{link:'https://en.wikipedia.org/wiki/Centroid', label:'1'}),
# (n18:NODE{link:'https://en.wikipedia.org/wiki/Altitude_(triangle)', label:'3'}),
# (n19:NODE{link:'https://en.wikipedia.org/wiki/Function_composition', label:'3'}),
# (n20:NODE{link:'https://en.wikipedia.org/wiki/Periodic_function', label:'2'}),
# (n21:NODE{link:'https://en.wikipedia.org/wiki/Dihedral_angle', label:'3'}),
# (n22:NODE{link:'https://en.wikipedia.org/wiki/Diophantine_geometry', label:'0'}),
# (n23:NODE{link:'https://en.wikipedia.org/wiki/Sampling_(statistics)#Simple_random_sampling', label:'0'}),
# (n24:NODE{link:'https://en.wikipedia.org/wiki/Minimax', label:'0'}),
# (n25:NODE{link:'https://en.wikipedia.org/wiki/Quantile_function', label:'0'}),
# (n26:NODE{link:'https://en.wikipedia.org/wiki/Karl_Weierstrass', label:'0'}),
# (n27:NODE{link:'https://en.wikipedia.org/wiki/Augustin-Louis_Cauchy', label:'0'}),
# (n28:NODE{link:'https://en.wikipedia.org//wiki/Vector_(disambiguation)', label:'1'}),
# (n29:NODE{link:'https://en.wikipedia.org//wiki/Wikipedia:Manual_of_Style/Lead_section', label:'1'}),
# (n30:NODE{link:'https://en.wikipedia.org//wiki/Help:Maintenance_template_removal', label:'1'}),
# (n31:NODE{link:'https://en.wikipedia.org//wiki/Mathematics', label:'1'}),
# (n32:NODE{link:'https://en.wikipedia.org//wiki/Physics', label:'1'}),
# (n33:NODE{link:'https://en.wikipedia.org//wiki/Vector_space', label:'1'}),
# (n34:NODE{link:'https://en.wikipedia.org//wiki/Euclidean_vector', label:'1'}),
# (n35:NODE{link:'https://en.wikipedia.org//wiki/Ray_(geometry)', label:'1'}),
# (n36:NODE{link:'https://en.wikipedia.org//wiki/Vector_algebra', label:'1'}),
# (n37:NODE{link:'https://en.wikipedia.org//wiki/Linear_algebra', label:'2'}),
# (n38:NODE{link:'https://en.wikipedia.org//wiki/Dimension', label:'1'}),
# (n39:NODE{link:'https://en.wikipedia.org//wiki/Geometry', label:'1'}),
# (n40:NODE{link:'https://en.wikipedia.org//wiki/Mechanics', label:'1'}),
# (n41:NODE{link:'https://en.wikipedia.org//wiki/Latin', label:'1'}),
# (n42:NODE{link:'https://en.wikipedia.org//wiki/Euclidean_space', label:'1'}),
# (n43:NODE{link:'https://en.wikipedia.org//wiki/Spatial_vector', label:'1'}),
# (n44:NODE{link:'https://en.wikipedia.org//wiki/Vector_addition', label:'1'}),
# (n45:NODE{link:'https://en.wikipedia.org//wiki/Scalar_multiplication', label:'1'}),
# (n46:NODE{link:'https://en.wikipedia.org//wiki/Real_number', label:'1'}),
# (n47:NODE{link:'https://en.wikipedia.org//wiki/File:Vector_from_A_to_B.svg', label:'1'}),
# (n48:NODE{link:'https://en.wikipedia.org//wiki/Engineering', label:'1'}),
# (n49:NODE{link:'https://en.wikipedia.org//wiki/Magnitude_(mathematics)', label:'1'}),
# (n50:NODE{link:'https://en.wikipedia.org//wiki/Euclidean_norm', label:'1'}),
# (n51:NODE{link:'https://en.wikipedia.org//wiki/Direction_(geometry)', label:'1'}),
# (n52:NODE{link:'https://en.wikipedia.org//wiki/Directed_line_segment', label:'1'}),
# (n53:NODE{link:'https://en.wikipedia.org//wiki/Displacement_(geometry)', label:'1'}),
# (n54:NODE{link:'https://en.wikipedia.org//wiki/Algebraic_operation', label:'1'}),
# (n55:NODE{link:'https://en.wikipedia.org//wiki/Addition', label:'1'}),
# (n56:NODE{link:'https://en.wikipedia.org//wiki/Subtraction', label:'1'}),
# (n57:NODE{link:'https://en.wikipedia.org//wiki/Multiplication', label:'1'}),
# (n58:NODE{link:'https://en.wikipedia.org//wiki/Additive_inverse', label:'1'}),
# (n59:NODE{link:'https://en.wikipedia.org//wiki/Commutativity', label:'1'}),
# (n60:NODE{link:'https://en.wikipedia.org//wiki/Associativity', label:'1'}),
# (n61:NODE{link:'https://en.wikipedia.org//wiki/Distributivity', label:'1'}),
# (n62:NODE{link:'https://en.wikipedia.org//wiki/Velocity', label:'3'}),
# (n63:NODE{link:'https://en.wikipedia.org//wiki/Acceleration', label:'3'}),
# (n64:NODE{link:'https://en.wikipedia.org//wiki/Force', label:'1'}),
# (n65:NODE{link:'https://en.wikipedia.org//wiki/Position_(vector)', label:'1'}),
# (n66:NODE{link:'https://en.wikipedia.org//wiki/Displacement_(vector)', label:'1'}),
# (n67:NODE{link:'https://en.wikipedia.org//wiki/Coordinate_system', label:'1'}),
# (n68:NODE{link:'https://en.wikipedia.org//wiki/Pseudovector', label:'1'}),
# (n69:NODE{link:'https://en.wikipedia.org//wiki/Tensor', label:'1'}),
# (n70:NODE{link:'https://en.wikipedia.org//wiki/File:Vector_add_scale.svg', label:'1'}),
# (n71:NODE{link:'https://en.wikipedia.org//wiki/Set_(mathematics)', label:'1'}),
# (n72:NODE{link:'https://en.wikipedia.org//wiki/Scalar_(mathematics)', label:'2'}),
# (n73:NODE{link:'https://en.wikipedia.org//wiki/Complex_number', label:'1'}),
# (n74:NODE{link:'https://en.wikipedia.org//wiki/Field_(mathematics)', label:'1'}),
# (n75:NODE{link:'https://en.wikipedia.org//wiki/Axiom', label:'1'}),
# (n76:NODE{link:'https://en.wikipedia.org//wiki/Force_vector', label:'1'}),
# (n77:NODE{link:'https://en.wikipedia.org//wiki/Three-dimensional_space', label:'1'}),
# (n78:NODE{link:'https://en.wikipedia.org//wiki/Mathematical_object', label:'3'}),
# (n79:NODE{link:'https://en.wikipedia.org//wiki/Dimension_(vector_space)', label:'1'}),
# (n80:NODE{link:'https://en.wikipedia.org//wiki/Mathematical_analysis', label:'0'}),
# (n81:NODE{link:'https://en.wikipedia.org//wiki/Function_space', label:'1'}),
# (n82:NODE{link:'https://en.wikipedia.org//wiki/Function_(mathematics)', label:'1'}),
# (n83:NODE{link:'https://en.wikipedia.org//wiki/Topology', label:'1'}),
# (n84:NODE{link:'https://en.wikipedia.org//wiki/Continuous_function', label:'3'}),
# (n85:NODE{link:'https://en.wikipedia.org//wiki/Norm_(mathematics)', label:'1'}),
# (n86:NODE{link:'https://en.wikipedia.org//wiki/Inner_product', label:'1'}),
# (n87:NODE{link:'https://en.wikipedia.org//wiki/Metric_(mathematics)', label:'1'}),
# (n88:NODE{link:'https://en.wikipedia.org//wiki/Banach_space', label:'1'}),
# (n89:NODE{link:'https://en.wikipedia.org//wiki/Hilbert_space', label:'1'}),
# (n90:NODE{link:'https://en.wikipedia.org//wiki/Analytic_geometry', label:'0'}),
# (n91:NODE{link:'https://en.wikipedia.org//wiki/Matrix_(mathematics)', label:'2'}),
# (n92:NODE{link:'https://en.wikipedia.org//wiki/Linear_equation', label:'1'}),
# (n93:NODE{link:'https://en.wikipedia.org//wiki/Giuseppe_Peano', label:'1'}),
# (n94:NODE{link:'https://en.wikipedia.org//wiki/Line_(geometry)', label:'2'}),
# (n95:NODE{link:'https://en.wikipedia.org//wiki/Plane_(geometry)', label:'3'}),
# (n96:NODE{link:'https://en.wikipedia.org//wiki/Science', label:'1'}),
# (n97:NODE{link:'https://en.wikipedia.org//wiki/System_of_linear_equations', label:'1'}),
# (n98:NODE{link:'https://en.wikipedia.org//wiki/Fourier_series', label:'1'}),
# (n99:NODE{link:'https://en.wikipedia.org//wiki/Image_compression', label:'1'}),
# (n100:NODE{link:'https://en.wikipedia.org//wiki/Partial_differential_equation', label:'1'}),
# (n101:NODE{link:'https://en.wikipedia.org//wiki/Coordinate-free', label:'1'}),
# (n102:NODE{link:'https://en.wikipedia.org//wiki/Manifold_(mathematics)', label:'1'}),
# (n103:NODE{link:'https://en.wikipedia.org//wiki/Abstract_algebra', label:'0'}),
# (n104:NODE{link:'https://en.wikipedia.org//wiki/Wikipedia:Merging', label:'1'}),
# (n105:NODE{link:'https://en.wikipedia.org//wiki/Talk:Vector_space#Merge_list_of_related_vector_concepts', label:'1'}),
# (n106:NODE{link:'https://en.wikipedia.org//wiki/Zero_vector', label:'1'}),
# (n107:NODE{link:'https://en.wikipedia.org//wiki/Additive_identity', label:'1'}),
# (n108:NODE{link:'https://en.wikipedia.org//wiki/Normed_vector_space', label:'1'}),
# (n109:NODE{link:'https://en.wikipedia.org//wiki/Euclidean_vector_space', label:'1'}),
# (n110:NODE{link:'https://en.wikipedia.org//wiki/Basis_vector', label:'1'}),
# (n111:NODE{link:'https://en.wikipedia.org//wiki/Basis_(linear_algebra)', label:'2'}),
# (n112:NODE{link:'https://en.wikipedia.org//wiki/Unit_vector', label:'1'}),
# (n113:NODE{link:'https://en.wikipedia.org//wiki/Isotropic_vector', label:'1'}),
# (n114:NODE{link:'https://en.wikipedia.org//wiki/Null_vector', label:'1'}),
# (n115:NODE{link:'https://en.wikipedia.org//wiki/Quadratic_form', label:'1'}),
# (n116:NODE{link:'https://en.wikipedia.org//wiki/Isotropic_quadratic_form', label:'1'}),
# (n117:NODE{link:'https://en.wikipedia.org//wiki/Row_and_column_vectors', label:'1'}),
# (n118:NODE{link:'https://en.wikipedia.org//wiki/Coordinate_vector', label:'1'}),
# (n119:NODE{link:'https://en.wikipedia.org//wiki/Tuple', label:'1'}),
# (n120:NODE{link:'https://en.wikipedia.org//wiki/Coordinates', label:'1'}),
# (n121:NODE{link:'https://en.wikipedia.org//wiki/Displacement_vector', label:'1'}),
# (n122:NODE{link:'https://en.wikipedia.org//wiki/Translation_(geometry)', label:'1'}),
# (n123:NODE{link:'https://en.wikipedia.org//wiki/Position_vector', label:'1'}),
# (n124:NODE{link:'https://en.wikipedia.org//wiki/Affine_space', label:'1'}),
# (n125:NODE{link:'https://en.wikipedia.org//wiki/Velocity_vector', label:'1'}),
# (n126:NODE{link:'https://en.wikipedia.org//wiki/Covector', label:'1'}),
# (n127:NODE{link:'https://en.wikipedia.org//wiki/Dual_space', label:'1'}),
# (n128:NODE{link:'https://en.wikipedia.org//wiki/Inner_product_space', label:'1'}),
# (n129:NODE{link:'https://en.wikipedia.org//wiki/Tangent_vector', label:'1'}),
# (n130:NODE{link:'https://en.wikipedia.org//wiki/Tangent_space', label:'1'}),
# (n131:NODE{link:'https://en.wikipedia.org//wiki/Curve', label:'2'}),
# (n132:NODE{link:'https://en.wikipedia.org//wiki/Surface_(mathematics)', label:'1'}),
# (n133:NODE{link:'https://en.wikipedia.org//wiki/Differential_manifold', label:'1'}),
# (n134:NODE{link:'https://en.wikipedia.org//wiki/Normal_vector', label:'1'}),
# (n135:NODE{link:'https://en.wikipedia.org//wiki/Gradient', label:'3'}),
# (n136:NODE{link:'https://en.wikipedia.org//wiki/Function_of_several_real_variables', label:'1'}),
# (n137:NODE{link:'https://en.wikipedia.org//wiki/Scalar_field', label:'1'}),
# (n138:NODE{link:'https://en.wikipedia.org//wiki/Level_curve', label:'1'}),
# (n139:NODE{link:'https://en.wikipedia.org//wiki/Four-vector', label:'1'}),
# (n140:NODE{link:'https://en.wikipedia.org//wiki/Theory_of_relativity', label:'3'}),
# (n141:NODE{link:'https://en.wikipedia.org//wiki/Minkowski_space', label:'1'}),
# (n142:NODE{link:'https://en.wikipedia.org//wiki/Algebra_over_a_field', label:'1'}),
# (n143:NODE{link:'https://en.wikipedia.org//wiki/Vector_quaternion', label:'1'}),
# (n144:NODE{link:'https://en.wikipedia.org//wiki/Quaternion', label:'1'}),
# (n145:NODE{link:'https://en.wikipedia.org//wiki/Multivector', label:'2'}),
# (n146:NODE{link:'https://en.wikipedia.org//wiki/P-vector', label:'1'}),
# (n147:NODE{link:'https://en.wikipedia.org//wiki/Exterior_algebra', label:'1'}),
# (n148:NODE{link:'https://en.wikipedia.org//wiki/Spinor', label:'1'}),
# (n149:NODE{link:'https://en.wikipedia.org//wiki/Rotation_vector', label:'1'}),
# (n150:NODE{link:'https://en.wikipedia.org//wiki/Closed_curve', label:'1'}),
# (n151:NODE{link:'https://en.wikipedia.org//wiki/Manifold', label:'1'}),
# (n152:NODE{link:'https://en.wikipedia.org//wiki/Orientable_manifold', label:'1'}),
# (n153:NODE{link:'https://en.wikipedia.org//wiki/Clifford_algebra', label:'1'}),
# (n154:NODE{link:'https://en.wikipedia.org//wiki/Witt_vector', label:'1'}),
# (n155:NODE{link:'https://en.wikipedia.org//wiki/Algebra_over_a_ring', label:'1'}),
# (n156:NODE{link:'https://en.wikipedia.org//wiki/Carry_(arithmetic)', label:'1'}),
# (n157:NODE{link:'https://en.wikipedia.org//wiki/P-adic_number', label:'1'}),
# (n158:NODE{link:'https://en.wikipedia.org//wiki/Wikipedia:Accuracy_dispute', label:'1'}),
# (n159:NODE{link:'https://en.wikipedia.org//wiki/Talk:Vector_(mathematics_and_physics)#Dispute', label:'1'}),
# (n160:NODE{link:'https://en.wikipedia.org//wiki/Wikipedia:Reliable_sources', label:'1'}),
# (n161:NODE{link:'https://en.wikipedia.org//wiki/Wikipedia:Disputed_statement', label:'1'}),
# (n162:NODE{link:'https://en.wikipedia.org//wiki/Talk:Vector_(mathematics_and_physics)#Tuples_that_aren’t_really_vectors?', label:'1'}),
# (n163:NODE{link:'https://en.wikipedia.org//wiki/Rotation_(geometry)', label:'1'}),
# (n164:NODE{link:'https://en.wikipedia.org//wiki/Burgers_vector', label:'1'}),
# (n165:NODE{link:'https://en.wikipedia.org//wiki/Interval_vector', label:'1'}),
# (n166:NODE{link:'https://en.wikipedia.org//wiki/Probability_vector', label:'1'}),
# (n167:NODE{link:'https://en.wikipedia.org//wiki/Random_vector', label:'1'}),
# (n168:NODE{link:'https://en.wikipedia.org//wiki/Multivariate_random_variable', label:'1'}),
# (n169:NODE{link:'https://en.wikipedia.org//wiki/Statistics', label:'0'}),
# (n170:NODE{link:'https://en.wikipedia.org//wiki/Random_variable', label:'1'}),
# (n171:NODE{link:'https://en.wikipedia.org//wiki/Correlated', label:'1'}),
# (n172:NODE{link:'https://en.wikipedia.org//wiki/Logical_matrix#Logical_vectors', label:'1'}),
# (n173:NODE{link:'https://en.wikipedia.org//wiki/Boolean_data_type', label:'1'}),
# (n174:NODE{link:'https://en.wikipedia.org//wiki/Graded_vector_space', label:'1'}),
# (n175:NODE{link:'https://en.wikipedia.org//wiki/Ordered_vector_space', label:'1'}),
# (n176:NODE{link:'https://en.wikipedia.org//wiki/Super_vector_space', label:'1'}),
# (n177:NODE{link:'https://en.wikipedia.org//wiki/Symplectic_vector_space', label:'1'}),
# (n178:NODE{link:'https://en.wikipedia.org//wiki/Topological_vector_space', label:'1'}),
# (n179:NODE{link:'https://en.wikipedia.org//wiki/Vector_field', label:'1'}),
# (n180:NODE{link:'https://en.wikipedia.org//wiki/Vector-valued_function', label:'1'}),
# (n181:NODE{link:'https://en.wikipedia.org//wiki/Conservative_vector_field', label:'1'}),
# (n182:NODE{link:'https://en.wikipedia.org//wiki/Hamiltonian_vector_field', label:'1'}),
# (n183:NODE{link:'https://en.wikipedia.org//wiki/Killing_vector_field', label:'1'}),
# (n184:NODE{link:'https://en.wikipedia.org//wiki/Solenoidal_vector_field', label:'1'}),
# (n185:NODE{link:'https://en.wikipedia.org//wiki/Vector_potential', label:'1'}),
# (n186:NODE{link:'https://en.wikipedia.org//wiki/Vector_flow', label:'1'}),
# (n187:NODE{link:'https://en.wikipedia.org//wiki/Ricci_calculus', label:'1'}),
# (n188:NODE{link:'https://en.wikipedia.org//wiki/Vector_Analysis_(Gibbs/Wilson)', label:'1'}),
# (n189:NODE{link:'https://en.wikipedia.org//wiki/Edwin_Bidwell_Wilson', label:'1'}),
# (n190:NODE{link:'https://en.wikipedia.org//wiki/Vector_bundle', label:'1'}),
# (n191:NODE{link:'https://en.wikipedia.org//wiki/Vector_calculus', label:'3'}),
# (n192:NODE{link:'https://en.wikipedia.org//wiki/Vector_differential', label:'1'}),
# (n193:NODE{link:'https://en.wikipedia.org//wiki/Vector_Laplacian', label:'1'}),
# (n194:NODE{link:'https://en.wikipedia.org//wiki/Vector_notation', label:'1'}),
# (n195:NODE{link:'https://en.wikipedia.org//wiki/Vector_operator', label:'1'}),
# (n196:NODE{link:'https://en.wikipedia.org//wiki/Vector_product', label:'1'}),
# (n197:NODE{link:'https://en.wikipedia.org//wiki/Vector_projection', label:'2'}),
# (n198:NODE{link:'https://en.wikipedia.org//wiki/Codomain', label:'1'}),
# (n199:NODE{link:'https://en.wikipedia.org//wiki/Vectorization_(mathematics)', label:'1'}),
# (n200:NODE{link:'https://en.wikipedia.org//wiki/Vector_autoregression', label:'1'}),
# (n201:NODE{link:'https://en.wikipedia.org//wiki/Vector_boson', label:'1'}),
# (n202:NODE{link:'https://en.wikipedia.org//wiki/Vector_measure', label:'1'}),
# (n203:NODE{link:'https://en.wikipedia.org//wiki/Vector_meson', label:'1'}),
# (n204:NODE{link:'https://en.wikipedia.org//wiki/Vector_quantization', label:'1'}),
# (n205:NODE{link:'https://en.wikipedia.org//wiki/Vector_soliton', label:'1'}),
# (n206:NODE{link:'https://en.wikipedia.org//wiki/Vector_synthesis', label:'1'}),
# (n207:NODE{link:'https://en.wikipedia.org//wiki/Category:Harv_and_Sfn_template_errors', label:'3'}),
# (n208:NODE{link:'https://en.wikipedia.org//wiki/Perfect_participle', label:'1'}),
# (n209:NODE{link:'https://en.wikipedia.org//wiki/Oxford_English_Dictionary', label:'1'}),
# (n210:NODE{link:'https://en.wikipedia.org//wiki/Oxford_University_Press', label:'1'}),
# (n211:NODE{link:'https://en.wikipedia.org//wiki/ISBN_(identifier)', label:'1'}),
# (n212:NODE{link:'https://en.wikipedia.org//wiki/Special:BookSources/9780195219425', label:'1'}),
# (n213:NODE{link:'https://en.wikipedia.org//wiki/Special:BookSources/1-55369-133-4', label:'1'}),
# (n214:NODE{link:'https://en.wikipedia.org//wiki/MIT_Press', label:'1'}),
# (n215:NODE{link:'https://en.wikipedia.org//wiki/Special:BookSources/978-0-262-59020-4', label:'1'}),
# (n216:NODE{link:'https://en.wikipedia.org//wiki/Encyclopedia_of_Mathematics', label:'1'}),
# (n217:NODE{link:'https://en.wikipedia.org//wiki/European_Mathematical_Society', label:'1'}),
# (n218:NODE{link:'https://en.wikipedia.org//wiki/Daniel_Pedoe', label:'1'}),
# (n219:NODE{link:'https://en.wikipedia.org//wiki/Special:BookSources/0-486-65812-0', label:'1'}),
# (n220:NODE{link:'https://en.wikipedia.org//wiki/Help:Category', label:'1'}),
# (n221:NODE{link:'https://en.wikipedia.org//wiki/Category:Vectors_(mathematics_and_physics)', label:'1'}),
# (n222:NODE{link:'https://en.wikipedia.org//wiki/Category:Harv_and_Sfn_no-target_errors', label:'3'}),
# (n223:NODE{link:'https://en.wikipedia.org//wiki/Category:Articles_with_short_description', label:'1'}),
# (n224:NODE{link:'https://en.wikipedia.org//wiki/Category:Short_description_matches_Wikidata', label:'1'}),
# (n225:NODE{link:'https://en.wikipedia.org//wiki/Category:Wikipedia_introduction_cleanup_from_November_2021', label:'1'}),
# (n226:NODE{link:'https://en.wikipedia.org//wiki/Category:All_pages_needing_cleanup', label:'1'}),
# (n227:NODE{link:'https://en.wikipedia.org//wiki/Category:Articles_covered_by_WikiProject_Wikify_from_November_2021', label:'1'}),
# (n228:NODE{link:'https://en.wikipedia.org//wiki/Category:All_articles_covered_by_WikiProject_Wikify', label:'1'}),
# (n229:NODE{link:'https://en.wikipedia.org//wiki/Category:Articles_with_excerpts', label:'1'}),
# (n230:NODE{link:'https://en.wikipedia.org//wiki/Category:Articles_to_be_merged_from_November_2021', label:'1'}),
# (n231:NODE{link:'https://en.wikipedia.org//wiki/Category:All_articles_to_be_merged', label:'1'}),
# (n232:NODE{link:'https://en.wikipedia.org//wiki/Category:Accuracy_disputes_from_November_2021', label:'1'}),
# (n233:NODE{link:'https://en.wikipedia.org//wiki/Category:All_accuracy_disputes', label:'1'}),
# (n234:NODE{link:'https://en.wikipedia.org//wiki/Category:Articles_with_disputed_statements_from_November_2021', label:'1'}),
# (n235:NODE{link:'https://en.wikipedia.org//wiki/Category:Broad-concept_articles', label:'1'}),
# (n236:NODE{link:'https://en.wikipedia.org//wiki/Special:MyTalk', label:'1'}),
# (n237:NODE{link:'https://en.wikipedia.org//wiki/Special:MyContributions', label:'1'}),
# (n238:NODE{link:'https://en.wikipedia.org//wiki/Vector_(mathematics_and_physics)', label:'1'}),
# (n239:NODE{link:'https://en.wikipedia.org//wiki/Talk:Vector_(mathematics_and_physics)', label:'1'}),
# (n240:NODE{link:'https://en.wikipedia.org//wiki/Main_Page', label:'1'}),
# (n241:NODE{link:'https://en.wikipedia.org//wiki/Wikipedia:Contents', label:'1'}),
# (n242:NODE{link:'https://en.wikipedia.org//wiki/Portal:Current_events', label:'1'}),
# (n243:NODE{link:'https://en.wikipedia.org//wiki/Special:Random', label:'1'}),
# (n244:NODE{link:'https://en.wikipedia.org//wiki/Wikipedia:About', label:'1'}),
# (n245:NODE{link:'https://en.wikipedia.org//wiki/Help:Contents', label:'1'}),
# (n246:NODE{link:'https://en.wikipedia.org//wiki/Help:Introduction', label:'1'}),
# (n247:NODE{link:'https://en.wikipedia.org//wiki/Wikipedia:Community_portal', label:'1'}),
# (n248:NODE{link:'https://en.wikipedia.org//wiki/Special:RecentChanges', label:'1'}),
# (n249:NODE{link:'https://en.wikipedia.org//wiki/Wikipedia:File_Upload_Wizard', label:'1'}),
# (n250:NODE{link:'https://en.wikipedia.org//wiki/Special:WhatLinksHere/Vector_(mathematics_and_physics)', label:'1'}),
# (n251:NODE{link:'https://en.wikipedia.org//wiki/Special:RecentChangesLinked/Vector_(mathematics_and_physics)', label:'1'}),
# (n252:NODE{link:'https://en.wikipedia.org//wiki/Special:SpecialPages', label:'1'}),
# (n253:NODE{link:'https://en.wikipedia.org//wiki/Wikipedia:General_disclaimer', label:'1'}),
# (n254:NODE{link:'https://en.wikipedia.org//wiki/Trigonometry', label:'3'}),
# (n255:NODE{link:'https://en.wikipedia.org//wiki/File:Sinus_und_Kosinus_am_Einheitskreis_1.svg', label:'3'}),
# (n256:NODE{link:'https://en.wikipedia.org//wiki/Outline_of_trigonometry', label:'3'}),
# (n257:NODE{link:'https://en.wikipedia.org//wiki/History_of_trigonometry', label:'3'}),
# (n258:NODE{link:'https://en.wikipedia.org//wiki/Uses_of_trigonometry', label:'3'}),
# (n259:NODE{link:'https://en.wikipedia.org//wiki/Trigonometric_functions', label:'3'}),
# (n260:NODE{link:'https://en.wikipedia.org//wiki/Generalized_trigonometry', label:'3'}),
# (n261:NODE{link:'https://en.wikipedia.org//wiki/List_of_trigonometric_identities', label:'3'}),
# (n262:NODE{link:'https://en.wikipedia.org//wiki/Exact_trigonometric_values', label:'3'}),
# (n263:NODE{link:'https://en.wikipedia.org//wiki/Trigonometric_tables', label:'3'}),
# (n264:NODE{link:'https://en.wikipedia.org//wiki/Unit_circle', label:'3'}),
# (n265:NODE{link:'https://en.wikipedia.org//wiki/Law_of_sines', label:'3'}),
# (n266:NODE{link:'https://en.wikipedia.org//wiki/Law_of_cosines', label:'3'}),
# (n267:NODE{link:'https://en.wikipedia.org//wiki/Law_of_tangents', label:'3'}),
# (n268:NODE{link:'https://en.wikipedia.org//wiki/Law_of_cotangents', label:'3'}),
# (n269:NODE{link:'https://en.wikipedia.org//wiki/Pythagorean_theorem', label:'3'}),
# (n270:NODE{link:'https://en.wikipedia.org//wiki/Calculus', label:'3'}),
# (n271:NODE{link:'https://en.wikipedia.org//wiki/Trigonometric_substitution', label:'3'}),
# (n272:NODE{link:'https://en.wikipedia.org//wiki/List_of_integrals_of_trigonometric_functions', label:'3'}),
# (n273:NODE{link:'https://en.wikipedia.org//wiki/List_of_integrals_of_inverse_trigonometric_functions', label:'3'}),
# (n274:NODE{link:'https://en.wikipedia.org//wiki/Differentiation_of_trigonometric_functions', label:'3'}),
# (n275:NODE{link:'https://en.wikipedia.org//wiki/Template:Trigonometry', label:'3'}),
# (n276:NODE{link:'https://en.wikipedia.org//wiki/Template_talk:Trigonometry', label:'3'}),
# (n277:NODE{link:'https://en.wikipedia.org//wiki/Inverse_function', label:'3'}),
# (n278:NODE{link:'https://en.wikipedia.org//wiki/Domain_of_a_function', label:'3'}),
# (n279:NODE{link:'https://en.wikipedia.org//wiki/Sine', label:'1'}),
# (n280:NODE{link:'https://en.wikipedia.org//wiki/Cosine', label:'3'}),
# (n281:NODE{link:'https://en.wikipedia.org//wiki/Tangent_(trigonometry)', label:'3'}),
# (n282:NODE{link:'https://en.wikipedia.org//wiki/Cotangent', label:'3'}),
# (n283:NODE{link:'https://en.wikipedia.org//wiki/Secant_(trigonometry)', label:'3'}),
# (n284:NODE{link:'https://en.wikipedia.org//wiki/Cosecant', label:'3'}),
# (n285:NODE{link:'https://en.wikipedia.org//wiki/Navigation', label:'3'}),
# (n286:NODE{link:'https://en.wikipedia.org//wiki/Trigonometric_functions#Notation', label:'3'}),
# (n287:NODE{link:'https://en.wikipedia.org//wiki/Wikipedia:Citation_needed', label:'3'}),
# (n288:NODE{link:'https://en.wikipedia.org//wiki/John_Herschel', label:'3'}),
# (n289:NODE{link:'https://en.wikipedia.org//wiki/Iterated_function#Definition', label:'3'}),
# (n290:NODE{link:'https://en.wikipedia.org//wiki/Multivalued_function', label:'3'}),
# (n291:NODE{link:'https://en.wikipedia.org//wiki/Multiplicative_inverse', label:'3'}),
# (n292:NODE{link:'https://en.wikipedia.org//wiki/UPPERCASE', label:'3'}),
# (n293:NODE{link:'https://en.wikipedia.org//wiki/ISO_80000-2#Function_symbols_and_definitions', label:'3'}),
# (n294:NODE{link:'https://en.wikipedia.org//wiki/One-to-one_function', label:'3'}),
# (n295:NODE{link:'https://en.wikipedia.org//wiki/Range_of_a_function', label:'3'}),
# (n296:NODE{link:'https://en.wikipedia.org//wiki/Subset', label:'3'}),
# (n297:NODE{link:'https://en.wikipedia.org//wiki/Square_root', label:'2'}),
# (n298:NODE{link:'https://en.wikipedia.org//wiki/Countably_infinite', label:'3'}),
# (n299:NODE{link:'https://en.wikipedia.org//wiki/Principal_branch', label:'1'}),
# (n300:NODE{link:'https://en.wikipedia.org//wiki/Principal_value', label:'3'}),
# (n301:NODE{link:'https://en.wikipedia.org//wiki/Radian', label:'3'}),
# (n302:NODE{link:'https://en.wikipedia.org//wiki/Degree_(angle)', label:'1'}),
# (n303:NODE{link:'https://en.wikipedia.org//wiki/Image_of_a_function', label:'3'}),
# (n304:NODE{link:'https://en.wikipedia.org//wiki/Radians', label:'3'}),
# (n305:NODE{link:'https://en.wikipedia.org//wiki/Integer', label:'1'}),
# (n306:NODE{link:'https://en.wikipedia.org//wiki/Set_subtraction', label:'3'}),
# (n307:NODE{link:'https://en.wikipedia.org//wiki/Minkowski_sum', label:'3'}),
# (n308:NODE{link:'https://en.wikipedia.org//wiki/Odd_integer', label:'3'}),
# (n309:NODE{link:'https://en.wikipedia.org//wiki/Well-defined', label:'3'}),
# (n310:NODE{link:'https://en.wikipedia.org//wiki/Logical_equality', label:'3'}),
# (n311:NODE{link:'https://en.wikipedia.org//wiki/If_and_only_if', label:'3'}),
# (n312:NODE{link:'https://en.wikipedia.org//wiki/Absolute_value', label:'1'}),
# (n313:NODE{link:'https://en.wikipedia.org//wiki/Sign_function', label:'1'}),
# (n314:NODE{link:'https://en.wikipedia.org//wiki/File:Trigonometric_functions_and_inverse3.svg', label:'3'}),
# (n315:NODE{link:'https://en.wikipedia.org//wiki/File:Trigonometric_functions_and_inverse.svg', label:'3'}),
# (n316:NODE{link:'https://en.wikipedia.org//wiki/File:Trigonometric_functions_and_inverse2.svg', label:'3'}),
# (n317:NODE{link:'https://en.wikipedia.org//wiki/File:Trigonometric_functions_and_inverse4.svg', label:'3'}),
# (n318:NODE{link:'https://en.wikipedia.org//wiki/File:Trigonometric_functions_and_inverse6.svg', label:'3'}),
# (n319:NODE{link:'https://en.wikipedia.org//wiki/File:Trigonometric_functions_and_inverse5.svg', label:'3'}),
# (n320:NODE{link:'https://en.wikipedia.org//wiki/File:Arcsine_Arccosine.svg', label:'3'}),
# (n321:NODE{link:'https://en.wikipedia.org//wiki/File:Arctangent_Arccotangent.svg', label:'3'}),
# (n322:NODE{link:'https://en.wikipedia.org//wiki/File:Arcsecant_Arccosecant.svg', label:'3'}),
# (n323:NODE{link:'https://en.wikipedia.org//wiki/Tangent_half-angle_formula', label:'3'}),
# (n324:NODE{link:'https://en.wikipedia.org//wiki/Angle_sum_and_difference_identities', label:'3'}),
# (n325:NODE{link:'https://en.wikipedia.org//wiki/Derivative', label:'3'}),
# (n326:NODE{link:'https://en.wikipedia.org//wiki/Improper_integral', label:'3'}),
# (n327:NODE{link:'https://en.wikipedia.org//wiki/Power_series', label:'3'}),
# (n328:NODE{link:'https://en.wikipedia.org//wiki/Binomial_series', label:'3'}),
# (n329:NODE{link:'https://en.wikipedia.org//wiki/Geometric_series', label:'3'}),
# (n330:NODE{link:'https://en.wikipedia.org//wiki/Leibniz_series', label:'3'}),
# (n331:NODE{link:'https://en.wikipedia.org//wiki/Leonhard_Euler', label:'0'}),
# (n332:NODE{link:'https://en.wikipedia.org//wiki/Taylor_series', label:'3'}),
# (n333:NODE{link:'https://en.wikipedia.org//wiki/Empty_product', label:'3'}),
# (n334:NODE{link:'https://en.wikipedia.org//wiki/Imaginary_unit', label:'1'}),
# (n335:NODE{link:'https://en.wikipedia.org//wiki/Generalized_continued_fraction', label:'3'}),
# (n336:NODE{link:'https://en.wikipedia.org//wiki/Carl_Friedrich_Gauss', label:'1'}),
# (n337:NODE{link:'https://en.wikipedia.org//wiki/Gaussian_hypergeometric_series', label:'3'}),
# (n338:NODE{link:'https://en.wikipedia.org//wiki/Inverse_hyperbolic_functions#Logarithmic_representation', label:'3'}),
# (n339:NODE{link:'https://en.wikipedia.org//wiki/Integration_by_parts', label:'3'}),
# (n340:NODE{link:'https://en.wikipedia.org//wiki/Integration_by_substitution', label:'3'}),
# (n341:NODE{link:'https://en.wikipedia.org//wiki/File:Riemann_surface_for_Arg_of_ArcTan_of_x.svg', label:'3'}),
# (n342:NODE{link:'https://en.wikipedia.org//wiki/Riemann_surface', label:'3'}),
# (n343:NODE{link:'https://en.wikipedia.org//wiki/Analytic_function', label:'3'}),
# (n344:NODE{link:'https://en.wikipedia.org//wiki/Branch_point', label:'3'}),
# (n345:NODE{link:'https://en.wikipedia.org//wiki/Branch_cut', label:'1'}),
# (n346:NODE{link:'https://en.wikipedia.org//wiki/Complex_logarithm', label:'1'}),
# (n347:NODE{link:'https://en.wikipedia.org//wiki/Complex_plane', label:'3'}),
# (n348:NODE{link:'https://en.wikipedia.org//wiki/Euler%27s_formula', label:'1'}),
# (n349:NODE{link:'https://en.wikipedia.org//wiki/Pythagorean_Theorem', label:'3'}),
# (n350:NODE{link:'https://en.wikipedia.org//wiki/Hyperbolic_angle', label:'3'}),
# (n351:NODE{link:'https://en.wikipedia.org//wiki/Inverse_hyperbolic_functions', label:'3'}),
# (n352:NODE{link:'https://en.wikipedia.org//wiki/Trigonometric_functions#Relationship_to_exponential_function_(Euler's_formula)', label:'3'}),
# (n353:NODE{link:'https://en.wikipedia.org//wiki/Domain_coloring', label:'3'}),
# (n354:NODE{link:'https://en.wikipedia.org//wiki/File:Complex_arcsin.jpg', label:'3'}),
# (n355:NODE{link:'https://en.wikipedia.org//wiki/File:Complex_arccos.jpg', label:'3'}),
# (n356:NODE{link:'https://en.wikipedia.org//wiki/File:Complex_arctan.jpg', label:'3'}),
# (n357:NODE{link:'https://en.wikipedia.org//wiki/File:Complex_ArcCot.jpg', label:'3'}),
# (n358:NODE{link:'https://en.wikipedia.org//wiki/File:Complex_ArcSec.jpg', label:'3'}),
# (n359:NODE{link:'https://en.wikipedia.org//wiki/File:Complex_ArcCsc.jpg', label:'3'}),
# (n360:NODE{link:'https://en.wikipedia.org//wiki/File:Trigonometry_triangle.svg', label:'3'}),
# (n361:NODE{link:'https://en.wikipedia.org//wiki/Right_triangle', label:'3'}),
# (n362:NODE{link:'https://en.wikipedia.org//wiki/Atan2', label:'3'}),
# (n363:NODE{link:'https://en.wikipedia.org//wiki/Arg_(mathematics)', label:'3'}),
# (n364:NODE{link:'https://en.wikipedia.org//wiki/ISO_standard', label:'3'}),
# (n365:NODE{link:'https://en.wikipedia.org//wiki/C_(programming_language)', label:'1'}),
# (n366:NODE{link:'https://en.wikipedia.org//wiki/Atan2#Realizations_of_the_function_in_common_programming_languages', label:'3'}),
# (n367:NODE{link:'https://en.wikipedia.org//wiki/Ill-conditioned', label:'3'}),
# (n368:NODE{link:'https://en.wikipedia.org//wiki/Inverse_exsecant', label:'3'}),
# (n369:NODE{link:'https://en.wikipedia.org//wiki/Inverse_versine', label:'3'}),
# (n370:NODE{link:'https://en.wikipedia.org//wiki/Trigonometric_function', label:'1'}),
# (n371:NODE{link:'https://en.wikipedia.org//wiki/Trigonometric_functions_of_matrices', label:'3'}),
# (n372:NODE{link:'https://en.wikipedia.org//wiki/Milton_Abramowitz', label:'1'}),
# (n373:NODE{link:'https://en.wikipedia.org//wiki/Irene_Stegun', label:'1'}),
# (n374:NODE{link:'https://en.wikipedia.org//wiki/Dover_Publications', label:'1'}),
# (n375:NODE{link:'https://en.wikipedia.org//wiki/Special:BookSources/978-0-486-61272-0', label:'1'}),
# (n376:NODE{link:'https://en.wikipedia.org//wiki/Nuclear_Instruments_and_Methods', label:'3'}),
# (n377:NODE{link:'https://en.wikipedia.org//wiki/ScienceDirect', label:'3'}),
# (n378:NODE{link:'https://en.wikipedia.org//wiki/Bibcode_(identifier)', label:'1'}),
# (n379:NODE{link:'https://en.wikipedia.org//wiki/Doi_(identifier)', label:'1'}),
# (n380:NODE{link:'https://en.wikipedia.org//wiki/Michiel_Hazewinkel', label:'3'}),
# (n381:NODE{link:'https://en.wikipedia.org//wiki/Kluwer_Academic_Publishers', label:'3'}),
# (n382:NODE{link:'https://en.wikipedia.org//wiki/Springer_Science_%26_Business_Media', label:'3'}),
# (n383:NODE{link:'https://en.wikipedia.org//wiki/Special:BookSources/978-155608010-4', label:'3'}),
# (n384:NODE{link:'https://en.wikipedia.org//wiki/University_of_Konstanz', label:'3'}),
# (n385:NODE{link:'https://en.wikipedia.org//wiki/Ventus_Publishing_ApS', label:'3'}),
# (n386:NODE{link:'https://en.wikipedia.org//wiki/Bookboon', label:'3'}),
# (n387:NODE{link:'https://en.wikipedia.org//wiki/Special:BookSources/978-87-7681-702-2', label:'3'}),
# (n388:NODE{link:'https://en.wikipedia.org//wiki/Special:BookSources/978-956141314-6', label:'3'}),
# (n389:NODE{link:'https://en.wikipedia.org//wiki/Henry_Holt_and_Company', label:'3'}),
# (n390:NODE{link:'https://en.wikipedia.org//wiki/Arc-sine', label:'3'}),
# (n391:NODE{link:'https://en.wikipedia.org//wiki/Anti-sine', label:'3'}),
# (n392:NODE{link:'https://en.wikipedia.org//wiki/Anti-function', label:'3'}),
# (n393:NODE{link:'https://en.wikipedia.org//wiki/Christian_Felix_Klein', label:'3'}),
# (n394:NODE{link:'https://en.wikipedia.org//wiki/J._Springer', label:'3'}),
# (n395:NODE{link:'https://en.wikipedia.org//wiki/Dover_Publications,_Inc.', label:'3'}),
# (n396:NODE{link:'https://en.wikipedia.org//wiki/The_Macmillan_Company', label:'3'}),
# (n397:NODE{link:'https://en.wikipedia.org//wiki/Special:BookSources/978-0-48643480-3', label:'3'}),
# (n398:NODE{link:'https://en.wikipedia.org//wiki/Special:BookSources/978-0-486-61348-2', label:'3'}),
# (n399:NODE{link:'https://en.wikipedia.org//wiki/The_Americana', label:'3'}),
# (n400:NODE{link:'https://en.wikipedia.org//wiki/Florian_Cajori', label:'3'}),
# (n401:NODE{link:'https://en.wikipedia.org//wiki/John_Frederick_William_Herschel', label:'3'}),
# (n402:NODE{link:'https://en.wikipedia.org//wiki/Theresa_M._Korn', label:'3'}),
# (n403:NODE{link:'https://en.wikipedia.org//wiki/Special:BookSources/978-0-486-41147-7', label:'3'}),
# (n404:NODE{link:'https://en.wikipedia.org//wiki/Lahore', label:'3'}),
# (n405:NODE{link:'https://en.wikipedia.org//wiki/A._K._Peters', label:'3'}),
# (n406:NODE{link:'https://en.wikipedia.org//wiki/Special:BookSources/978-1-56881-136-9', label:'3'}),
# (n407:NODE{link:'https://en.wikipedia.org//wiki/S2CID_(identifier)', label:'3'}),
# (n408:NODE{link:'https://en.wikipedia.org//wiki/ArXiv_(identifier)', label:'2'}),
# (n409:NODE{link:'https://en.wikipedia.org//wiki/Cambridge_University_Press', label:'1'}),
# (n410:NODE{link:'https://en.wikipedia.org//wiki/Eric_W._Weisstein', label:'1'}),
# (n411:NODE{link:'https://en.wikipedia.org//wiki/MathWorld', label:'1'}),
# (n412:NODE{link:'https://en.wikipedia.org//wiki/Template:Trigonometric_and_hyperbolic_functions', label:'3'}),
# (n413:NODE{link:'https://en.wikipedia.org//wiki/Template_talk:Trigonometric_and_hyperbolic_functions', label:'3'}),
# (n414:NODE{link:'https://en.wikipedia.org//wiki/Sine_and_cosine', label:'3'}),
# (n415:NODE{link:'https://en.wikipedia.org//wiki/Hyperbolic_functions', label:'3'}),
# (n416:NODE{link:'https://en.wikipedia.org//wiki/Versine', label:'3'}),
# (n417:NODE{link:'https://en.wikipedia.org//wiki/Exsecant', label:'3'}),
# (n418:NODE{link:'https://en.wikipedia.org//wiki/Jy%C4%81,_koti-jy%C4%81_and_utkrama-jy%C4%81', label:'3'}),
# (n419:NODE{link:'https://en.wikipedia.org//wiki/Category:Inverse_trigonometric_functions', label:'3'}),
# (n420:NODE{link:'https://en.wikipedia.org//wiki/Category:Trigonometry', label:'3'}),
# (n421:NODE{link:'https://en.wikipedia.org//wiki/Category:Elementary_special_functions', label:'1'}),
# (n422:NODE{link:'https://en.wikipedia.org//wiki/Category:Mathematical_relations', label:'3'}),
# (n423:NODE{link:'https://en.wikipedia.org//wiki/Category:Ratios', label:'3'}),
# (n424:NODE{link:'https://en.wikipedia.org//wiki/Category:Dimensionless_numbers', label:'3'}),
# (n425:NODE{link:'https://en.wikipedia.org//wiki/Category:CS1:_long_volume_value', label:'3'}),
# (n426:NODE{link:'https://en.wikipedia.org//wiki/Category:CS1_location_test', label:'3'}),
# (n427:NODE{link:'https://en.wikipedia.org//wiki/Category:CS1_German-language_sources_(de)', label:'1'}),
# (n428:NODE{link:'https://en.wikipedia.org//wiki/Category:All_articles_with_unsourced_statements', label:'1'}),
# (n429:NODE{link:'https://en.wikipedia.org//wiki/Category:Articles_with_unsourced_statements_from_March_2020', label:'3'}),
# (n430:NODE{link:'https://en.wikipedia.org//wiki/Category:Short_description_is_different_from_Wikidata', label:'1'}),
# (n431:NODE{link:'https://en.wikipedia.org//wiki/Category:Articles_with_unsourced_statements_from_January_2019', label:'3'}),
# (n432:NODE{link:'https://en.wikipedia.org//wiki/Category:Articles_with_unsourced_statements_from_March_2021', label:'3'}),
# (n433:NODE{link:'https://en.wikipedia.org//wiki/Category:Articles_with_unsourced_statements_from_May_2016', label:'3'}),
# (n434:NODE{link:'https://en.wikipedia.org//wiki/Inverse_trigonometric_functions', label:'3'}),
# (n435:NODE{link:'https://en.wikipedia.org//wiki/Talk:Inverse_trigonometric_functions', label:'3'}),
# (n436:NODE{link:'https://en.wikipedia.org//wiki/Special:WhatLinksHere/Inverse_trigonometric_functions', label:'3'}),
# (n437:NODE{link:'https://en.wikipedia.org//wiki/Special:RecentChangesLinked/Inverse_trigonometric_functions', label:'3'}),
#
# (n28)-[r1:NEIGHBOR_OF]->(n4),
# (n29)-[r2:NEIGHBOR_OF]->(n4),
# (n29)-[r3:NEIGHBOR_OF]->(n4),
# (n30)-[r4:NEIGHBOR_OF]->(n4),
# (n31)-[r5:NEIGHBOR_OF]->(n4),
# (n32)-[r6:NEIGHBOR_OF]->(n4),
# (n33)-[r7:NEIGHBOR_OF]->(n4),
# (n34)-[r8:NEIGHBOR_OF]->(n4),
# (n35)-[r9:NEIGHBOR_OF]->(n4),
# (n36)-[r10:NEIGHBOR_OF]->(n4),
# (n33)-[r11:NEIGHBOR_OF]->(n4),
# (n37)-[r12:NEIGHBOR_OF]->(n4),
# (n38)-[r13:NEIGHBOR_OF]->(n4),
# (n39)-[r14:NEIGHBOR_OF]->(n4),
# (n40)-[r15:NEIGHBOR_OF]->(n4),
# (n41)-[r16:NEIGHBOR_OF]->(n4),
# (n42)-[r17:NEIGHBOR_OF]->(n4),
# (n43)-[r18:NEIGHBOR_OF]->(n4),
# (n44)-[r19:NEIGHBOR_OF]->(n4),
# (n45)-[r20:NEIGHBOR_OF]->(n4),
# (n46)-[r21:NEIGHBOR_OF]->(n4),
# (n34)-[r22:NEIGHBOR_OF]->(n4),
# (n34)-[r23:NEIGHBOR_OF]->(n4),
# (n47)-[r24:NEIGHBOR_OF]->(n4),
# (n47)-[r25:NEIGHBOR_OF]->(n4),
# (n31)-[r26:NEIGHBOR_OF]->(n4),
# (n32)-[r27:NEIGHBOR_OF]->(n4),
# (n48)-[r28:NEIGHBOR_OF]->(n4),
# (n34)-[r29:NEIGHBOR_OF]->(n4),
# (n49)-[r30:NEIGHBOR_OF]->(n4),
# (n50)-[r31:NEIGHBOR_OF]->(n4),
# (n51)-[r32:NEIGHBOR_OF]->(n4),
# (n36)-[r33:NEIGHBOR_OF]->(n4),
# (n35)-[r34:NEIGHBOR_OF]->(n4),
# (n52)-[r35:NEIGHBOR_OF]->(n4),
# (n53)-[r36:NEIGHBOR_OF]->(n4),
# (n54)-[r37:NEIGHBOR_OF]->(n4),
# (n46)-[r38:NEIGHBOR_OF]->(n4),
# (n55)-[r39:NEIGHBOR_OF]->(n4),
# (n56)-[r40:NEIGHBOR_OF]->(n4),
# (n57)-[r41:NEIGHBOR_OF]->(n4),
# (n58)-[r42:NEIGHBOR_OF]->(n4),
# (n59)-[r43:NEIGHBOR_OF]->(n4),
# (n60)-[r44:NEIGHBOR_OF]->(n4),
# (n61)-[r45:NEIGHBOR_OF]->(n4),
# (n42)-[r46:NEIGHBOR_OF]->(n4),
# (n33)-[r47:NEIGHBOR_OF]->(n4),
# (n32)-[r48:NEIGHBOR_OF]->(n4),
# (n62)-[r49:NEIGHBOR_OF]->(n4),
# (n63)-[r50:NEIGHBOR_OF]->(n4),
# (n64)-[r51:NEIGHBOR_OF]->(n4),
# (n65)-[r52:NEIGHBOR_OF]->(n4),
# (n66)-[r53:NEIGHBOR_OF]->(n4),
# (n67)-[r54:NEIGHBOR_OF]->(n4),
# (n68)-[r55:NEIGHBOR_OF]->(n4),
# (n69)-[r56:NEIGHBOR_OF]->(n4),
# (n33)-[r57:NEIGHBOR_OF]->(n4),
# (n33)-[r58:NEIGHBOR_OF]->(n4),
# (n70)-[r59:NEIGHBOR_OF]->(n4),
# (n70)-[r60:NEIGHBOR_OF]->(n4),
# (n31)-[r61:NEIGHBOR_OF]->(n4),
# (n32)-[r62:NEIGHBOR_OF]->(n4),
# (n48)-[r63:NEIGHBOR_OF]->(n4),
# (n33)-[r64:NEIGHBOR_OF]->(n4),
# (n71)-[r65:NEIGHBOR_OF]->(n4),
# (n44)-[r66:NEIGHBOR_OF]->(n4),
# (n45)-[r67:NEIGHBOR_OF]->(n4),
# (n72)-[r68:NEIGHBOR_OF]->(n4),
# (n46)-[r69:NEIGHBOR_OF]->(n4),
# (n73)-[r70:NEIGHBOR_OF]->(n4),
# (n74)-[r71:NEIGHBOR_OF]->(n4),
# (n75)-[r72:NEIGHBOR_OF]->(n4),
# (n34)-[r73:NEIGHBOR_OF]->(n4),
# (n32)-[r74:NEIGHBOR_OF]->(n4),
# (n64)-[r75:NEIGHBOR_OF]->(n4),
# (n76)-[r76:NEIGHBOR_OF]->(n4),
# (n39)-[r77:NEIGHBOR_OF]->(n4),
# (n77)-[r78:NEIGHBOR_OF]->(n4),
# (n78)-[r79:NEIGHBOR_OF]->(n4),
# (n37)-[r80:NEIGHBOR_OF]->(n4),
# (n79)-[r81:NEIGHBOR_OF]->(n4),
# (n80)-[r82:NEIGHBOR_OF]->(n4),
# (n81)-[r83:NEIGHBOR_OF]->(n4),
# (n82)-[r84:NEIGHBOR_OF]->(n4),
# (n83)-[r85:NEIGHBOR_OF]->(n4),
# (n84)-[r86:NEIGHBOR_OF]->(n4),
# (n85)-[r87:NEIGHBOR_OF]->(n4),
# (n86)-[r88:NEIGHBOR_OF]->(n4),
# (n87)-[r89:NEIGHBOR_OF]->(n4),
# (n88)-[r90:NEIGHBOR_OF]->(n4),
# (n89)-[r91:NEIGHBOR_OF]->(n4),
# (n90)-[r92:NEIGHBOR_OF]->(n4),
# (n91)-[r93:NEIGHBOR_OF]->(n4),
# (n92)-[r94:NEIGHBOR_OF]->(n4),
# (n93)-[r95:NEIGHBOR_OF]->(n4),
# (n42)-[r96:NEIGHBOR_OF]->(n4),
# (n94)-[r97:NEIGHBOR_OF]->(n4),
# (n95)-[r98:NEIGHBOR_OF]->(n4),
# (n31)-[r99:NEIGHBOR_OF]->(n4),
# (n96)-[r100:NEIGHBOR_OF]->(n4),
# (n48)-[r101:NEIGHBOR_OF]->(n4),
# (n97)-[r102:NEIGHBOR_OF]->(n4),
# (n98)-[r103:NEIGHBOR_OF]->(n4),
# (n99)-[r104:NEIGHBOR_OF]->(n4),
# (n100)-[r105:NEIGHBOR_OF]->(n4),
# (n101)-[r106:NEIGHBOR_OF]->(n4),
# (n69)-[r107:NEIGHBOR_OF]->(n4),
# (n102)-[r108:NEIGHBOR_OF]->(n4),
# (n103)-[r109:NEIGHBOR_OF]->(n4),
# (n104)-[r110:NEIGHBOR_OF]->(n4),
# (n33)-[r111:NEIGHBOR_OF]->(n4),
# (n105)-[r112:NEIGHBOR_OF]->(n4),
# (n106)-[r113:NEIGHBOR_OF]->(n4),
# (n107)-[r114:NEIGHBOR_OF]->(n4),
# (n108)-[r115:NEIGHBOR_OF]->(n4),
# (n109)-[r116:NEIGHBOR_OF]->(n4),
# (n110)-[r117:NEIGHBOR_OF]->(n4),
# (n111)-[r118:NEIGHBOR_OF]->(n4),
# (n112)-[r119:NEIGHBOR_OF]->(n4),
# (n85)-[r120:NEIGHBOR_OF]->(n4),
# (n34)-[r121:NEIGHBOR_OF]->(n4),
# (n113)-[r122:NEIGHBOR_OF]->(n4),
# (n114)-[r123:NEIGHBOR_OF]->(n4),
# (n115)-[r124:NEIGHBOR_OF]->(n4),
# (n116)-[r125:NEIGHBOR_OF]->(n4),
# (n117)-[r126:NEIGHBOR_OF]->(n4),
# (n117)-[r127:NEIGHBOR_OF]->(n4),
# (n118)-[r128:NEIGHBOR_OF]->(n4),
# (n119)-[r129:NEIGHBOR_OF]->(n4),
# (n120)-[r130:NEIGHBOR_OF]->(n4),
# (n111)-[r131:NEIGHBOR_OF]->(n4),
# (n74)-[r132:NEIGHBOR_OF]->(n4),
# (n121)-[r133:NEIGHBOR_OF]->(n4),
# (n122)-[r134:NEIGHBOR_OF]->(n4),
# (n123)-[r135:NEIGHBOR_OF]->(n4),
# (n42)-[r136:NEIGHBOR_OF]->(n4),
# (n124)-[r137:NEIGHBOR_OF]->(n4),
# (n125)-[r138:NEIGHBOR_OF]->(n4),
# (n68)-[r139:NEIGHBOR_OF]->(n4),
# (n126)-[r140:NEIGHBOR_OF]->(n4),
# (n127)-[r141:NEIGHBOR_OF]->(n4),
# (n128)-[r142:NEIGHBOR_OF]->(n4),
# (n129)-[r143:NEIGHBOR_OF]->(n4),
# (n130)-[r144:NEIGHBOR_OF]->(n4),
# (n131)-[r145:NEIGHBOR_OF]->(n4),
# (n132)-[r146:NEIGHBOR_OF]->(n4),
# (n133)-[r147:NEIGHBOR_OF]->(n4),
# (n134)-[r148:NEIGHBOR_OF]->(n4),
# (n135)-[r149:NEIGHBOR_OF]->(n4),
# (n136)-[r150:NEIGHBOR_OF]->(n4),
# (n137)-[r151:NEIGHBOR_OF]->(n4),
# (n138)-[r152:NEIGHBOR_OF]->(n4),
# (n139)-[r153:NEIGHBOR_OF]->(n4),
# (n140)-[r154:NEIGHBOR_OF]->(n4),
# (n141)-[r155:NEIGHBOR_OF]->(n4),
# (n142)-[r156:NEIGHBOR_OF]->(n4),
# (n143)-[r157:NEIGHBOR_OF]->(n4),
# (n144)-[r158:NEIGHBOR_OF]->(n4),
# (n145)-[r159:NEIGHBOR_OF]->(n4),
# (n146)-[r160:NEIGHBOR_OF]->(n4),
# (n147)-[r161:NEIGHBOR_OF]->(n4),
# (n148)-[r162:NEIGHBOR_OF]->(n4),
# (n149)-[r163:NEIGHBOR_OF]->(n4),
# (n150)-[r164:NEIGHBOR_OF]->(n4),
# (n151)-[r165:NEIGHBOR_OF]->(n4),
# (n152)-[r166:NEIGHBOR_OF]->(n4),
# (n153)-[r167:NEIGHBOR_OF]->(n4),
# (n154)-[r168:NEIGHBOR_OF]->(n4),
# (n155)-[r169:NEIGHBOR_OF]->(n4),
# (n156)-[r170:NEIGHBOR_OF]->(n4),
# (n157)-[r171:NEIGHBOR_OF]->(n4),
# (n158)-[r172:NEIGHBOR_OF]->(n4),
# (n159)-[r173:NEIGHBOR_OF]->(n4),
# (n160)-[r174:NEIGHBOR_OF]->(n4),
# (n30)-[r175:NEIGHBOR_OF]->(n4),
# (n119)-[r176:NEIGHBOR_OF]->(n4),
# (n45)-[r177:NEIGHBOR_OF]->(n4),
# (n161)-[r178:NEIGHBOR_OF]->(n4),
# (n162)-[r179:NEIGHBOR_OF]->(n4),
# (n149)-[r180:NEIGHBOR_OF]->(n4),
# (n34)-[r181:NEIGHBOR_OF]->(n4),
# (n163)-[r182:NEIGHBOR_OF]->(n4),
# (n164)-[r183:NEIGHBOR_OF]->(n4),
# (n165)-[r184:NEIGHBOR_OF]->(n4),
# (n166)-[r185:NEIGHBOR_OF]->(n4),
# (n167)-[r186:NEIGHBOR_OF]->(n4),
# (n168)-[r187:NEIGHBOR_OF]->(n4),
# (n169)-[r188:NEIGHBOR_OF]->(n4),
# (n46)-[r189:NEIGHBOR_OF]->(n4),
# (n170)-[r190:NEIGHBOR_OF]->(n4),
# (n171)-[r191:NEIGHBOR_OF]->(n4),
# (n170)-[r192:NEIGHBOR_OF]->(n4),
# (n172)-[r193:NEIGHBOR_OF]->(n4),
# (n173)-[r194:NEIGHBOR_OF]->(n4),
# (n28)-[r195:NEIGHBOR_OF]->(n4),
# (n174)-[r196:NEIGHBOR_OF]->(n4),
# (n108)-[r197:NEIGHBOR_OF]->(n4),
# (n89)-[r198:NEIGHBOR_OF]->(n4),
# (n175)-[r199:NEIGHBOR_OF]->(n4),
# (n176)-[r200:NEIGHBOR_OF]->(n4),
# (n177)-[r201:NEIGHBOR_OF]->(n4),
# (n178)-[r202:NEIGHBOR_OF]->(n4),
# (n179)-[r203:NEIGHBOR_OF]->(n4),
# (n180)-[r204:NEIGHBOR_OF]->(n4),
# (n151)-[r205:NEIGHBOR_OF]->(n4),
# (n181)-[r206:NEIGHBOR_OF]->(n4),
# (n182)-[r207:NEIGHBOR_OF]->(n4),
# (n183)-[r208:NEIGHBOR_OF]->(n4),
# (n184)-[r209:NEIGHBOR_OF]->(n4),
# (n185)-[r210:NEIGHBOR_OF]->(n4),
# (n186)-[r211:NEIGHBOR_OF]->(n4),
# (n187)-[r212:NEIGHBOR_OF]->(n4),
# (n188)-[r213:NEIGHBOR_OF]->(n4),
# (n189)-[r214:NEIGHBOR_OF]->(n4),
# (n190)-[r215:NEIGHBOR_OF]->(n4),
# (n191)-[r216:NEIGHBOR_OF]->(n4),
# (n192)-[r217:NEIGHBOR_OF]->(n4),
# (n193)-[r218:NEIGHBOR_OF]->(n4),
# (n194)-[r219:NEIGHBOR_OF]->(n4),
# (n195)-[r220:NEIGHBOR_OF]->(n4),
# (n196)-[r221:NEIGHBOR_OF]->(n4),
# (n197)-[r222:NEIGHBOR_OF]->(n4),
# (n180)-[r223:NEIGHBOR_OF]->(n4),
# (n82)-[r224:NEIGHBOR_OF]->(n4),
# (n198)-[r225:NEIGHBOR_OF]->(n4),
# (n199)-[r226:NEIGHBOR_OF]->(n4),
# (n200)-[r227:NEIGHBOR_OF]->(n4),
# (n201)-[r228:NEIGHBOR_OF]->(n4),
# (n202)-[r229:NEIGHBOR_OF]->(n4),
# (n203)-[r230:NEIGHBOR_OF]->(n4),
# (n204)-[r231:NEIGHBOR_OF]->(n4),
# (n205)-[r232:NEIGHBOR_OF]->(n4),
# (n206)-[r233:NEIGHBOR_OF]->(n4),
# (n207)-[r234:NEIGHBOR_OF]->(n4),
# (n208)-[r235:NEIGHBOR_OF]->(n4),
# (n209)-[r236:NEIGHBOR_OF]->(n4),
# (n210)-[r237:NEIGHBOR_OF]->(n4),
# (n211)-[r238:NEIGHBOR_OF]->(n4),
# (n212)-[r239:NEIGHBOR_OF]->(n4),
# (n211)-[r240:NEIGHBOR_OF]->(n4),
# (n213)-[r241:NEIGHBOR_OF]->(n4),
# (n214)-[r242:NEIGHBOR_OF]->(n4),
# (n211)-[r243:NEIGHBOR_OF]->(n4),
# (n215)-[r244:NEIGHBOR_OF]->(n4),
# (n216)-[r245:NEIGHBOR_OF]->(n4),
# (n217)-[r246:NEIGHBOR_OF]->(n4),
# (n218)-[r247:NEIGHBOR_OF]->(n4),
# (n211)-[r248:NEIGHBOR_OF]->(n4),
# (n219)-[r249:NEIGHBOR_OF]->(n4),
# (n220)-[r250:NEIGHBOR_OF]->(n4),
# (n221)-[r251:NEIGHBOR_OF]->(n4),
# (n222)-[r252:NEIGHBOR_OF]->(n4),
# (n223)-[r253:NEIGHBOR_OF]->(n4),
# (n224)-[r254:NEIGHBOR_OF]->(n4),
# (n225)-[r255:NEIGHBOR_OF]->(n4),
# (n226)-[r256:NEIGHBOR_OF]->(n4),
# (n227)-[r257:NEIGHBOR_OF]->(n4),
# (n228)-[r258:NEIGHBOR_OF]->(n4),
# (n229)-[r259:NEIGHBOR_OF]->(n4),
# (n230)-[r260:NEIGHBOR_OF]->(n4),
# (n231)-[r261:NEIGHBOR_OF]->(n4),
# (n232)-[r262:NEIGHBOR_OF]->(n4),
# (n233)-[r263:NEIGHBOR_OF]->(n4),
# (n234)-[r264:NEIGHBOR_OF]->(n4),
# (n235)-[r265:NEIGHBOR_OF]->(n4),
# (n236)-[r266:NEIGHBOR_OF]->(n4),
# (n237)-[r267:NEIGHBOR_OF]->(n4),
# (n238)-[r268:NEIGHBOR_OF]->(n4),
# (n239)-[r269:NEIGHBOR_OF]->(n4),
# (n238)-[r270:NEIGHBOR_OF]->(n4),
# (n240)-[r271:NEIGHBOR_OF]->(n4),
# (n240)-[r272:NEIGHBOR_OF]->(n4),
# (n241)-[r273:NEIGHBOR_OF]->(n4),
# (n242)-[r274:NEIGHBOR_OF]->(n4),
# (n243)-[r275:NEIGHBOR_OF]->(n4),
# (n244)-[r276:NEIGHBOR_OF]->(n4),
# (n245)-[r277:NEIGHBOR_OF]->(n4),
# (n246)-[r278:NEIGHBOR_OF]->(n4),
# (n247)-[r279:NEIGHBOR_OF]->(n4),
# (n248)-[r280:NEIGHBOR_OF]->(n4),
# (n249)-[r281:NEIGHBOR_OF]->(n4),
# (n250)-[r282:NEIGHBOR_OF]->(n4),
# (n251)-[r283:NEIGHBOR_OF]->(n4),
# (n249)-[r284:NEIGHBOR_OF]->(n4),
# (n252)-[r285:NEIGHBOR_OF]->(n4),
# (n244)-[r286:NEIGHBOR_OF]->(n4),
# (n253)-[r287:NEIGHBOR_OF]->(n4),
# (n254)-[r288:NEIGHBOR_OF]->(n13),
# (n255)-[r289:NEIGHBOR_OF]->(n13),
# (n256)-[r290:NEIGHBOR_OF]->(n13),
# (n257)-[r291:NEIGHBOR_OF]->(n13),
# (n258)-[r292:NEIGHBOR_OF]->(n13),
# (n259)-[r293:NEIGHBOR_OF]->(n13),
# (n260)-[r294:NEIGHBOR_OF]->(n13),
# (n261)-[r295:NEIGHBOR_OF]->(n13),
# (n262)-[r296:NEIGHBOR_OF]->(n13),
# (n263)-[r297:NEIGHBOR_OF]->(n13),
# (n264)-[r298:NEIGHBOR_OF]->(n13),
# (n265)-[r299:NEIGHBOR_OF]->(n13),
# (n266)-[r300:NEIGHBOR_OF]->(n13),
# (n267)-[r301:NEIGHBOR_OF]->(n13),
# (n268)-[r302:NEIGHBOR_OF]->(n13),
# (n269)-[r303:NEIGHBOR_OF]->(n13),
# (n270)-[r304:NEIGHBOR_OF]->(n13),
# (n271)-[r305:NEIGHBOR_OF]->(n13),
# (n272)-[r306:NEIGHBOR_OF]->(n13),
# (n273)-[r307:NEIGHBOR_OF]->(n13),
# (n274)-[r308:NEIGHBOR_OF]->(n13),
# (n275)-[r309:NEIGHBOR_OF]->(n13),
# (n276)-[r310:NEIGHBOR_OF]->(n13),
# (n31)-[r311:NEIGHBOR_OF]->(n13),
# (n277)-[r312:NEIGHBOR_OF]->(n13),
# (n259)-[r313:NEIGHBOR_OF]->(n13),
# (n278)-[r314:NEIGHBOR_OF]->(n13),
# (n279)-[r315:NEIGHBOR_OF]->(n13),
# (n280)-[r316:NEIGHBOR_OF]->(n13),
# (n281)-[r317:NEIGHBOR_OF]->(n13),
# (n282)-[r318:NEIGHBOR_OF]->(n13),
# (n283)-[r319:NEIGHBOR_OF]->(n13),
# (n284)-[r320:NEIGHBOR_OF]->(n13),
# (n48)-[r321:NEIGHBOR_OF]->(n13),
# (n285)-[r322:NEIGHBOR_OF]->(n13),
# (n32)-[r323:NEIGHBOR_OF]->(n13),
# (n39)-[r324:NEIGHBOR_OF]->(n13),
# (n286)-[r325:NEIGHBOR_OF]->(n13),
# (n287)-[r326:NEIGHBOR_OF]->(n13),
# (n264)-[r327:NEIGHBOR_OF]->(n13),
# (n288)-[r328:NEIGHBOR_OF]->(n13),
# (n289)-[r329:NEIGHBOR_OF]->(n13),
# (n277)-[r330:NEIGHBOR_OF]->(n13),
# (n290)-[r331:NEIGHBOR_OF]->(n13),
# (n291)-[r332:NEIGHBOR_OF]->(n13),
# (n277)-[r333:NEIGHBOR_OF]->(n13),
# (n292)-[r334:NEIGHBOR_OF]->(n13),
# (n293)-[r335:NEIGHBOR_OF]->(n13),
# (n294)-[r336:NEIGHBOR_OF]->(n13),
# (n295)-[r337:NEIGHBOR_OF]->(n13),
# (n296)-[r338:NEIGHBOR_OF]->(n13),
# (n290)-[r339:NEIGHBOR_OF]->(n13),
# (n297)-[r340:NEIGHBOR_OF]->(n13),
# (n298)-[r341:NEIGHBOR_OF]->(n13),
# (n299)-[r342:NEIGHBOR_OF]->(n13),
# (n300)-[r343:NEIGHBOR_OF]->(n13),
# (n301)-[r344:NEIGHBOR_OF]->(n13),
# (n302)-[r345:NEIGHBOR_OF]->(n13),
# (n279)-[r346:NEIGHBOR_OF]->(n13),
# (n280)-[r347:NEIGHBOR_OF]->(n13),
# (n281)-[r348:NEIGHBOR_OF]->(n13),
# (n282)-[r349:NEIGHBOR_OF]->(n13),
# (n283)-[r350:NEIGHBOR_OF]->(n13),
# (n284)-[r351:NEIGHBOR_OF]->(n13),
# (n287)-[r352:NEIGHBOR_OF]->(n13),
# (n73)-[r353:NEIGHBOR_OF]->(n13),
# (n303)-[r354:NEIGHBOR_OF]->(n13),
# (n300)-[r355:NEIGHBOR_OF]->(n13),
# (n304)-[r356:NEIGHBOR_OF]->(n13),
# (n278)-[r357:NEIGHBOR_OF]->(n13),
# (n303)-[r358:NEIGHBOR_OF]->(n13),
# (n303)-[r359:NEIGHBOR_OF]->(n13),
# (n300)-[r360:NEIGHBOR_OF]->(n13),
# (n279)-[r361:NEIGHBOR_OF]->(n13),
# (n280)-[r362:NEIGHBOR_OF]->(n13),
# (n281)-[r363:NEIGHBOR_OF]->(n13),
# (n282)-[r364:NEIGHBOR_OF]->(n13),
# (n283)-[r365:NEIGHBOR_OF]->(n13),
# (n284)-[r366:NEIGHBOR_OF]->(n13),
# (n46)-[r367:NEIGHBOR_OF]->(n13),
# (n305)-[r368:NEIGHBOR_OF]->(n13),
# (n306)-[r369:NEIGHBOR_OF]->(n13),
# (n307)-[r370:NEIGHBOR_OF]->(n13),
# (n308)-[r371:NEIGHBOR_OF]->(n13),
# (n309)-[r372:NEIGHBOR_OF]->(n13),
# (n305)-[r373:NEIGHBOR_OF]->(n13),
# (n310)-[r374:NEIGHBOR_OF]->(n13),
# (n311)-[r375:NEIGHBOR_OF]->(n13),
# (n310)-[r376:NEIGHBOR_OF]->(n13),
# (n310)-[r377:NEIGHBOR_OF]->(n13),
# (n310)-[r378:NEIGHBOR_OF]->(n13),
# (n310)-[r379:NEIGHBOR_OF]->(n13),
# (n310)-[r380:NEIGHBOR_OF]->(n13),
# (n310)-[r381:NEIGHBOR_OF]->(n13),
# (n310)-[r382:NEIGHBOR_OF]->(n13),
# (n310)-[r383:NEIGHBOR_OF]->(n13),
# (n311)-[r384:NEIGHBOR_OF]->(n13),
# (n310)-[r385:NEIGHBOR_OF]->(n13),
# (n310)-[r386:NEIGHBOR_OF]->(n13),
# (n269)-[r387:NEIGHBOR_OF]->(n13),
# (n287)-[r388:NEIGHBOR_OF]->(n13),
# (n312)-[r389:NEIGHBOR_OF]->(n13),
# (n313)-[r390:NEIGHBOR_OF]->(n13),
# (n314)-[r391:NEIGHBOR_OF]->(n13),
# (n315)-[r392:NEIGHBOR_OF]->(n13),
# (n316)-[r393:NEIGHBOR_OF]->(n13),
# (n317)-[r394:NEIGHBOR_OF]->(n13),
# (n318)-[r395:NEIGHBOR_OF]->(n13),
# (n319)-[r396:NEIGHBOR_OF]->(n13),
# (n320)-[r397:NEIGHBOR_OF]->(n13),
# (n320)-[r398:NEIGHBOR_OF]->(n13),
# (n321)-[r399:NEIGHBOR_OF]->(n13),
# (n321)-[r400:NEIGHBOR_OF]->(n13),
# (n322)-[r401:NEIGHBOR_OF]->(n13),
# (n322)-[r402:NEIGHBOR_OF]->(n13),
# (n323)-[r403:NEIGHBOR_OF]->(n13),
# (n324)-[r404:NEIGHBOR_OF]->(n13),
# (n274)-[r405:NEIGHBOR_OF]->(n13),
# (n325)-[r406:NEIGHBOR_OF]->(n13),
# (n326)-[r407:NEIGHBOR_OF]->(n13),
# (n327)-[r408:NEIGHBOR_OF]->(n13),
# (n328)-[r409:NEIGHBOR_OF]->(n13),
# (n329)-[r410:NEIGHBOR_OF]->(n13),
# (n330)-[r411:NEIGHBOR_OF]->(n13),
# (n331)-[r412:NEIGHBOR_OF]->(n13),
# (n332)-[r413:NEIGHBOR_OF]->(n13),
# (n333)-[r414:NEIGHBOR_OF]->(n13),
# (n334)-[r415:NEIGHBOR_OF]->(n13),
# (n335)-[r416:NEIGHBOR_OF]->(n13),
# (n331)-[r417:NEIGHBOR_OF]->(n13),
# (n336)-[r418:NEIGHBOR_OF]->(n13),
# (n337)-[r419:NEIGHBOR_OF]->(n13),
# (n338)-[r420:NEIGHBOR_OF]->(n13),
# (n339)-[r421:NEIGHBOR_OF]->(n13),
# (n339)-[r422:NEIGHBOR_OF]->(n13),
# (n340)-[r423:NEIGHBOR_OF]->(n13),
# (n341)-[r424:NEIGHBOR_OF]->(n13),
# (n341)-[r425:NEIGHBOR_OF]->(n13),
# (n342)-[r426:NEIGHBOR_OF]->(n13),
# (n343)-[r427:NEIGHBOR_OF]->(n13),
# (n344)-[r428:NEIGHBOR_OF]->(n13),
# (n345)-[r429:NEIGHBOR_OF]->(n13),
# (n346)-[r430:NEIGHBOR_OF]->(n13),
# (n278)-[r431:NEIGHBOR_OF]->(n13),
# (n347)-[r432:NEIGHBOR_OF]->(n13),
# (n348)-[r433:NEIGHBOR_OF]->(n13),
# (n349)-[r434:NEIGHBOR_OF]->(n13),
# (n350)-[r435:NEIGHBOR_OF]->(n13),
# (n351)-[r436:NEIGHBOR_OF]->(n13),
# (n352)-[r437:NEIGHBOR_OF]->(n13),
# (n353)-[r438:NEIGHBOR_OF]->(n13),
# (n347)-[r439:NEIGHBOR_OF]->(n13),
# (n354)-[r440:NEIGHBOR_OF]->(n13),
# (n355)-[r441:NEIGHBOR_OF]->(n13),
# (n356)-[r442:NEIGHBOR_OF]->(n13),
# (n357)-[r443:NEIGHBOR_OF]->(n13),
# (n358)-[r444:NEIGHBOR_OF]->(n13),
# (n359)-[r445:NEIGHBOR_OF]->(n13),
# (n360)-[r446:NEIGHBOR_OF]->(n13),
# (n360)-[r447:NEIGHBOR_OF]->(n13),
# (n361)-[r448:NEIGHBOR_OF]->(n13),
# (n361)-[r449:NEIGHBOR_OF]->(n13),
# (n349)-[r450:NEIGHBOR_OF]->(n13),
# (n362)-[r451:NEIGHBOR_OF]->(n13),
# (n362)-[r452:NEIGHBOR_OF]->(n13),
# (n300)-[r453:NEIGHBOR_OF]->(n13),
# (n363)-[r454:NEIGHBOR_OF]->(n13),
# (n73)-[r455:NEIGHBOR_OF]->(n13),
# (n323)-[r456:NEIGHBOR_OF]->(n13),
# (n364)-[r457:NEIGHBOR_OF]->(n13),
# (n365)-[r458:NEIGHBOR_OF]->(n13),
# (n366)-[r459:NEIGHBOR_OF]->(n13),
# (n367)-[r460:NEIGHBOR_OF]->(n13),
# (n368)-[r461:NEIGHBOR_OF]->(n13),
# (n369)-[r462:NEIGHBOR_OF]->(n13),
# (n351)-[r463:NEIGHBOR_OF]->(n13),
# (n273)-[r464:NEIGHBOR_OF]->(n13),
# (n261)-[r465:NEIGHBOR_OF]->(n13),
# (n370)-[r466:NEIGHBOR_OF]->(n13),
# (n371)-[r467:NEIGHBOR_OF]->(n13),
# (n372)-[r468:NEIGHBOR_OF]->(n13),
# (n373)-[r469:NEIGHBOR_OF]->(n13),
# (n374)-[r470:NEIGHBOR_OF]->(n13),
# (n211)-[r471:NEIGHBOR_OF]->(n13),
# (n375)-[r472:NEIGHBOR_OF]->(n13),
# (n376)-[r473:NEIGHBOR_OF]->(n13),
# (n377)-[r474:NEIGHBOR_OF]->(n13),
# (n378)-[r475:NEIGHBOR_OF]->(n13),
# (n379)-[r476:NEIGHBOR_OF]->(n13),
# (n380)-[r477:NEIGHBOR_OF]->(n13),
# (n216)-[r478:NEIGHBOR_OF]->(n13),
# (n381)-[r479:NEIGHBOR_OF]->(n13),
# (n382)-[r480:NEIGHBOR_OF]->(n13),
# (n211)-[r481:NEIGHBOR_OF]->(n13),
# (n383)-[r482:NEIGHBOR_OF]->(n13),
# (n384)-[r483:NEIGHBOR_OF]->(n13),
# (n385)-[r484:NEIGHBOR_OF]->(n13),
# (n386)-[r485:NEIGHBOR_OF]->(n13),
# (n211)-[r486:NEIGHBOR_OF]->(n13),
# (n387)-[r487:NEIGHBOR_OF]->(n13),
# (n211)-[r488:NEIGHBOR_OF]->(n13),
# (n388)-[r489:NEIGHBOR_OF]->(n13),
# (n389)-[r490:NEIGHBOR_OF]->(n13),
# (n390)-[r491:NEIGHBOR_OF]->(n13),
# (n391)-[r492:NEIGHBOR_OF]->(n13),
# (n392)-[r493:NEIGHBOR_OF]->(n13),
# (n370)-[r494:NEIGHBOR_OF]->(n13),
# (n393)-[r495:NEIGHBOR_OF]->(n13),
# (n394)-[r496:NEIGHBOR_OF]->(n13),
# (n393)-[r497:NEIGHBOR_OF]->(n13),
# (n395)-[r498:NEIGHBOR_OF]->(n13),
# (n396)-[r499:NEIGHBOR_OF]->(n13),
# (n211)-[r500:NEIGHBOR_OF]->(n13),
# (n397)-[r501:NEIGHBOR_OF]->(n13),
# (n374)-[r502:NEIGHBOR_OF]->(n13),
# (n211)-[r503:NEIGHBOR_OF]->(n13),
# (n398)-[r504:NEIGHBOR_OF]->(n13),
# (n399)-[r505:NEIGHBOR_OF]->(n13),
# (n400)-[r506:NEIGHBOR_OF]->(n13),
# (n396)-[r507:NEIGHBOR_OF]->(n13),
# (n401)-[r508:NEIGHBOR_OF]->(n13),
# (n379)-[r509:NEIGHBOR_OF]->(n13),
# (n402)-[r510:NEIGHBOR_OF]->(n13),
# (n395)-[r511:NEIGHBOR_OF]->(n13),
# (n211)-[r512:NEIGHBOR_OF]->(n13),
# (n403)-[r513:NEIGHBOR_OF]->(n13),
# (n404)-[r514:NEIGHBOR_OF]->(n13),
# (n405)-[r515:NEIGHBOR_OF]->(n13),
# (n211)-[r516:NEIGHBOR_OF]->(n13),
# (n406)-[r517:NEIGHBOR_OF]->(n13),
# (n379)-[r518:NEIGHBOR_OF]->(n13),
# (n407)-[r519:NEIGHBOR_OF]->(n13),
# (n408)-[r520:NEIGHBOR_OF]->(n13),
# (n379)-[r521:NEIGHBOR_OF]->(n13),
# (n407)-[r522:NEIGHBOR_OF]->(n13),
# (n287)-[r523:NEIGHBOR_OF]->(n13),
# (n409)-[r524:NEIGHBOR_OF]->(n13),
# (n378)-[r525:NEIGHBOR_OF]->(n13),
# (n379)-[r526:NEIGHBOR_OF]->(n13),
# (n410)-[r527:NEIGHBOR_OF]->(n13),
# (n411)-[r528:NEIGHBOR_OF]->(n13),
# (n412)-[r529:NEIGHBOR_OF]->(n13),
# (n413)-[r530:NEIGHBOR_OF]->(n13),
# (n259)-[r531:NEIGHBOR_OF]->(n13),
# (n414)-[r532:NEIGHBOR_OF]->(n13),
# (n415)-[r533:NEIGHBOR_OF]->(n13),
# (n351)-[r534:NEIGHBOR_OF]->(n13),
# (n416)-[r535:NEIGHBOR_OF]->(n13),
# (n417)-[r536:NEIGHBOR_OF]->(n13),
# (n418)-[r537:NEIGHBOR_OF]->(n13),
# (n362)-[r538:NEIGHBOR_OF]->(n13),
# (n220)-[r539:NEIGHBOR_OF]->(n13),
# (n419)-[r540:NEIGHBOR_OF]->(n13),
# (n420)-[r541:NEIGHBOR_OF]->(n13),
# (n421)-[r542:NEIGHBOR_OF]->(n13),
# (n422)-[r543:NEIGHBOR_OF]->(n13),
# (n423)-[r544:NEIGHBOR_OF]->(n13),
# (n424)-[r545:NEIGHBOR_OF]->(n13),
# (n425)-[r546:NEIGHBOR_OF]->(n13),
# (n426)-[r547:NEIGHBOR_OF]->(n13),
# (n427)-[r548:NEIGHBOR_OF]->(n13),
# (n428)-[r549:NEIGHBOR_OF]->(n13),
# (n429)-[r550:NEIGHBOR_OF]->(n13),
# (n223)-[r551:NEIGHBOR_OF]->(n13),
# (n430)-[r552:NEIGHBOR_OF]->(n13),
# (n431)-[r553:NEIGHBOR_OF]->(n13),
# (n432)-[r554:NEIGHBOR_OF]->(n13),
# (n433)-[r555:NEIGHBOR_OF]->(n13),
# (n236)-[r556:NEIGHBOR_OF]->(n13),
# (n237)-[r557:NEIGHBOR_OF]->(n13),
# (n434)-[r558:NEIGHBOR_OF]->(n13),
# (n435)-[r559:NEIGHBOR_OF]->(n13),
# (n434)-[r560:NEIGHBOR_OF]->(n13),
# (n240)-[r561:NEIGHBOR_OF]->(n13),
# (n240)-[r562:NEIGHBOR_OF]->(n13),
# (n241)-[r563:NEIGHBOR_OF]->(n13),
# (n242)-[r564:NEIGHBOR_OF]->(n13),
# (n243)-[r565:NEIGHBOR_OF]->(n13),
# (n244)-[r566:NEIGHBOR_OF]->(n13),
# (n245)-[r567:NEIGHBOR_OF]->(n13),
# (n246)-[r568:NEIGHBOR_OF]->(n13),
# (n247)-[r569:NEIGHBOR_OF]->(n13),
# (n248)-[r570:NEIGHBOR_OF]->(n13),
# (n249)-[r571:NEIGHBOR_OF]->(n13),
# (n436)-[r572:NEIGHBOR_OF]->(n13),
# (n437)-[r573:NEIGHBOR_OF]->(n13),
# (n249)-[r574:NEIGHBOR_OF]->(n13),
# (n252)-[r575:NEIGHBOR_OF]->(n13),
# (n244)-[r576:NEIGHBOR_OF]->(n13),
# (n253)-[r577:NEIGHBOR_OF]->(n13),
# ;

# %%
############################################################## Do by above method #########################################################

# %%
st = "CREATE "

for h in bfs_queue:
  st+="(n"+str(h.id)+":NODE"+str(h.label)+"{link:'"+h.link+"'"+"}"+"),"+"\n"
st = st.rstrip(",")
st+="\n"
#print(st)
rel = 0
for n in bfs_queue:
  for nn in n.neighbours:
    rel+=1
    st+="(n"+str(nn.id)+")"+"-[r"+str(rel)+":NEIGHBOR_OF]->"+"(n"+str(n.id)+"),"+"\n"
st = st.rstrip(",")
st+=";"
print(st)
# Out:
# CREATE (n1:NODE3{link:'https://en.wikipedia.org/wiki/Antiderivative'}),
# (n2:NODE3{link:'https://en.wikipedia.org/wiki/Hyperbola'}),
# (n3:NODE3{link:'https://en.wikipedia.org/wiki/Area_under_the_curve_(pharmacokinetics)'}),
# (n4:NODE1{link:'https://en.wikipedia.org/wiki/Vector_(mathematics_and_physics)'}),
# (n5:NODE2{link:'https://en.wikipedia.org/wiki/Parabola'}),
# (n6:NODE1{link:'https://en.wikipedia.org/wiki/Logarithm'}),
# (n7:NODE1{link:'https://en.wikipedia.org/wiki/Harmonic_progression'}),
# (n8:NODE1{link:'https://en.wikipedia.org/wiki/De_Morgan%27s_laws'}),
# (n9:NODE1{link:'https://en.wikipedia.org/wiki/Even_and_odd_functions'}),
# (n10:NODE1{link:'https://en.wikipedia.org/wiki/Floor_and_ceiling_functions'}),
# (n11:NODE2{link:'https://en.wikipedia.org/wiki/Transpose'}),
# (n12:NODE1{link:'https://en.wikipedia.org/wiki/Chord_(geometry)'}),
# (n13:NODE3{link:'https://en.wikipedia.org/wiki/Inverse_trigonometric_functions'}),
# (n14:NODE2{link:'https://en.wikipedia.org/wiki/Parametric_equation'}),
# (n15:NODE2{link:'https://en.wikipedia.org/wiki/Director_circle'}),
# (n16:NODE2{link:'https://en.wikipedia.org/wiki/Coplanarity'}),
# (n17:NODE1{link:'https://en.wikipedia.org/wiki/Centroid'}),
# (n18:NODE3{link:'https://en.wikipedia.org/wiki/Altitude_(triangle)'}),
# (n19:NODE3{link:'https://en.wikipedia.org/wiki/Function_composition'}),
# (n20:NODE2{link:'https://en.wikipedia.org/wiki/Periodic_function'}),
# (n21:NODE3{link:'https://en.wikipedia.org/wiki/Dihedral_angle'}),
# (n22:NODE0{link:'https://en.wikipedia.org/wiki/Diophantine_geometry'}),
# (n23:NODE0{link:'https://en.wikipedia.org/wiki/Sampling_(statistics)#Simple_random_sampling'}),
# (n24:NODE0{link:'https://en.wikipedia.org/wiki/Minimax'}),
# (n25:NODE0{link:'https://en.wikipedia.org/wiki/Quantile_function'}),
# (n26:NODE0{link:'https://en.wikipedia.org/wiki/Karl_Weierstrass'}),
# (n27:NODE0{link:'https://en.wikipedia.org/wiki/Augustin-Louis_Cauchy'}),
# (n28:NODE1{link:'https://en.wikipedia.org//wiki/Vector_(disambiguation)'}),
# (n29:NODE1{link:'https://en.wikipedia.org//wiki/Wikipedia:Manual_of_Style/Lead_section'}),
# (n30:NODE1{link:'https://en.wikipedia.org//wiki/Help:Maintenance_template_removal'}),
# (n31:NODE1{link:'https://en.wikipedia.org//wiki/Mathematics'}),
# (n32:NODE1{link:'https://en.wikipedia.org//wiki/Physics'}),
# (n33:NODE1{link:'https://en.wikipedia.org//wiki/Vector_space'}),
# (n34:NODE1{link:'https://en.wikipedia.org//wiki/Euclidean_vector'}),
# (n35:NODE1{link:'https://en.wikipedia.org//wiki/Ray_(geometry)'}),
# (n36:NODE1{link:'https://en.wikipedia.org//wiki/Vector_algebra'}),
# (n37:NODE2{link:'https://en.wikipedia.org//wiki/Linear_algebra'}),
# (n38:NODE1{link:'https://en.wikipedia.org//wiki/Dimension'}),
# (n39:NODE1{link:'https://en.wikipedia.org//wiki/Geometry'}),
# (n40:NODE1{link:'https://en.wikipedia.org//wiki/Mechanics'}),
# (n41:NODE1{link:'https://en.wikipedia.org//wiki/Latin'}),
# (n42:NODE1{link:'https://en.wikipedia.org//wiki/Euclidean_space'}),
# (n43:NODE1{link:'https://en.wikipedia.org//wiki/Spatial_vector'}),
# (n44:NODE1{link:'https://en.wikipedia.org//wiki/Vector_addition'}),
# (n45:NODE1{link:'https://en.wikipedia.org//wiki/Scalar_multiplication'}),
# (n46:NODE1{link:'https://en.wikipedia.org//wiki/Real_number'}),
# (n47:NODE1{link:'https://en.wikipedia.org//wiki/File:Vector_from_A_to_B.svg'}),
# (n48:NODE1{link:'https://en.wikipedia.org//wiki/Engineering'}),
# (n49:NODE1{link:'https://en.wikipedia.org//wiki/Magnitude_(mathematics)'}),
# (n50:NODE1{link:'https://en.wikipedia.org//wiki/Euclidean_norm'}),
# (n51:NODE1{link:'https://en.wikipedia.org//wiki/Direction_(geometry)'}),
# (n52:NODE1{link:'https://en.wikipedia.org//wiki/Directed_line_segment'}),
# (n53:NODE1{link:'https://en.wikipedia.org//wiki/Displacement_(geometry)'}),
# (n54:NODE1{link:'https://en.wikipedia.org//wiki/Algebraic_operation'}),
# (n55:NODE1{link:'https://en.wikipedia.org//wiki/Addition'}),
# (n56:NODE1{link:'https://en.wikipedia.org//wiki/Subtraction'}),
# (n57:NODE1{link:'https://en.wikipedia.org//wiki/Multiplication'}),
# (n58:NODE1{link:'https://en.wikipedia.org//wiki/Additive_inverse'}),
# (n59:NODE1{link:'https://en.wikipedia.org//wiki/Commutativity'}),
# (n60:NODE1{link:'https://en.wikipedia.org//wiki/Associativity'}),
# (n61:NODE1{link:'https://en.wikipedia.org//wiki/Distributivity'}),
# (n62:NODE3{link:'https://en.wikipedia.org//wiki/Velocity'}),
# (n63:NODE3{link:'https://en.wikipedia.org//wiki/Acceleration'}),
# (n64:NODE1{link:'https://en.wikipedia.org//wiki/Force'}),
# (n65:NODE1{link:'https://en.wikipedia.org//wiki/Position_(vector)'}),
# (n66:NODE1{link:'https://en.wikipedia.org//wiki/Displacement_(vector)'}),
# (n67:NODE1{link:'https://en.wikipedia.org//wiki/Coordinate_system'}),
# (n68:NODE1{link:'https://en.wikipedia.org//wiki/Pseudovector'}),
# (n69:NODE1{link:'https://en.wikipedia.org//wiki/Tensor'}),
# (n70:NODE1{link:'https://en.wikipedia.org//wiki/File:Vector_add_scale.svg'}),
# (n71:NODE1{link:'https://en.wikipedia.org//wiki/Set_(mathematics)'}),
# (n72:NODE2{link:'https://en.wikipedia.org//wiki/Scalar_(mathematics)'}),
# (n73:NODE1{link:'https://en.wikipedia.org//wiki/Complex_number'}),
# (n74:NODE1{link:'https://en.wikipedia.org//wiki/Field_(mathematics)'}),
# (n75:NODE1{link:'https://en.wikipedia.org//wiki/Axiom'}),
# (n76:NODE1{link:'https://en.wikipedia.org//wiki/Force_vector'}),
# (n77:NODE1{link:'https://en.wikipedia.org//wiki/Three-dimensional_space'}),
# (n78:NODE3{link:'https://en.wikipedia.org//wiki/Mathematical_object'}),
# (n79:NODE1{link:'https://en.wikipedia.org//wiki/Dimension_(vector_space)'}),
# (n80:NODE0{link:'https://en.wikipedia.org//wiki/Mathematical_analysis'}),
# (n81:NODE1{link:'https://en.wikipedia.org//wiki/Function_space'}),
# (n82:NODE1{link:'https://en.wikipedia.org//wiki/Function_(mathematics)'}),
# (n83:NODE1{link:'https://en.wikipedia.org//wiki/Topology'}),
# (n84:NODE3{link:'https://en.wikipedia.org//wiki/Continuous_function'}),
# (n85:NODE1{link:'https://en.wikipedia.org//wiki/Norm_(mathematics)'}),
# (n86:NODE1{link:'https://en.wikipedia.org//wiki/Inner_product'}),
# (n87:NODE1{link:'https://en.wikipedia.org//wiki/Metric_(mathematics)'}),
# (n88:NODE1{link:'https://en.wikipedia.org//wiki/Banach_space'}),
# (n89:NODE1{link:'https://en.wikipedia.org//wiki/Hilbert_space'}),
# (n90:NODE0{link:'https://en.wikipedia.org//wiki/Analytic_geometry'}),
# (n91:NODE2{link:'https://en.wikipedia.org//wiki/Matrix_(mathematics)'}),
# (n92:NODE1{link:'https://en.wikipedia.org//wiki/Linear_equation'}),
# (n93:NODE1{link:'https://en.wikipedia.org//wiki/Giuseppe_Peano'}),
# (n94:NODE2{link:'https://en.wikipedia.org//wiki/Line_(geometry)'}),
# (n95:NODE3{link:'https://en.wikipedia.org//wiki/Plane_(geometry)'}),
# (n96:NODE1{link:'https://en.wikipedia.org//wiki/Science'}),
# (n97:NODE1{link:'https://en.wikipedia.org//wiki/System_of_linear_equations'}),
# (n98:NODE1{link:'https://en.wikipedia.org//wiki/Fourier_series'}),
# (n99:NODE1{link:'https://en.wikipedia.org//wiki/Image_compression'}),
# (n100:NODE1{link:'https://en.wikipedia.org//wiki/Partial_differential_equation'}),
# (n101:NODE1{link:'https://en.wikipedia.org//wiki/Coordinate-free'}),
# (n102:NODE1{link:'https://en.wikipedia.org//wiki/Manifold_(mathematics)'}),
# (n103:NODE0{link:'https://en.wikipedia.org//wiki/Abstract_algebra'}),
# (n104:NODE1{link:'https://en.wikipedia.org//wiki/Wikipedia:Merging'}),
# (n105:NODE1{link:'https://en.wikipedia.org//wiki/Talk:Vector_space#Merge_list_of_related_vector_concepts'}),
# (n106:NODE1{link:'https://en.wikipedia.org//wiki/Zero_vector'}),
# (n107:NODE1{link:'https://en.wikipedia.org//wiki/Additive_identity'}),
# (n108:NODE1{link:'https://en.wikipedia.org//wiki/Normed_vector_space'}),
# (n109:NODE1{link:'https://en.wikipedia.org//wiki/Euclidean_vector_space'}),
# (n110:NODE1{link:'https://en.wikipedia.org//wiki/Basis_vector'}),
# (n111:NODE2{link:'https://en.wikipedia.org//wiki/Basis_(linear_algebra)'}),
# (n112:NODE1{link:'https://en.wikipedia.org//wiki/Unit_vector'}),
# (n113:NODE1{link:'https://en.wikipedia.org//wiki/Isotropic_vector'}),
# (n114:NODE1{link:'https://en.wikipedia.org//wiki/Null_vector'}),
# (n115:NODE1{link:'https://en.wikipedia.org//wiki/Quadratic_form'}),
# (n116:NODE1{link:'https://en.wikipedia.org//wiki/Isotropic_quadratic_form'}),
# (n117:NODE1{link:'https://en.wikipedia.org//wiki/Row_and_column_vectors'}),
# (n118:NODE1{link:'https://en.wikipedia.org//wiki/Coordinate_vector'}),
# (n119:NODE1{link:'https://en.wikipedia.org//wiki/Tuple'}),
# (n120:NODE1{link:'https://en.wikipedia.org//wiki/Coordinates'}),
# (n121:NODE1{link:'https://en.wikipedia.org//wiki/Displacement_vector'}),
# (n122:NODE1{link:'https://en.wikipedia.org//wiki/Translation_(geometry)'}),
# (n123:NODE1{link:'https://en.wikipedia.org//wiki/Position_vector'}),
# (n124:NODE1{link:'https://en.wikipedia.org//wiki/Affine_space'}),
# (n125:NODE1{link:'https://en.wikipedia.org//wiki/Velocity_vector'}),
# (n126:NODE1{link:'https://en.wikipedia.org//wiki/Covector'}),
# (n127:NODE1{link:'https://en.wikipedia.org//wiki/Dual_space'}),
# (n128:NODE1{link:'https://en.wikipedia.org//wiki/Inner_product_space'}),
# (n129:NODE1{link:'https://en.wikipedia.org//wiki/Tangent_vector'}),
# (n130:NODE1{link:'https://en.wikipedia.org//wiki/Tangent_space'}),
# (n131:NODE2{link:'https://en.wikipedia.org//wiki/Curve'}),
# (n132:NODE1{link:'https://en.wikipedia.org//wiki/Surface_(mathematics)'}),
# (n133:NODE1{link:'https://en.wikipedia.org//wiki/Differential_manifold'}),
# (n134:NODE1{link:'https://en.wikipedia.org//wiki/Normal_vector'}),
# (n135:NODE3{link:'https://en.wikipedia.org//wiki/Gradient'}),
# (n136:NODE1{link:'https://en.wikipedia.org//wiki/Function_of_several_real_variables'}),
# (n137:NODE1{link:'https://en.wikipedia.org//wiki/Scalar_field'}),
# (n138:NODE1{link:'https://en.wikipedia.org//wiki/Level_curve'}),
# (n139:NODE1{link:'https://en.wikipedia.org//wiki/Four-vector'}),
# (n140:NODE3{link:'https://en.wikipedia.org//wiki/Theory_of_relativity'}),
# (n141:NODE1{link:'https://en.wikipedia.org//wiki/Minkowski_space'}),
# (n142:NODE1{link:'https://en.wikipedia.org//wiki/Algebra_over_a_field'}),
# (n143:NODE1{link:'https://en.wikipedia.org//wiki/Vector_quaternion'}),
# (n144:NODE1{link:'https://en.wikipedia.org//wiki/Quaternion'}),
# (n145:NODE2{link:'https://en.wikipedia.org//wiki/Multivector'}),
# (n146:NODE1{link:'https://en.wikipedia.org//wiki/P-vector'}),
# (n147:NODE1{link:'https://en.wikipedia.org//wiki/Exterior_algebra'}),
# (n148:NODE1{link:'https://en.wikipedia.org//wiki/Spinor'}),
# (n149:NODE1{link:'https://en.wikipedia.org//wiki/Rotation_vector'}),
# (n150:NODE1{link:'https://en.wikipedia.org//wiki/Closed_curve'}),
# (n151:NODE1{link:'https://en.wikipedia.org//wiki/Manifold'}),
# (n152:NODE1{link:'https://en.wikipedia.org//wiki/Orientable_manifold'}),
# (n153:NODE1{link:'https://en.wikipedia.org//wiki/Clifford_algebra'}),
# (n154:NODE1{link:'https://en.wikipedia.org//wiki/Witt_vector'}),
# (n155:NODE1{link:'https://en.wikipedia.org//wiki/Algebra_over_a_ring'}),
# (n156:NODE1{link:'https://en.wikipedia.org//wiki/Carry_(arithmetic)'}),
# (n157:NODE1{link:'https://en.wikipedia.org//wiki/P-adic_number'}),
# (n158:NODE1{link:'https://en.wikipedia.org//wiki/Wikipedia:Accuracy_dispute'}),
# (n159:NODE1{link:'https://en.wikipedia.org//wiki/Talk:Vector_(mathematics_and_physics)#Dispute'}),
# (n160:NODE1{link:'https://en.wikipedia.org//wiki/Wikipedia:Reliable_sources'}),
# (n161:NODE1{link:'https://en.wikipedia.org//wiki/Wikipedia:Disputed_statement'}),
# (n162:NODE1{link:'https://en.wikipedia.org//wiki/Talk:Vector_(mathematics_and_physics)#Tuples_that_aren’t_really_vectors?'}),
# (n163:NODE1{link:'https://en.wikipedia.org//wiki/Rotation_(geometry)'}),
# (n164:NODE1{link:'https://en.wikipedia.org//wiki/Burgers_vector'}),
# (n165:NODE1{link:'https://en.wikipedia.org//wiki/Interval_vector'}),
# (n166:NODE1{link:'https://en.wikipedia.org//wiki/Probability_vector'}),
# (n167:NODE1{link:'https://en.wikipedia.org//wiki/Random_vector'}),
# (n168:NODE1{link:'https://en.wikipedia.org//wiki/Multivariate_random_variable'}),
# (n169:NODE0{link:'https://en.wikipedia.org//wiki/Statistics'}),
# (n170:NODE1{link:'https://en.wikipedia.org//wiki/Random_variable'}),
# (n171:NODE1{link:'https://en.wikipedia.org//wiki/Correlated'}),
# (n172:NODE1{link:'https://en.wikipedia.org//wiki/Logical_matrix#Logical_vectors'}),
# (n173:NODE1{link:'https://en.wikipedia.org//wiki/Boolean_data_type'}),
# (n174:NODE1{link:'https://en.wikipedia.org//wiki/Graded_vector_space'}),
# (n175:NODE1{link:'https://en.wikipedia.org//wiki/Ordered_vector_space'}),
# (n176:NODE1{link:'https://en.wikipedia.org//wiki/Super_vector_space'}),
# (n177:NODE1{link:'https://en.wikipedia.org//wiki/Symplectic_vector_space'}),
# (n178:NODE1{link:'https://en.wikipedia.org//wiki/Topological_vector_space'}),
# (n179:NODE1{link:'https://en.wikipedia.org//wiki/Vector_field'}),
# (n180:NODE1{link:'https://en.wikipedia.org//wiki/Vector-valued_function'}),
# (n181:NODE1{link:'https://en.wikipedia.org//wiki/Conservative_vector_field'}),
# (n182:NODE1{link:'https://en.wikipedia.org//wiki/Hamiltonian_vector_field'}),
# (n183:NODE1{link:'https://en.wikipedia.org//wiki/Killing_vector_field'}),
# (n184:NODE1{link:'https://en.wikipedia.org//wiki/Solenoidal_vector_field'}),
# (n185:NODE1{link:'https://en.wikipedia.org//wiki/Vector_potential'}),
# (n186:NODE1{link:'https://en.wikipedia.org//wiki/Vector_flow'}),
# (n187:NODE1{link:'https://en.wikipedia.org//wiki/Ricci_calculus'}),
# (n188:NODE1{link:'https://en.wikipedia.org//wiki/Vector_Analysis_(Gibbs/Wilson)'}),
# (n189:NODE1{link:'https://en.wikipedia.org//wiki/Edwin_Bidwell_Wilson'}),
# (n190:NODE1{link:'https://en.wikipedia.org//wiki/Vector_bundle'}),
# (n191:NODE3{link:'https://en.wikipedia.org//wiki/Vector_calculus'}),
# (n192:NODE1{link:'https://en.wikipedia.org//wiki/Vector_differential'}),
# (n193:NODE1{link:'https://en.wikipedia.org//wiki/Vector_Laplacian'}),
# (n194:NODE1{link:'https://en.wikipedia.org//wiki/Vector_notation'}),
# (n195:NODE1{link:'https://en.wikipedia.org//wiki/Vector_operator'}),
# (n196:NODE1{link:'https://en.wikipedia.org//wiki/Vector_product'}),
# (n197:NODE2{link:'https://en.wikipedia.org//wiki/Vector_projection'}),
# (n198:NODE1{link:'https://en.wikipedia.org//wiki/Codomain'}),
# (n199:NODE1{link:'https://en.wikipedia.org//wiki/Vectorization_(mathematics)'}),
# (n200:NODE1{link:'https://en.wikipedia.org//wiki/Vector_autoregression'}),
# (n201:NODE1{link:'https://en.wikipedia.org//wiki/Vector_boson'}),
# (n202:NODE1{link:'https://en.wikipedia.org//wiki/Vector_measure'}),
# (n203:NODE1{link:'https://en.wikipedia.org//wiki/Vector_meson'}),
# (n204:NODE1{link:'https://en.wikipedia.org//wiki/Vector_quantization'}),
# (n205:NODE1{link:'https://en.wikipedia.org//wiki/Vector_soliton'}),
# (n206:NODE1{link:'https://en.wikipedia.org//wiki/Vector_synthesis'}),
# (n207:NODE3{link:'https://en.wikipedia.org//wiki/Category:Harv_and_Sfn_template_errors'}),
# (n208:NODE1{link:'https://en.wikipedia.org//wiki/Perfect_participle'}),
# (n209:NODE1{link:'https://en.wikipedia.org//wiki/Oxford_English_Dictionary'}),
# (n210:NODE1{link:'https://en.wikipedia.org//wiki/Oxford_University_Press'}),
# (n211:NODE1{link:'https://en.wikipedia.org//wiki/ISBN_(identifier)'}),
# (n212:NODE1{link:'https://en.wikipedia.org//wiki/Special:BookSources/9780195219425'}),
# (n213:NODE1{link:'https://en.wikipedia.org//wiki/Special:BookSources/1-55369-133-4'}),
# (n214:NODE1{link:'https://en.wikipedia.org//wiki/MIT_Press'}),
# (n215:NODE1{link:'https://en.wikipedia.org//wiki/Special:BookSources/978-0-262-59020-4'}),
# (n216:NODE1{link:'https://en.wikipedia.org//wiki/Encyclopedia_of_Mathematics'}),
# (n217:NODE1{link:'https://en.wikipedia.org//wiki/European_Mathematical_Society'}),
# (n218:NODE1{link:'https://en.wikipedia.org//wiki/Daniel_Pedoe'}),
# (n219:NODE1{link:'https://en.wikipedia.org//wiki/Special:BookSources/0-486-65812-0'}),
# (n220:NODE1{link:'https://en.wikipedia.org//wiki/Help:Category'}),
# (n221:NODE1{link:'https://en.wikipedia.org//wiki/Category:Vectors_(mathematics_and_physics)'}),
# (n222:NODE3{link:'https://en.wikipedia.org//wiki/Category:Harv_and_Sfn_no-target_errors'}),
# (n223:NODE1{link:'https://en.wikipedia.org//wiki/Category:Articles_with_short_description'}),
# (n224:NODE1{link:'https://en.wikipedia.org//wiki/Category:Short_description_matches_Wikidata'}),
# (n225:NODE1{link:'https://en.wikipedia.org//wiki/Category:Wikipedia_introduction_cleanup_from_November_2021'}),
# (n226:NODE1{link:'https://en.wikipedia.org//wiki/Category:All_pages_needing_cleanup'}),
# (n227:NODE1{link:'https://en.wikipedia.org//wiki/Category:Articles_covered_by_WikiProject_Wikify_from_November_2021'}),
# (n228:NODE1{link:'https://en.wikipedia.org//wiki/Category:All_articles_covered_by_WikiProject_Wikify'}),
# (n229:NODE1{link:'https://en.wikipedia.org//wiki/Category:Articles_with_excerpts'}),
# (n230:NODE1{link:'https://en.wikipedia.org//wiki/Category:Articles_to_be_merged_from_November_2021'}),
# (n231:NODE1{link:'https://en.wikipedia.org//wiki/Category:All_articles_to_be_merged'}),
# (n232:NODE1{link:'https://en.wikipedia.org//wiki/Category:Accuracy_disputes_from_November_2021'}),
# (n233:NODE1{link:'https://en.wikipedia.org//wiki/Category:All_accuracy_disputes'}),
# (n234:NODE1{link:'https://en.wikipedia.org//wiki/Category:Articles_with_disputed_statements_from_November_2021'}),
# (n235:NODE1{link:'https://en.wikipedia.org//wiki/Category:Broad-concept_articles'}),
# (n236:NODE1{link:'https://en.wikipedia.org//wiki/Special:MyTalk'}),
# (n237:NODE1{link:'https://en.wikipedia.org//wiki/Special:MyContributions'}),
# (n238:NODE1{link:'https://en.wikipedia.org//wiki/Vector_(mathematics_and_physics)'}),
# (n239:NODE1{link:'https://en.wikipedia.org//wiki/Talk:Vector_(mathematics_and_physics)'}),
# (n240:NODE1{link:'https://en.wikipedia.org//wiki/Main_Page'}),
# (n241:NODE1{link:'https://en.wikipedia.org//wiki/Wikipedia:Contents'}),
# (n242:NODE1{link:'https://en.wikipedia.org//wiki/Portal:Current_events'}),
# (n243:NODE1{link:'https://en.wikipedia.org//wiki/Special:Random'}),
# (n244:NODE1{link:'https://en.wikipedia.org//wiki/Wikipedia:About'}),
# (n245:NODE1{link:'https://en.wikipedia.org//wiki/Help:Contents'}),
# (n246:NODE1{link:'https://en.wikipedia.org//wiki/Help:Introduction'}),
# (n247:NODE1{link:'https://en.wikipedia.org//wiki/Wikipedia:Community_portal'}),
# (n248:NODE1{link:'https://en.wikipedia.org//wiki/Special:RecentChanges'}),
# (n249:NODE1{link:'https://en.wikipedia.org//wiki/Wikipedia:File_Upload_Wizard'}),
# (n250:NODE1{link:'https://en.wikipedia.org//wiki/Special:WhatLinksHere/Vector_(mathematics_and_physics)'}),
# (n251:NODE1{link:'https://en.wikipedia.org//wiki/Special:RecentChangesLinked/Vector_(mathematics_and_physics)'}),
# (n252:NODE1{link:'https://en.wikipedia.org//wiki/Special:SpecialPages'}),
# (n253:NODE1{link:'https://en.wikipedia.org//wiki/Wikipedia:General_disclaimer'}),
# (n254:NODE3{link:'https://en.wikipedia.org//wiki/Trigonometry'}),
# (n255:NODE3{link:'https://en.wikipedia.org//wiki/File:Sinus_und_Kosinus_am_Einheitskreis_1.svg'}),
# (n256:NODE3{link:'https://en.wikipedia.org//wiki/Outline_of_trigonometry'}),
# (n257:NODE3{link:'https://en.wikipedia.org//wiki/History_of_trigonometry'}),
# (n258:NODE3{link:'https://en.wikipedia.org//wiki/Uses_of_trigonometry'}),
# (n259:NODE3{link:'https://en.wikipedia.org//wiki/Trigonometric_functions'}),
# (n260:NODE3{link:'https://en.wikipedia.org//wiki/Generalized_trigonometry'}),
# (n261:NODE3{link:'https://en.wikipedia.org//wiki/List_of_trigonometric_identities'}),
# (n262:NODE3{link:'https://en.wikipedia.org//wiki/Exact_trigonometric_values'}),
# (n263:NODE3{link:'https://en.wikipedia.org//wiki/Trigonometric_tables'}),
# (n264:NODE3{link:'https://en.wikipedia.org//wiki/Unit_circle'}),
# (n265:NODE3{link:'https://en.wikipedia.org//wiki/Law_of_sines'}),
# (n266:NODE3{link:'https://en.wikipedia.org//wiki/Law_of_cosines'}),
# (n267:NODE3{link:'https://en.wikipedia.org//wiki/Law_of_tangents'}),
# (n268:NODE3{link:'https://en.wikipedia.org//wiki/Law_of_cotangents'}),
# (n269:NODE3{link:'https://en.wikipedia.org//wiki/Pythagorean_theorem'}),
# (n270:NODE3{link:'https://en.wikipedia.org//wiki/Calculus'}),
# (n271:NODE3{link:'https://en.wikipedia.org//wiki/Trigonometric_substitution'}),
# (n272:NODE3{link:'https://en.wikipedia.org//wiki/List_of_integrals_of_trigonometric_functions'}),
# (n273:NODE3{link:'https://en.wikipedia.org//wiki/List_of_integrals_of_inverse_trigonometric_functions'}),
# (n274:NODE3{link:'https://en.wikipedia.org//wiki/Differentiation_of_trigonometric_functions'}),
# (n275:NODE3{link:'https://en.wikipedia.org//wiki/Template:Trigonometry'}),
# (n276:NODE3{link:'https://en.wikipedia.org//wiki/Template_talk:Trigonometry'}),
# (n277:NODE3{link:'https://en.wikipedia.org//wiki/Inverse_function'}),
# (n278:NODE3{link:'https://en.wikipedia.org//wiki/Domain_of_a_function'}),
# (n279:NODE1{link:'https://en.wikipedia.org//wiki/Sine'}),
# (n280:NODE3{link:'https://en.wikipedia.org//wiki/Cosine'}),
# (n281:NODE3{link:'https://en.wikipedia.org//wiki/Tangent_(trigonometry)'}),
# (n282:NODE3{link:'https://en.wikipedia.org//wiki/Cotangent'}),
# (n283:NODE3{link:'https://en.wikipedia.org//wiki/Secant_(trigonometry)'}),
# (n284:NODE3{link:'https://en.wikipedia.org//wiki/Cosecant'}),
# (n285:NODE3{link:'https://en.wikipedia.org//wiki/Navigation'}),
# (n286:NODE3{link:'https://en.wikipedia.org//wiki/Trigonometric_functions#Notation'}),
# (n287:NODE3{link:'https://en.wikipedia.org//wiki/Wikipedia:Citation_needed'}),
# (n288:NODE3{link:'https://en.wikipedia.org//wiki/John_Herschel'}),
# (n289:NODE3{link:'https://en.wikipedia.org//wiki/Iterated_function#Definition'}),
# (n290:NODE3{link:'https://en.wikipedia.org//wiki/Multivalued_function'}),
# (n291:NODE3{link:'https://en.wikipedia.org//wiki/Multiplicative_inverse'}),
# (n292:NODE3{link:'https://en.wikipedia.org//wiki/UPPERCASE'}),
# (n293:NODE3{link:'https://en.wikipedia.org//wiki/ISO_80000-2#Function_symbols_and_definitions'}),
# (n294:NODE3{link:'https://en.wikipedia.org//wiki/One-to-one_function'}),
# (n295:NODE3{link:'https://en.wikipedia.org//wiki/Range_of_a_function'}),
# (n296:NODE3{link:'https://en.wikipedia.org//wiki/Subset'}),
# (n297:NODE2{link:'https://en.wikipedia.org//wiki/Square_root'}),
# (n298:NODE3{link:'https://en.wikipedia.org//wiki/Countably_infinite'}),
# (n299:NODE1{link:'https://en.wikipedia.org//wiki/Principal_branch'}),
# (n300:NODE3{link:'https://en.wikipedia.org//wiki/Principal_value'}),
# (n301:NODE3{link:'https://en.wikipedia.org//wiki/Radian'}),
# (n302:NODE1{link:'https://en.wikipedia.org//wiki/Degree_(angle)'}),
# (n303:NODE3{link:'https://en.wikipedia.org//wiki/Image_of_a_function'}),
# (n304:NODE3{link:'https://en.wikipedia.org//wiki/Radians'}),
# (n305:NODE1{link:'https://en.wikipedia.org//wiki/Integer'}),
# (n306:NODE3{link:'https://en.wikipedia.org//wiki/Set_subtraction'}),
# (n307:NODE3{link:'https://en.wikipedia.org//wiki/Minkowski_sum'}),
# (n308:NODE3{link:'https://en.wikipedia.org//wiki/Odd_integer'}),
# (n309:NODE3{link:'https://en.wikipedia.org//wiki/Well-defined'}),
# (n310:NODE3{link:'https://en.wikipedia.org//wiki/Logical_equality'}),
# (n311:NODE3{link:'https://en.wikipedia.org//wiki/If_and_only_if'}),
# (n312:NODE1{link:'https://en.wikipedia.org//wiki/Absolute_value'}),
# (n313:NODE1{link:'https://en.wikipedia.org//wiki/Sign_function'}),
# (n314:NODE3{link:'https://en.wikipedia.org//wiki/File:Trigonometric_functions_and_inverse3.svg'}),
# (n315:NODE3{link:'https://en.wikipedia.org//wiki/File:Trigonometric_functions_and_inverse.svg'}),
# (n316:NODE3{link:'https://en.wikipedia.org//wiki/File:Trigonometric_functions_and_inverse2.svg'}),
# (n317:NODE3{link:'https://en.wikipedia.org//wiki/File:Trigonometric_functions_and_inverse4.svg'}),
# (n318:NODE3{link:'https://en.wikipedia.org//wiki/File:Trigonometric_functions_and_inverse6.svg'}),
# (n319:NODE3{link:'https://en.wikipedia.org//wiki/File:Trigonometric_functions_and_inverse5.svg'}),
# (n320:NODE3{link:'https://en.wikipedia.org//wiki/File:Arcsine_Arccosine.svg'}),
# (n321:NODE3{link:'https://en.wikipedia.org//wiki/File:Arctangent_Arccotangent.svg'}),
# (n322:NODE3{link:'https://en.wikipedia.org//wiki/File:Arcsecant_Arccosecant.svg'}),
# (n323:NODE3{link:'https://en.wikipedia.org//wiki/Tangent_half-angle_formula'}),
# (n324:NODE3{link:'https://en.wikipedia.org//wiki/Angle_sum_and_difference_identities'}),
# (n325:NODE3{link:'https://en.wikipedia.org//wiki/Derivative'}),
# (n326:NODE3{link:'https://en.wikipedia.org//wiki/Improper_integral'}),
# (n327:NODE3{link:'https://en.wikipedia.org//wiki/Power_series'}),
# (n328:NODE3{link:'https://en.wikipedia.org//wiki/Binomial_series'}),
# (n329:NODE3{link:'https://en.wikipedia.org//wiki/Geometric_series'}),
# (n330:NODE3{link:'https://en.wikipedia.org//wiki/Leibniz_series'}),
# (n331:NODE0{link:'https://en.wikipedia.org//wiki/Leonhard_Euler'}),
# (n332:NODE3{link:'https://en.wikipedia.org//wiki/Taylor_series'}),
# (n333:NODE3{link:'https://en.wikipedia.org//wiki/Empty_product'}),
# (n334:NODE1{link:'https://en.wikipedia.org//wiki/Imaginary_unit'}),
# (n335:NODE3{link:'https://en.wikipedia.org//wiki/Generalized_continued_fraction'}),
# (n336:NODE1{link:'https://en.wikipedia.org//wiki/Carl_Friedrich_Gauss'}),
# (n337:NODE3{link:'https://en.wikipedia.org//wiki/Gaussian_hypergeometric_series'}),
# (n338:NODE3{link:'https://en.wikipedia.org//wiki/Inverse_hyperbolic_functions#Logarithmic_representation'}),
# (n339:NODE3{link:'https://en.wikipedia.org//wiki/Integration_by_parts'}),
# (n340:NODE3{link:'https://en.wikipedia.org//wiki/Integration_by_substitution'}),
# (n341:NODE3{link:'https://en.wikipedia.org//wiki/File:Riemann_surface_for_Arg_of_ArcTan_of_x.svg'}),
# (n342:NODE3{link:'https://en.wikipedia.org//wiki/Riemann_surface'}),
# (n343:NODE3{link:'https://en.wikipedia.org//wiki/Analytic_function'}),
# (n344:NODE3{link:'https://en.wikipedia.org//wiki/Branch_point'}),
# (n345:NODE1{link:'https://en.wikipedia.org//wiki/Branch_cut'}),
# (n346:NODE1{link:'https://en.wikipedia.org//wiki/Complex_logarithm'}),
# (n347:NODE3{link:'https://en.wikipedia.org//wiki/Complex_plane'}),
# (n348:NODE1{link:'https://en.wikipedia.org//wiki/Euler%27s_formula'}),
# (n349:NODE3{link:'https://en.wikipedia.org//wiki/Pythagorean_Theorem'}),
# (n350:NODE3{link:'https://en.wikipedia.org//wiki/Hyperbolic_angle'}),
# (n351:NODE3{link:'https://en.wikipedia.org//wiki/Inverse_hyperbolic_functions'}),
# (n352:NODE3{link:'https://en.wikipedia.org//wiki/Trigonometric_functions#Relationship_to_exponential_function_(Euler's_formula)'}),
# (n353:NODE3{link:'https://en.wikipedia.org//wiki/Domain_coloring'}),
# (n354:NODE3{link:'https://en.wikipedia.org//wiki/File:Complex_arcsin.jpg'}),
# (n355:NODE3{link:'https://en.wikipedia.org//wiki/File:Complex_arccos.jpg'}),
# (n356:NODE3{link:'https://en.wikipedia.org//wiki/File:Complex_arctan.jpg'}),
# (n357:NODE3{link:'https://en.wikipedia.org//wiki/File:Complex_ArcCot.jpg'}),
# (n358:NODE3{link:'https://en.wikipedia.org//wiki/File:Complex_ArcSec.jpg'}),
# (n359:NODE3{link:'https://en.wikipedia.org//wiki/File:Complex_ArcCsc.jpg'}),
# (n360:NODE3{link:'https://en.wikipedia.org//wiki/File:Trigonometry_triangle.svg'}),
# (n361:NODE3{link:'https://en.wikipedia.org//wiki/Right_triangle'}),
# (n362:NODE3{link:'https://en.wikipedia.org//wiki/Atan2'}),
# (n363:NODE3{link:'https://en.wikipedia.org//wiki/Arg_(mathematics)'}),
# (n364:NODE3{link:'https://en.wikipedia.org//wiki/ISO_standard'}),
# (n365:NODE1{link:'https://en.wikipedia.org//wiki/C_(programming_language)'}),
# (n366:NODE3{link:'https://en.wikipedia.org//wiki/Atan2#Realizations_of_the_function_in_common_programming_languages'}),
# (n367:NODE3{link:'https://en.wikipedia.org//wiki/Ill-conditioned'}),
# (n368:NODE3{link:'https://en.wikipedia.org//wiki/Inverse_exsecant'}),
# (n369:NODE3{link:'https://en.wikipedia.org//wiki/Inverse_versine'}),
# (n370:NODE1{link:'https://en.wikipedia.org//wiki/Trigonometric_function'}),
# (n371:NODE3{link:'https://en.wikipedia.org//wiki/Trigonometric_functions_of_matrices'}),
# (n372:NODE1{link:'https://en.wikipedia.org//wiki/Milton_Abramowitz'}),
# (n373:NODE1{link:'https://en.wikipedia.org//wiki/Irene_Stegun'}),
# (n374:NODE1{link:'https://en.wikipedia.org//wiki/Dover_Publications'}),
# (n375:NODE1{link:'https://en.wikipedia.org//wiki/Special:BookSources/978-0-486-61272-0'}),
# (n376:NODE3{link:'https://en.wikipedia.org//wiki/Nuclear_Instruments_and_Methods'}),
# (n377:NODE3{link:'https://en.wikipedia.org//wiki/ScienceDirect'}),
# (n378:NODE1{link:'https://en.wikipedia.org//wiki/Bibcode_(identifier)'}),
# (n379:NODE1{link:'https://en.wikipedia.org//wiki/Doi_(identifier)'}),
# (n380:NODE3{link:'https://en.wikipedia.org//wiki/Michiel_Hazewinkel'}),
# (n381:NODE3{link:'https://en.wikipedia.org//wiki/Kluwer_Academic_Publishers'}),
# (n382:NODE3{link:'https://en.wikipedia.org//wiki/Springer_Science_%26_Business_Media'}),
# (n383:NODE3{link:'https://en.wikipedia.org//wiki/Special:BookSources/978-155608010-4'}),
# (n384:NODE3{link:'https://en.wikipedia.org//wiki/University_of_Konstanz'}),
# (n385:NODE3{link:'https://en.wikipedia.org//wiki/Ventus_Publishing_ApS'}),
# (n386:NODE3{link:'https://en.wikipedia.org//wiki/Bookboon'}),
# (n387:NODE3{link:'https://en.wikipedia.org//wiki/Special:BookSources/978-87-7681-702-2'}),
# (n388:NODE3{link:'https://en.wikipedia.org//wiki/Special:BookSources/978-956141314-6'}),
# (n389:NODE3{link:'https://en.wikipedia.org//wiki/Henry_Holt_and_Company'}),
# (n390:NODE3{link:'https://en.wikipedia.org//wiki/Arc-sine'}),
# (n391:NODE3{link:'https://en.wikipedia.org//wiki/Anti-sine'}),
# (n392:NODE3{link:'https://en.wikipedia.org//wiki/Anti-function'}),
# (n393:NODE3{link:'https://en.wikipedia.org//wiki/Christian_Felix_Klein'}),
# (n394:NODE3{link:'https://en.wikipedia.org//wiki/J._Springer'}),
# (n395:NODE3{link:'https://en.wikipedia.org//wiki/Dover_Publications,_Inc.'}),
# (n396:NODE3{link:'https://en.wikipedia.org//wiki/The_Macmillan_Company'}),
# (n397:NODE3{link:'https://en.wikipedia.org//wiki/Special:BookSources/978-0-48643480-3'}),
# (n398:NODE3{link:'https://en.wikipedia.org//wiki/Special:BookSources/978-0-486-61348-2'}),
# (n399:NODE3{link:'https://en.wikipedia.org//wiki/The_Americana'}),
# (n400:NODE3{link:'https://en.wikipedia.org//wiki/Florian_Cajori'}),
# (n401:NODE3{link:'https://en.wikipedia.org//wiki/John_Frederick_William_Herschel'}),
# (n402:NODE3{link:'https://en.wikipedia.org//wiki/Theresa_M._Korn'}),
# (n403:NODE3{link:'https://en.wikipedia.org//wiki/Special:BookSources/978-0-486-41147-7'}),
# (n404:NODE3{link:'https://en.wikipedia.org//wiki/Lahore'}),
# (n405:NODE3{link:'https://en.wikipedia.org//wiki/A._K._Peters'}),
# (n406:NODE3{link:'https://en.wikipedia.org//wiki/Special:BookSources/978-1-56881-136-9'}),
# (n407:NODE3{link:'https://en.wikipedia.org//wiki/S2CID_(identifier)'}),
# (n408:NODE2{link:'https://en.wikipedia.org//wiki/ArXiv_(identifier)'}),
# (n409:NODE1{link:'https://en.wikipedia.org//wiki/Cambridge_University_Press'}),
# (n410:NODE1{link:'https://en.wikipedia.org//wiki/Eric_W._Weisstein'}),
# (n411:NODE1{link:'https://en.wikipedia.org//wiki/MathWorld'}),
# (n412:NODE3{link:'https://en.wikipedia.org//wiki/Template:Trigonometric_and_hyperbolic_functions'}),
# (n413:NODE3{link:'https://en.wikipedia.org//wiki/Template_talk:Trigonometric_and_hyperbolic_functions'}),
# (n414:NODE3{link:'https://en.wikipedia.org//wiki/Sine_and_cosine'}),
# (n415:NODE3{link:'https://en.wikipedia.org//wiki/Hyperbolic_functions'}),
# (n416:NODE3{link:'https://en.wikipedia.org//wiki/Versine'}),
# (n417:NODE3{link:'https://en.wikipedia.org//wiki/Exsecant'}),
# (n418:NODE3{link:'https://en.wikipedia.org//wiki/Jy%C4%81,_koti-jy%C4%81_and_utkrama-jy%C4%81'}),
# (n419:NODE3{link:'https://en.wikipedia.org//wiki/Category:Inverse_trigonometric_functions'}),
# (n420:NODE3{link:'https://en.wikipedia.org//wiki/Category:Trigonometry'}),
# (n421:NODE1{link:'https://en.wikipedia.org//wiki/Category:Elementary_special_functions'}),
# (n422:NODE3{link:'https://en.wikipedia.org//wiki/Category:Mathematical_relations'}),
# (n423:NODE3{link:'https://en.wikipedia.org//wiki/Category:Ratios'}),
# (n424:NODE3{link:'https://en.wikipedia.org//wiki/Category:Dimensionless_numbers'}),
# (n425:NODE3{link:'https://en.wikipedia.org//wiki/Category:CS1:_long_volume_value'}),
# (n426:NODE3{link:'https://en.wikipedia.org//wiki/Category:CS1_location_test'}),
# (n427:NODE1{link:'https://en.wikipedia.org//wiki/Category:CS1_German-language_sources_(de)'}),
# (n428:NODE1{link:'https://en.wikipedia.org//wiki/Category:All_articles_with_unsourced_statements'}),
# (n429:NODE3{link:'https://en.wikipedia.org//wiki/Category:Articles_with_unsourced_statements_from_March_2020'}),
# (n430:NODE1{link:'https://en.wikipedia.org//wiki/Category:Short_description_is_different_from_Wikidata'}),
# (n431:NODE3{link:'https://en.wikipedia.org//wiki/Category:Articles_with_unsourced_statements_from_January_2019'}),
# (n432:NODE3{link:'https://en.wikipedia.org//wiki/Category:Articles_with_unsourced_statements_from_March_2021'}),
# (n433:NODE3{link:'https://en.wikipedia.org//wiki/Category:Articles_with_unsourced_statements_from_May_2016'}),
# (n434:NODE3{link:'https://en.wikipedia.org//wiki/Inverse_trigonometric_functions'}),
# (n435:NODE3{link:'https://en.wikipedia.org//wiki/Talk:Inverse_trigonometric_functions'}),
# (n436:NODE3{link:'https://en.wikipedia.org//wiki/Special:WhatLinksHere/Inverse_trigonometric_functions'}),
# (n437:NODE3{link:'https://en.wikipedia.org//wiki/Special:RecentChangesLinked/Inverse_trigonometric_functions'}),
#
# (n28)-[r1:NEIGHBOR_OF]->(n4),
# (n29)-[r2:NEIGHBOR_OF]->(n4),
# (n29)-[r3:NEIGHBOR_OF]->(n4),
# (n30)-[r4:NEIGHBOR_OF]->(n4),
# (n31)-[r5:NEIGHBOR_OF]->(n4),
# (n32)-[r6:NEIGHBOR_OF]->(n4),
# (n33)-[r7:NEIGHBOR_OF]->(n4),
# (n34)-[r8:NEIGHBOR_OF]->(n4),
# (n35)-[r9:NEIGHBOR_OF]->(n4),
# (n36)-[r10:NEIGHBOR_OF]->(n4),
# (n33)-[r11:NEIGHBOR_OF]->(n4),
# (n37)-[r12:NEIGHBOR_OF]->(n4),
# (n38)-[r13:NEIGHBOR_OF]->(n4),
# (n39)-[r14:NEIGHBOR_OF]->(n4),
# (n40)-[r15:NEIGHBOR_OF]->(n4),
# (n41)-[r16:NEIGHBOR_OF]->(n4),
# (n42)-[r17:NEIGHBOR_OF]->(n4),
# (n43)-[r18:NEIGHBOR_OF]->(n4),
# (n44)-[r19:NEIGHBOR_OF]->(n4),
# (n45)-[r20:NEIGHBOR_OF]->(n4),
# (n46)-[r21:NEIGHBOR_OF]->(n4),
# (n34)-[r22:NEIGHBOR_OF]->(n4),
# (n34)-[r23:NEIGHBOR_OF]->(n4),
# (n47)-[r24:NEIGHBOR_OF]->(n4),
# (n47)-[r25:NEIGHBOR_OF]->(n4),
# (n31)-[r26:NEIGHBOR_OF]->(n4),
# (n32)-[r27:NEIGHBOR_OF]->(n4),
# (n48)-[r28:NEIGHBOR_OF]->(n4),
# (n34)-[r29:NEIGHBOR_OF]->(n4),
# (n49)-[r30:NEIGHBOR_OF]->(n4),
# (n50)-[r31:NEIGHBOR_OF]->(n4),
# (n51)-[r32:NEIGHBOR_OF]->(n4),
# (n36)-[r33:NEIGHBOR_OF]->(n4),
# (n35)-[r34:NEIGHBOR_OF]->(n4),
# (n52)-[r35:NEIGHBOR_OF]->(n4),
# (n53)-[r36:NEIGHBOR_OF]->(n4),
# (n54)-[r37:NEIGHBOR_OF]->(n4),
# (n46)-[r38:NEIGHBOR_OF]->(n4),
# (n55)-[r39:NEIGHBOR_OF]->(n4),
# (n56)-[r40:NEIGHBOR_OF]->(n4),
# (n57)-[r41:NEIGHBOR_OF]->(n4),
# (n58)-[r42:NEIGHBOR_OF]->(n4),
# (n59)-[r43:NEIGHBOR_OF]->(n4),
# (n60)-[r44:NEIGHBOR_OF]->(n4),
# (n61)-[r45:NEIGHBOR_OF]->(n4),
# (n42)-[r46:NEIGHBOR_OF]->(n4),
# (n33)-[r47:NEIGHBOR_OF]->(n4),
# (n32)-[r48:NEIGHBOR_OF]->(n4),
# (n62)-[r49:NEIGHBOR_OF]->(n4),
# (n63)-[r50:NEIGHBOR_OF]->(n4),
# (n64)-[r51:NEIGHBOR_OF]->(n4),
# (n65)-[r52:NEIGHBOR_OF]->(n4),
# (n66)-[r53:NEIGHBOR_OF]->(n4),
# (n67)-[r54:NEIGHBOR_OF]->(n4),
# (n68)-[r55:NEIGHBOR_OF]->(n4),
# (n69)-[r56:NEIGHBOR_OF]->(n4),
# (n33)-[r57:NEIGHBOR_OF]->(n4),
# (n33)-[r58:NEIGHBOR_OF]->(n4),
# (n70)-[r59:NEIGHBOR_OF]->(n4),
# (n70)-[r60:NEIGHBOR_OF]->(n4),
# (n31)-[r61:NEIGHBOR_OF]->(n4),
# (n32)-[r62:NEIGHBOR_OF]->(n4),
# (n48)-[r63:NEIGHBOR_OF]->(n4),
# (n33)-[r64:NEIGHBOR_OF]->(n4),
# (n71)-[r65:NEIGHBOR_OF]->(n4),
# (n44)-[r66:NEIGHBOR_OF]->(n4),
# (n45)-[r67:NEIGHBOR_OF]->(n4),
# (n72)-[r68:NEIGHBOR_OF]->(n4),
# (n46)-[r69:NEIGHBOR_OF]->(n4),
# (n73)-[r70:NEIGHBOR_OF]->(n4),
# (n74)-[r71:NEIGHBOR_OF]->(n4),
# (n75)-[r72:NEIGHBOR_OF]->(n4),
# (n34)-[r73:NEIGHBOR_OF]->(n4),
# (n32)-[r74:NEIGHBOR_OF]->(n4),
# (n64)-[r75:NEIGHBOR_OF]->(n4),
# (n76)-[r76:NEIGHBOR_OF]->(n4),
# (n39)-[r77:NEIGHBOR_OF]->(n4),
# (n77)-[r78:NEIGHBOR_OF]->(n4),
# (n78)-[r79:NEIGHBOR_OF]->(n4),
# (n37)-[r80:NEIGHBOR_OF]->(n4),
# (n79)-[r81:NEIGHBOR_OF]->(n4),
# (n80)-[r82:NEIGHBOR_OF]->(n4),
# (n81)-[r83:NEIGHBOR_OF]->(n4),
# (n82)-[r84:NEIGHBOR_OF]->(n4),
# (n83)-[r85:NEIGHBOR_OF]->(n4),
# (n84)-[r86:NEIGHBOR_OF]->(n4),
# (n85)-[r87:NEIGHBOR_OF]->(n4),
# (n86)-[r88:NEIGHBOR_OF]->(n4),
# (n87)-[r89:NEIGHBOR_OF]->(n4),
# (n88)-[r90:NEIGHBOR_OF]->(n4),
# (n89)-[r91:NEIGHBOR_OF]->(n4),
# (n90)-[r92:NEIGHBOR_OF]->(n4),
# (n91)-[r93:NEIGHBOR_OF]->(n4),
# (n92)-[r94:NEIGHBOR_OF]->(n4),
# (n93)-[r95:NEIGHBOR_OF]->(n4),
# (n42)-[r96:NEIGHBOR_OF]->(n4),
# (n94)-[r97:NEIGHBOR_OF]->(n4),
# (n95)-[r98:NEIGHBOR_OF]->(n4),
# (n31)-[r99:NEIGHBOR_OF]->(n4),
# (n96)-[r100:NEIGHBOR_OF]->(n4),
# (n48)-[r101:NEIGHBOR_OF]->(n4),
# (n97)-[r102:NEIGHBOR_OF]->(n4),
# (n98)-[r103:NEIGHBOR_OF]->(n4),
# (n99)-[r104:NEIGHBOR_OF]->(n4),
# (n100)-[r105:NEIGHBOR_OF]->(n4),
# (n101)-[r106:NEIGHBOR_OF]->(n4),
# (n69)-[r107:NEIGHBOR_OF]->(n4),
# (n102)-[r108:NEIGHBOR_OF]->(n4),
# (n103)-[r109:NEIGHBOR_OF]->(n4),
# (n104)-[r110:NEIGHBOR_OF]->(n4),
# (n33)-[r111:NEIGHBOR_OF]->(n4),
# (n105)-[r112:NEIGHBOR_OF]->(n4),
# (n106)-[r113:NEIGHBOR_OF]->(n4),
# (n107)-[r114:NEIGHBOR_OF]->(n4),
# (n108)-[r115:NEIGHBOR_OF]->(n4),
# (n109)-[r116:NEIGHBOR_OF]->(n4),
# (n110)-[r117:NEIGHBOR_OF]->(n4),
# (n111)-[r118:NEIGHBOR_OF]->(n4),
# (n112)-[r119:NEIGHBOR_OF]->(n4),
# (n85)-[r120:NEIGHBOR_OF]->(n4),
# (n34)-[r121:NEIGHBOR_OF]->(n4),
# (n113)-[r122:NEIGHBOR_OF]->(n4),
# (n114)-[r123:NEIGHBOR_OF]->(n4),
# (n115)-[r124:NEIGHBOR_OF]->(n4),
# (n116)-[r125:NEIGHBOR_OF]->(n4),
# (n117)-[r126:NEIGHBOR_OF]->(n4),
# (n117)-[r127:NEIGHBOR_OF]->(n4),
# (n118)-[r128:NEIGHBOR_OF]->(n4),
# (n119)-[r129:NEIGHBOR_OF]->(n4),
# (n120)-[r130:NEIGHBOR_OF]->(n4),
# (n111)-[r131:NEIGHBOR_OF]->(n4),
# (n74)-[r132:NEIGHBOR_OF]->(n4),
# (n121)-[r133:NEIGHBOR_OF]->(n4),
# (n122)-[r134:NEIGHBOR_OF]->(n4),
# (n123)-[r135:NEIGHBOR_OF]->(n4),
# (n42)-[r136:NEIGHBOR_OF]->(n4),
# (n124)-[r137:NEIGHBOR_OF]->(n4),
# (n125)-[r138:NEIGHBOR_OF]->(n4),
# (n68)-[r139:NEIGHBOR_OF]->(n4),
# (n126)-[r140:NEIGHBOR_OF]->(n4),
# (n127)-[r141:NEIGHBOR_OF]->(n4),
# (n128)-[r142:NEIGHBOR_OF]->(n4),
# (n129)-[r143:NEIGHBOR_OF]->(n4),
# (n130)-[r144:NEIGHBOR_OF]->(n4),
# (n131)-[r145:NEIGHBOR_OF]->(n4),
# (n132)-[r146:NEIGHBOR_OF]->(n4),
# (n133)-[r147:NEIGHBOR_OF]->(n4),
# (n134)-[r148:NEIGHBOR_OF]->(n4),
# (n135)-[r149:NEIGHBOR_OF]->(n4),
# (n136)-[r150:NEIGHBOR_OF]->(n4),
# (n137)-[r151:NEIGHBOR_OF]->(n4),
# (n138)-[r152:NEIGHBOR_OF]->(n4),
# (n139)-[r153:NEIGHBOR_OF]->(n4),
# (n140)-[r154:NEIGHBOR_OF]->(n4),
# (n141)-[r155:NEIGHBOR_OF]->(n4),
# (n142)-[r156:NEIGHBOR_OF]->(n4),
# (n143)-[r157:NEIGHBOR_OF]->(n4),
# (n144)-[r158:NEIGHBOR_OF]->(n4),
# (n145)-[r159:NEIGHBOR_OF]->(n4),
# (n146)-[r160:NEIGHBOR_OF]->(n4),
# (n147)-[r161:NEIGHBOR_OF]->(n4),
# (n148)-[r162:NEIGHBOR_OF]->(n4),
# (n149)-[r163:NEIGHBOR_OF]->(n4),
# (n150)-[r164:NEIGHBOR_OF]->(n4),
# (n151)-[r165:NEIGHBOR_OF]->(n4),
# (n152)-[r166:NEIGHBOR_OF]->(n4),
# (n153)-[r167:NEIGHBOR_OF]->(n4),
# (n154)-[r168:NEIGHBOR_OF]->(n4),
# (n155)-[r169:NEIGHBOR_OF]->(n4),
# (n156)-[r170:NEIGHBOR_OF]->(n4),
# (n157)-[r171:NEIGHBOR_OF]->(n4),
# (n158)-[r172:NEIGHBOR_OF]->(n4),
# (n159)-[r173:NEIGHBOR_OF]->(n4),
# (n160)-[r174:NEIGHBOR_OF]->(n4),
# (n30)-[r175:NEIGHBOR_OF]->(n4),
# (n119)-[r176:NEIGHBOR_OF]->(n4),
# (n45)-[r177:NEIGHBOR_OF]->(n4),
# (n161)-[r178:NEIGHBOR_OF]->(n4),
# (n162)-[r179:NEIGHBOR_OF]->(n4),
# (n149)-[r180:NEIGHBOR_OF]->(n4),
# (n34)-[r181:NEIGHBOR_OF]->(n4),
# (n163)-[r182:NEIGHBOR_OF]->(n4),
# (n164)-[r183:NEIGHBOR_OF]->(n4),
# (n165)-[r184:NEIGHBOR_OF]->(n4),
# (n166)-[r185:NEIGHBOR_OF]->(n4),
# (n167)-[r186:NEIGHBOR_OF]->(n4),
# (n168)-[r187:NEIGHBOR_OF]->(n4),
# (n169)-[r188:NEIGHBOR_OF]->(n4),
# (n46)-[r189:NEIGHBOR_OF]->(n4),
# (n170)-[r190:NEIGHBOR_OF]->(n4),
# (n171)-[r191:NEIGHBOR_OF]->(n4),
# (n170)-[r192:NEIGHBOR_OF]->(n4),
# (n172)-[r193:NEIGHBOR_OF]->(n4),
# (n173)-[r194:NEIGHBOR_OF]->(n4),
# (n28)-[r195:NEIGHBOR_OF]->(n4),
# (n174)-[r196:NEIGHBOR_OF]->(n4),
# (n108)-[r197:NEIGHBOR_OF]->(n4),
# (n89)-[r198:NEIGHBOR_OF]->(n4),
# (n175)-[r199:NEIGHBOR_OF]->(n4),
# (n176)-[r200:NEIGHBOR_OF]->(n4),
# (n177)-[r201:NEIGHBOR_OF]->(n4),
# (n178)-[r202:NEIGHBOR_OF]->(n4),
# (n179)-[r203:NEIGHBOR_OF]->(n4),
# (n180)-[r204:NEIGHBOR_OF]->(n4),
# (n151)-[r205:NEIGHBOR_OF]->(n4),
# (n181)-[r206:NEIGHBOR_OF]->(n4),
# (n182)-[r207:NEIGHBOR_OF]->(n4),
# (n183)-[r208:NEIGHBOR_OF]->(n4),
# (n184)-[r209:NEIGHBOR_OF]->(n4),
# (n185)-[r210:NEIGHBOR_OF]->(n4),
# (n186)-[r211:NEIGHBOR_OF]->(n4),
# (n187)-[r212:NEIGHBOR_OF]->(n4),
# (n188)-[r213:NEIGHBOR_OF]->(n4),
# (n189)-[r214:NEIGHBOR_OF]->(n4),
# (n190)-[r215:NEIGHBOR_OF]->(n4),
# (n191)-[r216:NEIGHBOR_OF]->(n4),
# (n192)-[r217:NEIGHBOR_OF]->(n4),
# (n193)-[r218:NEIGHBOR_OF]->(n4),
# (n194)-[r219:NEIGHBOR_OF]->(n4),
# (n195)-[r220:NEIGHBOR_OF]->(n4),
# (n196)-[r221:NEIGHBOR_OF]->(n4),
# (n197)-[r222:NEIGHBOR_OF]->(n4),
# (n180)-[r223:NEIGHBOR_OF]->(n4),
# (n82)-[r224:NEIGHBOR_OF]->(n4),
# (n198)-[r225:NEIGHBOR_OF]->(n4),
# (n199)-[r226:NEIGHBOR_OF]->(n4),
# (n200)-[r227:NEIGHBOR_OF]->(n4),
# (n201)-[r228:NEIGHBOR_OF]->(n4),
# (n202)-[r229:NEIGHBOR_OF]->(n4),
# (n203)-[r230:NEIGHBOR_OF]->(n4),
# (n204)-[r231:NEIGHBOR_OF]->(n4),
# (n205)-[r232:NEIGHBOR_OF]->(n4),
# (n206)-[r233:NEIGHBOR_OF]->(n4),
# (n207)-[r234:NEIGHBOR_OF]->(n4),
# (n208)-[r235:NEIGHBOR_OF]->(n4),
# (n209)-[r236:NEIGHBOR_OF]->(n4),
# (n210)-[r237:NEIGHBOR_OF]->(n4),
# (n211)-[r238:NEIGHBOR_OF]->(n4),
# (n212)-[r239:NEIGHBOR_OF]->(n4),
# (n211)-[r240:NEIGHBOR_OF]->(n4),
# (n213)-[r241:NEIGHBOR_OF]->(n4),
# (n214)-[r242:NEIGHBOR_OF]->(n4),
# (n211)-[r243:NEIGHBOR_OF]->(n4),
# (n215)-[r244:NEIGHBOR_OF]->(n4),
# (n216)-[r245:NEIGHBOR_OF]->(n4),
# (n217)-[r246:NEIGHBOR_OF]->(n4),
# (n218)-[r247:NEIGHBOR_OF]->(n4),
# (n211)-[r248:NEIGHBOR_OF]->(n4),
# (n219)-[r249:NEIGHBOR_OF]->(n4),
# (n220)-[r250:NEIGHBOR_OF]->(n4),
# (n221)-[r251:NEIGHBOR_OF]->(n4),
# (n222)-[r252:NEIGHBOR_OF]->(n4),
# (n223)-[r253:NEIGHBOR_OF]->(n4),
# (n224)-[r254:NEIGHBOR_OF]->(n4),
# (n225)-[r255:NEIGHBOR_OF]->(n4),
# (n226)-[r256:NEIGHBOR_OF]->(n4),
# (n227)-[r257:NEIGHBOR_OF]->(n4),
# (n228)-[r258:NEIGHBOR_OF]->(n4),
# (n229)-[r259:NEIGHBOR_OF]->(n4),
# (n230)-[r260:NEIGHBOR_OF]->(n4),
# (n231)-[r261:NEIGHBOR_OF]->(n4),
# (n232)-[r262:NEIGHBOR_OF]->(n4),
# (n233)-[r263:NEIGHBOR_OF]->(n4),
# (n234)-[r264:NEIGHBOR_OF]->(n4),
# (n235)-[r265:NEIGHBOR_OF]->(n4),
# (n236)-[r266:NEIGHBOR_OF]->(n4),
# (n237)-[r267:NEIGHBOR_OF]->(n4),
# (n238)-[r268:NEIGHBOR_OF]->(n4),
# (n239)-[r269:NEIGHBOR_OF]->(n4),
# (n238)-[r270:NEIGHBOR_OF]->(n4),
# (n240)-[r271:NEIGHBOR_OF]->(n4),
# (n240)-[r272:NEIGHBOR_OF]->(n4),
# (n241)-[r273:NEIGHBOR_OF]->(n4),
# (n242)-[r274:NEIGHBOR_OF]->(n4),
# (n243)-[r275:NEIGHBOR_OF]->(n4),
# (n244)-[r276:NEIGHBOR_OF]->(n4),
# (n245)-[r277:NEIGHBOR_OF]->(n4),
# (n246)-[r278:NEIGHBOR_OF]->(n4),
# (n247)-[r279:NEIGHBOR_OF]->(n4),
# (n248)-[r280:NEIGHBOR_OF]->(n4),
# (n249)-[r281:NEIGHBOR_OF]->(n4),
# (n250)-[r282:NEIGHBOR_OF]->(n4),
# (n251)-[r283:NEIGHBOR_OF]->(n4),
# (n249)-[r284:NEIGHBOR_OF]->(n4),
# (n252)-[r285:NEIGHBOR_OF]->(n4),
# (n244)-[r286:NEIGHBOR_OF]->(n4),
# (n253)-[r287:NEIGHBOR_OF]->(n4),
# (n254)-[r288:NEIGHBOR_OF]->(n13),
# (n255)-[r289:NEIGHBOR_OF]->(n13),
# (n256)-[r290:NEIGHBOR_OF]->(n13),
# (n257)-[r291:NEIGHBOR_OF]->(n13),
# (n258)-[r292:NEIGHBOR_OF]->(n13),
# (n259)-[r293:NEIGHBOR_OF]->(n13),
# (n260)-[r294:NEIGHBOR_OF]->(n13),
# (n261)-[r295:NEIGHBOR_OF]->(n13),
# (n262)-[r296:NEIGHBOR_OF]->(n13),
# (n263)-[r297:NEIGHBOR_OF]->(n13),
# (n264)-[r298:NEIGHBOR_OF]->(n13),
# (n265)-[r299:NEIGHBOR_OF]->(n13),
# (n266)-[r300:NEIGHBOR_OF]->(n13),
# (n267)-[r301:NEIGHBOR_OF]->(n13),
# (n268)-[r302:NEIGHBOR_OF]->(n13),
# (n269)-[r303:NEIGHBOR_OF]->(n13),
# (n270)-[r304:NEIGHBOR_OF]->(n13),
# (n271)-[r305:NEIGHBOR_OF]->(n13),
# (n272)-[r306:NEIGHBOR_OF]->(n13),
# (n273)-[r307:NEIGHBOR_OF]->(n13),
# (n274)-[r308:NEIGHBOR_OF]->(n13),
# (n275)-[r309:NEIGHBOR_OF]->(n13),
# (n276)-[r310:NEIGHBOR_OF]->(n13),
# (n31)-[r311:NEIGHBOR_OF]->(n13),
# (n277)-[r312:NEIGHBOR_OF]->(n13),
# (n259)-[r313:NEIGHBOR_OF]->(n13),
# (n278)-[r314:NEIGHBOR_OF]->(n13),
# (n279)-[r315:NEIGHBOR_OF]->(n13),
# (n280)-[r316:NEIGHBOR_OF]->(n13),
# (n281)-[r317:NEIGHBOR_OF]->(n13),
# (n282)-[r318:NEIGHBOR_OF]->(n13),
# (n283)-[r319:NEIGHBOR_OF]->(n13),
# (n284)-[r320:NEIGHBOR_OF]->(n13),
# (n48)-[r321:NEIGHBOR_OF]->(n13),
# (n285)-[r322:NEIGHBOR_OF]->(n13),
# (n32)-[r323:NEIGHBOR_OF]->(n13),
# (n39)-[r324:NEIGHBOR_OF]->(n13),
# (n286)-[r325:NEIGHBOR_OF]->(n13),
# (n287)-[r326:NEIGHBOR_OF]->(n13),
# (n264)-[r327:NEIGHBOR_OF]->(n13),
# (n288)-[r328:NEIGHBOR_OF]->(n13),
# (n289)-[r329:NEIGHBOR_OF]->(n13),
# (n277)-[r330:NEIGHBOR_OF]->(n13),
# (n290)-[r331:NEIGHBOR_OF]->(n13),
# (n291)-[r332:NEIGHBOR_OF]->(n13),
# (n277)-[r333:NEIGHBOR_OF]->(n13),
# (n292)-[r334:NEIGHBOR_OF]->(n13),
# (n293)-[r335:NEIGHBOR_OF]->(n13),
# (n294)-[r336:NEIGHBOR_OF]->(n13),
# (n295)-[r337:NEIGHBOR_OF]->(n13),
# (n296)-[r338:NEIGHBOR_OF]->(n13),
# (n290)-[r339:NEIGHBOR_OF]->(n13),
# (n297)-[r340:NEIGHBOR_OF]->(n13),
# (n298)-[r341:NEIGHBOR_OF]->(n13),
# (n299)-[r342:NEIGHBOR_OF]->(n13),
# (n300)-[r343:NEIGHBOR_OF]->(n13),
# (n301)-[r344:NEIGHBOR_OF]->(n13),
# (n302)-[r345:NEIGHBOR_OF]->(n13),
# (n279)-[r346:NEIGHBOR_OF]->(n13),
# (n280)-[r347:NEIGHBOR_OF]->(n13),
# (n281)-[r348:NEIGHBOR_OF]->(n13),
# (n282)-[r349:NEIGHBOR_OF]->(n13),
# (n283)-[r350:NEIGHBOR_OF]->(n13),
# (n284)-[r351:NEIGHBOR_OF]->(n13),
# (n287)-[r352:NEIGHBOR_OF]->(n13),
# (n73)-[r353:NEIGHBOR_OF]->(n13),
# (n303)-[r354:NEIGHBOR_OF]->(n13),
# (n300)-[r355:NEIGHBOR_OF]->(n13),
# (n304)-[r356:NEIGHBOR_OF]->(n13),
# (n278)-[r357:NEIGHBOR_OF]->(n13),
# (n303)-[r358:NEIGHBOR_OF]->(n13),
# (n303)-[r359:NEIGHBOR_OF]->(n13),
# (n300)-[r360:NEIGHBOR_OF]->(n13),
# (n279)-[r361:NEIGHBOR_OF]->(n13),
# (n280)-[r362:NEIGHBOR_OF]->(n13),
# (n281)-[r363:NEIGHBOR_OF]->(n13),
# (n282)-[r364:NEIGHBOR_OF]->(n13),
# (n283)-[r365:NEIGHBOR_OF]->(n13),
# (n284)-[r366:NEIGHBOR_OF]->(n13),
# (n46)-[r367:NEIGHBOR_OF]->(n13),
# (n305)-[r368:NEIGHBOR_OF]->(n13),
# (n306)-[r369:NEIGHBOR_OF]->(n13),
# (n307)-[r370:NEIGHBOR_OF]->(n13),
# (n308)-[r371:NEIGHBOR_OF]->(n13),
# (n309)-[r372:NEIGHBOR_OF]->(n13),
# (n305)-[r373:NEIGHBOR_OF]->(n13),
# (n310)-[r374:NEIGHBOR_OF]->(n13),
# (n311)-[r375:NEIGHBOR_OF]->(n13),
# (n310)-[r376:NEIGHBOR_OF]->(n13),
# (n310)-[r377:NEIGHBOR_OF]->(n13),
# (n310)-[r378:NEIGHBOR_OF]->(n13),
# (n310)-[r379:NEIGHBOR_OF]->(n13),
# (n310)-[r380:NEIGHBOR_OF]->(n13),
# (n310)-[r381:NEIGHBOR_OF]->(n13),
# (n310)-[r382:NEIGHBOR_OF]->(n13),
# (n310)-[r383:NEIGHBOR_OF]->(n13),
# (n311)-[r384:NEIGHBOR_OF]->(n13),
# (n310)-[r385:NEIGHBOR_OF]->(n13),
# (n310)-[r386:NEIGHBOR_OF]->(n13),
# (n269)-[r387:NEIGHBOR_OF]->(n13),
# (n287)-[r388:NEIGHBOR_OF]->(n13),
# (n312)-[r389:NEIGHBOR_OF]->(n13),
# (n313)-[r390:NEIGHBOR_OF]->(n13),
# (n314)-[r391:NEIGHBOR_OF]->(n13),
# (n315)-[r392:NEIGHBOR_OF]->(n13),
# (n316)-[r393:NEIGHBOR_OF]->(n13),
# (n317)-[r394:NEIGHBOR_OF]->(n13),
# (n318)-[r395:NEIGHBOR_OF]->(n13),
# (n319)-[r396:NEIGHBOR_OF]->(n13),
# (n320)-[r397:NEIGHBOR_OF]->(n13),
# (n320)-[r398:NEIGHBOR_OF]->(n13),
# (n321)-[r399:NEIGHBOR_OF]->(n13),
# (n321)-[r400:NEIGHBOR_OF]->(n13),
# (n322)-[r401:NEIGHBOR_OF]->(n13),
# (n322)-[r402:NEIGHBOR_OF]->(n13),
# (n323)-[r403:NEIGHBOR_OF]->(n13),
# (n324)-[r404:NEIGHBOR_OF]->(n13),
# (n274)-[r405:NEIGHBOR_OF]->(n13),
# (n325)-[r406:NEIGHBOR_OF]->(n13),
# (n326)-[r407:NEIGHBOR_OF]->(n13),
# (n327)-[r408:NEIGHBOR_OF]->(n13),
# (n328)-[r409:NEIGHBOR_OF]->(n13),
# (n329)-[r410:NEIGHBOR_OF]->(n13),
# (n330)-[r411:NEIGHBOR_OF]->(n13),
# (n331)-[r412:NEIGHBOR_OF]->(n13),
# (n332)-[r413:NEIGHBOR_OF]->(n13),
# (n333)-[r414:NEIGHBOR_OF]->(n13),
# (n334)-[r415:NEIGHBOR_OF]->(n13),
# (n335)-[r416:NEIGHBOR_OF]->(n13),
# (n331)-[r417:NEIGHBOR_OF]->(n13),
# (n336)-[r418:NEIGHBOR_OF]->(n13),
# (n337)-[r419:NEIGHBOR_OF]->(n13),
# (n338)-[r420:NEIGHBOR_OF]->(n13),
# (n339)-[r421:NEIGHBOR_OF]->(n13),
# (n339)-[r422:NEIGHBOR_OF]->(n13),
# (n340)-[r423:NEIGHBOR_OF]->(n13),
# (n341)-[r424:NEIGHBOR_OF]->(n13),
# (n341)-[r425:NEIGHBOR_OF]->(n13),
# (n342)-[r426:NEIGHBOR_OF]->(n13),
# (n343)-[r427:NEIGHBOR_OF]->(n13),
# (n344)-[r428:NEIGHBOR_OF]->(n13),
# (n345)-[r429:NEIGHBOR_OF]->(n13),
# (n346)-[r430:NEIGHBOR_OF]->(n13),
# (n278)-[r431:NEIGHBOR_OF]->(n13),
# (n347)-[r432:NEIGHBOR_OF]->(n13),
# (n348)-[r433:NEIGHBOR_OF]->(n13),
# (n349)-[r434:NEIGHBOR_OF]->(n13),
# (n350)-[r435:NEIGHBOR_OF]->(n13),
# (n351)-[r436:NEIGHBOR_OF]->(n13),
# (n352)-[r437:NEIGHBOR_OF]->(n13),
# (n353)-[r438:NEIGHBOR_OF]->(n13),
# (n347)-[r439:NEIGHBOR_OF]->(n13),
# (n354)-[r440:NEIGHBOR_OF]->(n13),
# (n355)-[r441:NEIGHBOR_OF]->(n13),
# (n356)-[r442:NEIGHBOR_OF]->(n13),
# (n357)-[r443:NEIGHBOR_OF]->(n13),
# (n358)-[r444:NEIGHBOR_OF]->(n13),
# (n359)-[r445:NEIGHBOR_OF]->(n13),
# (n360)-[r446:NEIGHBOR_OF]->(n13),
# (n360)-[r447:NEIGHBOR_OF]->(n13),
# (n361)-[r448:NEIGHBOR_OF]->(n13),
# (n361)-[r449:NEIGHBOR_OF]->(n13),
# (n349)-[r450:NEIGHBOR_OF]->(n13),
# (n362)-[r451:NEIGHBOR_OF]->(n13),
# (n362)-[r452:NEIGHBOR_OF]->(n13),
# (n300)-[r453:NEIGHBOR_OF]->(n13),
# (n363)-[r454:NEIGHBOR_OF]->(n13),
# (n73)-[r455:NEIGHBOR_OF]->(n13),
# (n323)-[r456:NEIGHBOR_OF]->(n13),
# (n364)-[r457:NEIGHBOR_OF]->(n13),
# (n365)-[r458:NEIGHBOR_OF]->(n13),
# (n366)-[r459:NEIGHBOR_OF]->(n13),
# (n367)-[r460:NEIGHBOR_OF]->(n13),
# (n368)-[r461:NEIGHBOR_OF]->(n13),
# (n369)-[r462:NEIGHBOR_OF]->(n13),
# (n351)-[r463:NEIGHBOR_OF]->(n13),
# (n273)-[r464:NEIGHBOR_OF]->(n13),
# (n261)-[r465:NEIGHBOR_OF]->(n13),
# (n370)-[r466:NEIGHBOR_OF]->(n13),
# (n371)-[r467:NEIGHBOR_OF]->(n13),
# (n372)-[r468:NEIGHBOR_OF]->(n13),
# (n373)-[r469:NEIGHBOR_OF]->(n13),
# (n374)-[r470:NEIGHBOR_OF]->(n13),
# (n211)-[r471:NEIGHBOR_OF]->(n13),
# (n375)-[r472:NEIGHBOR_OF]->(n13),
# (n376)-[r473:NEIGHBOR_OF]->(n13),
# (n377)-[r474:NEIGHBOR_OF]->(n13),
# (n378)-[r475:NEIGHBOR_OF]->(n13),
# (n379)-[r476:NEIGHBOR_OF]->(n13),
# (n380)-[r477:NEIGHBOR_OF]->(n13),
# (n216)-[r478:NEIGHBOR_OF]->(n13),
# (n381)-[r479:NEIGHBOR_OF]->(n13),
# (n382)-[r480:NEIGHBOR_OF]->(n13),
# (n211)-[r481:NEIGHBOR_OF]->(n13),
# (n383)-[r482:NEIGHBOR_OF]->(n13),
# (n384)-[r483:NEIGHBOR_OF]->(n13),
# (n385)-[r484:NEIGHBOR_OF]->(n13),
# (n386)-[r485:NEIGHBOR_OF]->(n13),
# (n211)-[r486:NEIGHBOR_OF]->(n13),
# (n387)-[r487:NEIGHBOR_OF]->(n13),
# (n211)-[r488:NEIGHBOR_OF]->(n13),
# (n388)-[r489:NEIGHBOR_OF]->(n13),
# (n389)-[r490:NEIGHBOR_OF]->(n13),
# (n390)-[r491:NEIGHBOR_OF]->(n13),
# (n391)-[r492:NEIGHBOR_OF]->(n13),
# (n392)-[r493:NEIGHBOR_OF]->(n13),
# (n370)-[r494:NEIGHBOR_OF]->(n13),
# (n393)-[r495:NEIGHBOR_OF]->(n13),
# (n394)-[r496:NEIGHBOR_OF]->(n13),
# (n393)-[r497:NEIGHBOR_OF]->(n13),
# (n395)-[r498:NEIGHBOR_OF]->(n13),
# (n396)-[r499:NEIGHBOR_OF]->(n13),
# (n211)-[r500:NEIGHBOR_OF]->(n13),
# (n397)-[r501:NEIGHBOR_OF]->(n13),
# (n374)-[r502:NEIGHBOR_OF]->(n13),
# (n211)-[r503:NEIGHBOR_OF]->(n13),
# (n398)-[r504:NEIGHBOR_OF]->(n13),
# (n399)-[r505:NEIGHBOR_OF]->(n13),
# (n400)-[r506:NEIGHBOR_OF]->(n13),
# (n396)-[r507:NEIGHBOR_OF]->(n13),
# (n401)-[r508:NEIGHBOR_OF]->(n13),
# (n379)-[r509:NEIGHBOR_OF]->(n13),
# (n402)-[r510:NEIGHBOR_OF]->(n13),
# (n395)-[r511:NEIGHBOR_OF]->(n13),
# (n211)-[r512:NEIGHBOR_OF]->(n13),
# (n403)-[r513:NEIGHBOR_OF]->(n13),
# (n404)-[r514:NEIGHBOR_OF]->(n13),
# (n405)-[r515:NEIGHBOR_OF]->(n13),
# (n211)-[r516:NEIGHBOR_OF]->(n13),
# (n406)-[r517:NEIGHBOR_OF]->(n13),
# (n379)-[r518:NEIGHBOR_OF]->(n13),
# (n407)-[r519:NEIGHBOR_OF]->(n13),
# (n408)-[r520:NEIGHBOR_OF]->(n13),
# (n379)-[r521:NEIGHBOR_OF]->(n13),
# (n407)-[r522:NEIGHBOR_OF]->(n13),
# (n287)-[r523:NEIGHBOR_OF]->(n13),
# (n409)-[r524:NEIGHBOR_OF]->(n13),
# (n378)-[r525:NEIGHBOR_OF]->(n13),
# (n379)-[r526:NEIGHBOR_OF]->(n13),
# (n410)-[r527:NEIGHBOR_OF]->(n13),
# (n411)-[r528:NEIGHBOR_OF]->(n13),
# (n412)-[r529:NEIGHBOR_OF]->(n13),
# (n413)-[r530:NEIGHBOR_OF]->(n13),
# (n259)-[r531:NEIGHBOR_OF]->(n13),
# (n414)-[r532:NEIGHBOR_OF]->(n13),
# (n415)-[r533:NEIGHBOR_OF]->(n13),
# (n351)-[r534:NEIGHBOR_OF]->(n13),
# (n416)-[r535:NEIGHBOR_OF]->(n13),
# (n417)-[r536:NEIGHBOR_OF]->(n13),
# (n418)-[r537:NEIGHBOR_OF]->(n13),
# (n362)-[r538:NEIGHBOR_OF]->(n13),
# (n220)-[r539:NEIGHBOR_OF]->(n13),
# (n419)-[r540:NEIGHBOR_OF]->(n13),
# (n420)-[r541:NEIGHBOR_OF]->(n13),
# (n421)-[r542:NEIGHBOR_OF]->(n13),
# (n422)-[r543:NEIGHBOR_OF]->(n13),
# (n423)-[r544:NEIGHBOR_OF]->(n13),
# (n424)-[r545:NEIGHBOR_OF]->(n13),
# (n425)-[r546:NEIGHBOR_OF]->(n13),
# (n426)-[r547:NEIGHBOR_OF]->(n13),
# (n427)-[r548:NEIGHBOR_OF]->(n13),
# (n428)-[r549:NEIGHBOR_OF]->(n13),
# (n429)-[r550:NEIGHBOR_OF]->(n13),
# (n223)-[r551:NEIGHBOR_OF]->(n13),
# (n430)-[r552:NEIGHBOR_OF]->(n13),
# (n431)-[r553:NEIGHBOR_OF]->(n13),
# (n432)-[r554:NEIGHBOR_OF]->(n13),
# (n433)-[r555:NEIGHBOR_OF]->(n13),
# (n236)-[r556:NEIGHBOR_OF]->(n13),
# (n237)-[r557:NEIGHBOR_OF]->(n13),
# (n434)-[r558:NEIGHBOR_OF]->(n13),
# (n435)-[r559:NEIGHBOR_OF]->(n13),
# (n434)-[r560:NEIGHBOR_OF]->(n13),
# (n240)-[r561:NEIGHBOR_OF]->(n13),
# (n240)-[r562:NEIGHBOR_OF]->(n13),
# (n241)-[r563:NEIGHBOR_OF]->(n13),
# (n242)-[r564:NEIGHBOR_OF]->(n13),
# (n243)-[r565:NEIGHBOR_OF]->(n13),
# (n244)-[r566:NEIGHBOR_OF]->(n13),
# (n245)-[r567:NEIGHBOR_OF]->(n13),
# (n246)-[r568:NEIGHBOR_OF]->(n13),
# (n247)-[r569:NEIGHBOR_OF]->(n13),
# (n248)-[r570:NEIGHBOR_OF]->(n13),
# (n249)-[r571:NEIGHBOR_OF]->(n13),
# (n436)-[r572:NEIGHBOR_OF]->(n13),
# (n437)-[r573:NEIGHBOR_OF]->(n13),
# (n249)-[r574:NEIGHBOR_OF]->(n13),
# (n252)-[r575:NEIGHBOR_OF]->(n13),
# (n244)-[r576:NEIGHBOR_OF]->(n13),
# (n253)-[r577:NEIGHBOR_OF]->(n13),
# ;

# %%
len(bfs_queue)
# Out:
# 437

# %%
# Implementing GNN
import numpy as np
initial_embedding_matrix = np.stack([n.embedding for n in bfs_queue])
# We will update this matrix in subsequent passes

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
initial_embedding_matrix
# Out:
# array([[ 0.06638414, -0.2866605 , -0.12929122, ...,  0.06957521,
#          0.6415759 ,  0.670869  ],
#        [ 0.713002  , -1.4152358 , -0.6512912 , ...,  0.35884568,
#          1.4448406 ,  1.1701587 ],
#        [ 0.31630933, -0.4885309 , -0.10898053, ...,  0.30732152,
#          0.40860137,  0.5878364 ],
#        ...,
#        [ 0.49651578, -0.4387598 , -0.15660518, ...,  0.28429177,
#          0.8203162 ,  0.70391506],
#        [ 0.03698523, -0.0184543 , -0.0134409 , ...,  0.00544398,
#         -0.00185403,  0.02470144],
#        [ 0.09444778, -0.03717188, -0.01494965, ...,  0.03292532,
#          0.07118396,  0.04680646]], dtype=float32)
