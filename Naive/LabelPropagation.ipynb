# %%
start_links = ['https://en.wikipedia.org/wiki/Antiderivative',
'https://en.wikipedia.org/wiki/Hyperbola',
'https://en.wikipedia.org/wiki/Area_under_the_curve_(pharmacokinetics)',
'https://en.wikipedia.org/wiki/Vector_(mathematics_and_physics)',
'https://en.wikipedia.org/wiki/Parabola',
'https://en.wikipedia.org/wiki/Logarithm',
'https://en.wikipedia.org/wiki/Harmonic_progression',
'https://en.wikipedia.org/wiki/De_Morgan%27s_laws',
'https://en.wikipedia.org/wiki/Even_and_odd_functions',
'https://en.wikipedia.org/wiki/Floor_and_ceiling_functions',
'https://en.wikipedia.org/wiki/Transpose',
'https://en.wikipedia.org/wiki/Chord_(geometry)',
'https://en.wikipedia.org/wiki/Inverse_trigonometric_functions',
'https://en.wikipedia.org/wiki/Parametric_equation',
'https://en.wikipedia.org/wiki/Director_circle',
'https://en.wikipedia.org/wiki/Coplanarity',
'https://en.wikipedia.org/wiki/Centroid',
'https://en.wikipedia.org/wiki/Altitude_(triangle)',
'https://en.wikipedia.org/wiki/Function_composition',
'https://en.wikipedia.org/wiki/Periodic_function',
'https://en.wikipedia.org/wiki/Dihedral_angle',
'https://en.wikipedia.org/wiki/Diophantine_geometry',
'https://en.wikipedia.org/wiki/Sampling_(statistics)#Simple_random_sampling',
'https://en.wikipedia.org/wiki/Minimax',
'https://en.wikipedia.org/wiki/Quantile_function',
'https://en.wikipedia.org/wiki/Karl_Weierstrass',
'https://en.wikipedia.org/wiki/Augustin-Louis_Cauchy']

start_labels = [3,3,3,1,2,1,1,1,1,1,2,1,3,2,2,2,1,3,3,2,3,0,0,0,0,0,0]
# 1 is beginner, 2 is intermediate, 3 is advanced

# %%
from bs4 import BeautifulSoup
import requests

# %%
class Node:
  def __init__(self,link,label=None):
    self.link = link # to store the link 
    self.label = label # to store the label
    self.neighbours = [] # to store the neighbours
    # to store the labels that come to this node in propagation step
    # and then assign to it the most frequent one
    self.label_options = [] 

    self.name = link.split('/')[-1] # can be useful if we are displaying the nodes
    # neighbours is a list of nodes

unique_links = {} # to store all unique links and their nodes

# %%
# creating and storing initial nodes
start_nodes = [Node(lnk,lbl) for lnk,lbl in zip(start_links,start_labels)]
for n in start_nodes:
  unique_links[n.link] = n

# helper function
def getLinks(link):
  # returns a list of all links present on the page of the passed link
  r = requests.get(link)
  soup = BeautifulSoup(r.content, 'html5lib')
  return ['https://en.wikipedia.org/'+i['href'] for i in soup.find_all('a',href=True) if i['href'].startswith("/wiki")]

# %%
bfs_queue = [] # Queue to carry out bfs

# add the initial nodes to the queue
for s in start_nodes:
  bfs_queue.append(s) 

# testing on 1000 counts first -----------------> 10 minutes time, 76,162 nodes collected
# testing on 1500 counts first -----------------> 13 minutes time, 1,26,584 nodes collected
count = 1500 
for node in bfs_queue:

  count-=1 # testing
  if count==0:break # testing
  #if len(bfs_queue)==100000:break

  links = getLinks(node.link)
  neighbours = [] # store neighbours of the node
  for lnk in links:
    if lnk in unique_links:
      # Do nothing if link already explored
      #print("Already present")
      pass
    else:
      new = Node(lnk)
      bfs_queue.append(new) # add this node to queue
      unique_links[lnk] = new # also add to unique_links dictionary
    # here I am ensuring that no link is repeated but neighbours can be repeated
      
  for lk in links:
    neighbours.append(unique_links[lk])
  node.neighbours = neighbours

# %%
# helper function
def stat():
  global bfs_queue,unique_links
  print("Length of bfs_queue:",len(bfs_queue))
  print("Length of unique_links:",len(unique_links))

# %%
stat()
# Out:
# Length of bfs_queue: 126660
# Length of unique_links: 126660

# %%
from collections import Counter
import numpy as np

# %%
# Now let us try to propagate the labels using the Label Propagation method

while True:
  # Loop until unlabelled nodes are 0, ie till all nodes get a label
  unlabelled = 0
  for lnk in unique_links:
    node = unique_links[lnk]

    if node.label is not None:
      #print(node.label,node.neighbours)
      for n in node.neighbours:
        #print("n.label->",n.label)
        if n.label is None:
          unlabelled+=1
          n.label_options.append(node.label)

  for lk in unique_links:
    node = unique_links[lk]
    if node.label is None: # can remove this condition, so that we update all nodes everytime, to get better results
      node.label = Counter(node.label_options).most_common(1)[0][0]

  print("Number of unlabelled nodes:",unlabelled)
  if unlabelled==0:break

  ask = input("Continue?")
  if ask!='y':break
# Out:
# Number of unlabelled nodes: 322115
# Continue?y
# Number of unlabelled nodes: 0

# %%
def ulb():
  c = 0
  for l in unique_links:
    if unique_links[l].label==None:c+=1
  return "Unlabelled nodes are:"+str(c)

# %%
ulb()
# Out:
# 'Unlabelled nodes are:0'

# %%
def counts():
  c1 = 0
  c1 = 0
  c2 = 0
  c3 = 0
  c4 = 0
  for l in unique_links:
    lb = unique_links[l].label
    if lb == 1:c1+=1
    if lb == 2:c2+=1
    if lb == 3:c3+=1
    if lb == 0:c4+=1
  print("Beginner:",c1)
  print("Intermediate:",c2)
  print("Advanced:",c3)
  print("Irrelevant:",c4)

# %%
counts()
# Out:
# Beginner: 58559
# Intermediate: 22486
# Advanced: 40619
# Irrelevant: 4920

# %%
import pandas as pd
pages = pd.DataFrame(columns=['Name','Link','Label'])
pages['Name'] = [n.name for n in unique_links.values()]
pages['Link'] = [n.link for n in unique_links.values()]
pages['Label'] = [n.label for n in unique_links.values()]

# %%
pages.tail()
# Out:
#                                              Name  \
# 126579            Category:Mathematical_databases
# 126580  Category:Publications_established_in_1931
# 126581                     Talk:Zentralblatt_MATH
# 126582                          Zentralblatt_MATH
# 126583                          Zentralblatt_MATH
#
#                                                      Link  Label
# 126579  https://en.wikipedia.org//wiki/Category:Mathem...      0
# 126580  https://en.wikipedia.org//wiki/Category:Public...      0
# 126581  https://en.wikipedia.org//wiki/Talk:Zentralbla...      0
# 126582  https://en.wikipedia.org//wiki/Special:WhatLin...      0
# 126583  https://en.wikipedia.org//wiki/Special:RecentC...      0

# %%
pages.to_csv("/content/drive/MyDrive/Semester4/DS250/Wikipedia/pages.csv")

# %%
edges = pd.DataFrame(columns=['From','To'])
frm = []
to = []
frmto = []
c = 0
for lnk in unique_links:
  c+=1
  node = unique_links[lnk]

  for n in node.neighbours:
    # frm.append(lnk)
    # to.append(n.link)
    frmto.append((lnk,n.link))
print(c)
# Out:
# 126584

# %%
print(len(frm),len(to))
# Out:
# 511993 511993

# %%
edges['From'] = [n[0] for n in frmto]#frm
edges['To'] = [n[1] for n in frmto]#to
edges.to_csv("/content/drive/MyDrive/Semester4/DS250/Wikipedia/edges.csv")

# %%
edges
# Out:
#                                                      From  \
# 0            https://en.wikipedia.org/wiki/Antiderivative
# 1            https://en.wikipedia.org/wiki/Antiderivative
# 2            https://en.wikipedia.org/wiki/Antiderivative
# 3            https://en.wikipedia.org/wiki/Antiderivative
# 4            https://en.wikipedia.org/wiki/Antiderivative
# ...                                                   ...
# 511988  https://en.wikipedia.org//wiki/Special:BookSou...
# 511989  https://en.wikipedia.org//wiki/Special:BookSou...
# 511990  https://en.wikipedia.org//wiki/Special:BookSou...
# 511991  https://en.wikipedia.org//wiki/Special:BookSou...
# 511992  https://en.wikipedia.org//wiki/Special:BookSou...
#
#                                                        To
# 0       https://en.wikipedia.org//wiki/Antiderivative_...
# 1       https://en.wikipedia.org//wiki/Lists_of_integrals
# 2                 https://en.wikipedia.org//wiki/Calculus
# 3       https://en.wikipedia.org//wiki/Fundamental_the...
# 4       https://en.wikipedia.org//wiki/Leibniz_integra...
# ...                                                   ...
# 511988  https://en.wikipedia.org//wiki/Wikipedia:File_...
# 511989  https://en.wikipedia.org//wiki/Wikipedia:File_...
# 511990  https://en.wikipedia.org//wiki/Special:Special...
# 511991     https://en.wikipedia.org//wiki/Wikipedia:About
# 511992  https://en.wikipedia.org//wiki/Wikipedia:Gener...
#
# [511993 rows x 2 columns]

# %%
###-------------Centrality measures----------------------###

# %%
# degree centrality and degree distribution
import matplotlib.pyplot as plt
import seaborn as sns

# %%
degrees = {}
for node in bfs_queue:
  degrees[node] = len(node.neighbours)

deg_centrality = {} # just use this dictionary to find degree centrality of any link
for node in bfs_queue:
  deg_centrality[node.link] = len(node.neighbours)

# %%
plt.scatter(list(range(len(bfs_queue))),degrees.values())
plt.xlim(0,100)
plt.ylabel("Degrees")
# Out:
# Text(0, 0.5, 'Degrees')

# %%
sns.displot(list(degrees.values()),bins=100)

# %%
list(degrees.values()).count(150) # 6 nodes have degree 150
# Out:
# 6

# %%
deg_counts = {}
for n in set(degrees.values()):
  deg_counts[n] = list(degrees.values()).count(n)

# %%
len(set(degrees.values())),len(degrees.values())
# Out:
# (587, 126660)

# %%
sns.scatterplot(list(deg_counts.keys()),list(deg_counts.values()))
plt.ylim(0,50)
# We can see that the degree distribution follows power law.
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# (0.0, 50.0)

# %%
# Let us randomly select 1000 nodes from bfs_queue and then try out
# centrality measures on them in neo4j

# %%
import random
ran_100 = random.sample(bfs_queue,100)

for n in ran_100:
  for nn in n.neighbours:
    ran_100.append(nn)

# %%
import pandas as pd

# %%
pages = pd.read_csv("/content/drive/MyDrive/Semester4/DS250/Wikipedia/pages.csv")

# %%
pages.head()
# Out:
#    Unnamed: 0                                     Name  \
# 0           0                           Antiderivative
# 1           1                                Hyperbola
# 2           2  Area_under_the_curve_(pharmacokinetics)
# 3           3         Vector_(mathematics_and_physics)
# 4           4                                 Parabola
#
#                                                 Link  Label
# 0       https://en.wikipedia.org/wiki/Antiderivative      3
# 1            https://en.wikipedia.org/wiki/Hyperbola      3
# 2  https://en.wikipedia.org/wiki/Area_under_the_c...      3
# 3  https://en.wikipedia.org/wiki/Vector_(mathemat...      1
# 4             https://en.wikipedia.org/wiki/Parabola      2

# %%
len(pages)
# Out:
# 126584

# %%
len(pages['Link'].unique())
# Out:
# 126584

# %%
label = pages.loc[pages['Link']==pages.iloc[3]['Link']]['Label']
label.values[0]
# Out:
# 1

# %%
id = {}
for i,n in enumerate(ran_100):
  id[n] = i+1

# %%
st = "CREATE "
df = pages.copy()
for h in ran_100:
  label = df.loc[df['Link']==h.link]['Label']
  # print(label)
  # print(h.link)
  try:
    st+="(n"+str(id[h])+":NODE{link:'"+h.link+"'"+",LABEL:"+str(label.values[0])+"}"+"),"+"\n"
  except:
    continue
st = st.rstrip(",")
st+="\n"
#print(st)
rel = 0
for n in ran_100:
  for nn in n.neighbours:
    if n.link in pages['Link']:
      rel+=1
      st+="(n"+str(id[nn])+")"+"-[r"+str(rel)+":NEIGHBOR_OF]->"+"(n"+str(id[n])+"),"+"\n"
st = st.rstrip(",")
st+=";"
print(st)
# Out:
# CREATE (n1:NODE{link:'https://en.wikipedia.org//wiki/File:Trigonometrija-graf.png',LABEL:3}),
# (n2:NODE{link:'https://en.wikipedia.org//wiki/File:Ab_major_scale.png',LABEL:1}),
# (n3:NODE{link:'https://en.wikipedia.org//wiki/Supershear_earthquake',LABEL:1}),
# (n4:NODE{link:'https://en.wikipedia.org//wiki/Dietrich_von_Hildebrand',LABEL:2}),
# (n5:NODE{link:'https://en.wikipedia.org//wiki/Nine_Chapters_on_the_Mathematical_Art',LABEL:1}),
# (n6:NODE{link:'https://en.wikipedia.org//wiki/Salvarsan',LABEL:3}),
# (n7:NODE{link:'https://en.wikipedia.org//wiki/Paul_%C3%89mile_Appell',LABEL:1}),
# (n8:NODE{link:'https://en.wikipedia.org//wiki/Solomon_Islands_campaign',LABEL:1}),
# (n9:NODE{link:'https://en.wikipedia.org//wiki/Pregolya',LABEL:0}),
# (n10:NODE{link:'https://en.wikipedia.org//wiki/Special:RecentChangesLinked/Envelope_(mathematics)',LABEL:3}),
# (n11:NODE{link:'https://en.wikipedia.org//wiki/19th_Waffen_Grenadier_Division_of_the_SS_(2nd_Latvian)',LABEL:0}),
# (n12:NODE{link:'https://en.wikipedia.org//wiki/Theoretical_chemistry',LABEL:1}),
# (n13:NODE{link:'https://en.wikipedia.org//wiki/Tambour',LABEL:2}),
# (n14:NODE{link:'https://en.wikipedia.org//wiki/Fethullah_G%C3%BClen',LABEL:1}),
# (n15:NODE{link:'https://en.wikipedia.org//wiki/List_of_world_production_chemical_elements',LABEL:1}),
# (n16:NODE{link:'https://en.wikipedia.org//wiki/List_of_nuclear_weapons_tests_of_the_United_States',LABEL:3}),
# (n17:NODE{link:'https://en.wikipedia.org//wiki/Special:BookSources/978-0-03-077945-9',LABEL:0}),
# (n18:NODE{link:'https://en.wikipedia.org//wiki/Category:Neuroscience',LABEL:3}),
# (n19:NODE{link:'https://en.wikipedia.org//wiki/Alpha_process',LABEL:3}),
# (n20:NODE{link:'https://en.wikipedia.org//wiki/Subsizar',LABEL:3}),
# (n21:NODE{link:'https://en.wikipedia.org//wiki/Silvering',LABEL:2}),
# (n22:NODE{link:'https://en.wikipedia.org//wiki/Chandrayaan_2',LABEL:3}),
# (n23:NODE{link:'https://en.wikipedia.org//wiki/Metric_slug',LABEL:1}),
# (n24:NODE{link:'https://en.wikipedia.org//wiki/Graphe_paranomon',LABEL:2}),
# (n25:NODE{link:'https://en.wikipedia.org//wiki/Leonardo_Vinci',LABEL:2}),
# (n26:NODE{link:'https://en.wikipedia.org//wiki/Real_polynomial',LABEL:2}),
# (n27:NODE{link:'https://en.wikipedia.org//wiki/Gisbert_W%C3%BCstholz',LABEL:0}),
# (n28:NODE{link:'https://en.wikipedia.org//wiki/Azeri',LABEL:3}),
# (n29:NODE{link:'https://en.wikipedia.org//wiki/Special:BookSources/978-1-78499-148-7',LABEL:3}),
# (n30:NODE{link:'https://en.wikipedia.org//wiki/Special:WhatLinksHere/Level_(logarithmic_quantity)',LABEL:1}),
# (n31:NODE{link:'https://en.wikipedia.org//wiki/Intermediate_frequency',LABEL:2}),
# (n32:NODE{link:'https://en.wikipedia.org//wiki/Category:Wikipedia_requested_images',LABEL:1}),
# (n33:NODE{link:'https://en.wikipedia.org//wiki/File:Stokes_patch.svg',LABEL:3}),
# (n34:NODE{link:'https://en.wikipedia.org//wiki/NASA_Astronaut_Corps',LABEL:2}),
# (n35:NODE{link:'https://en.wikipedia.org//wiki/Monic_polynomial',LABEL:2}),
# (n36:NODE{link:'https://en.wikipedia.org//wiki/Los_Alamos_Ranch_School',LABEL:1}),
# (n37:NODE{link:'https://en.wikipedia.org//wiki/Hypergeometric_distribution',LABEL:1}),
# (n38:NODE{link:'https://en.wikipedia.org//wiki/Harry_S._Truman_1948_presidential_campaign',LABEL:1}),
# (n39:NODE{link:'https://en.wikipedia.org//wiki/Origen',LABEL:2}),
# (n40:NODE{link:'https://en.wikipedia.org//wiki/EmDrive',LABEL:3}),
# (n41:NODE{link:'https://en.wikipedia.org//wiki/Category:Articles_with_unsourced_statements_from_January_2021',LABEL:1}),
# (n42:NODE{link:'https://en.wikipedia.org//wiki/Solubility_chart',LABEL:1}),
# (n43:NODE{link:'https://en.wikipedia.org//wiki/Lampbrush_chromosome',LABEL:3}),
# (n44:NODE{link:'https://en.wikipedia.org//wiki/Vein_matching',LABEL:1}),
# (n45:NODE{link:'https://en.wikipedia.org//wiki/Capture_of_Marrakesh_(1147)',LABEL:1}),
# (n46:NODE{link:'https://en.wikipedia.org//wiki/Category:Numerical_integration_(quadrature)',LABEL:3}),
# (n47:NODE{link:'https://en.wikipedia.org//wiki/Anastasia_(surname)',LABEL:3}),
# (n48:NODE{link:'https://en.wikipedia.org//wiki/Risk_management',LABEL:3}),
# (n49:NODE{link:'https://en.wikipedia.org//wiki/Porter_Square',LABEL:3}),
# (n50:NODE{link:'https://en.wikipedia.org//wiki/Tilos',LABEL:3}),
# (n51:NODE{link:'https://en.wikipedia.org//wiki/Odd_functions',LABEL:1}),
# (n52:NODE{link:'https://en.wikipedia.org//wiki/Wikipedia:Wikipedia_Loves_Libraries',LABEL:1}),
# (n53:NODE{link:'https://en.wikipedia.org//wiki/Republic_of_Sassari',LABEL:2}),
# (n54:NODE{link:'https://en.wikipedia.org//wiki/John_Lothrop_Motley',LABEL:2}),
# (n55:NODE{link:'https://en.wikipedia.org//wiki/1939%E2%80%931940_Winter_Offensive',LABEL:1}),
# (n56:NODE{link:'https://en.wikipedia.org//wiki/Ntames',LABEL:3}),
# (n57:NODE{link:'https://en.wikipedia.org//wiki/Xi_baryon',LABEL:3}),
# (n58:NODE{link:'https://en.wikipedia.org//wiki/Reaction_rate_constant',LABEL:3}),
# (n59:NODE{link:'https://en.wikipedia.org//wiki/Alpine_newt',LABEL:1}),
# (n60:NODE{link:'https://en.wikipedia.org//wiki/Mona_Lisa_(opera)',LABEL:2}),
# (n61:NODE{link:'https://en.wikipedia.org//wiki/International_standard',LABEL:1}),
# (n62:NODE{link:'https://en.wikipedia.org//wiki/Uniformly_smooth_space',LABEL:1}),
# (n63:NODE{link:'https://en.wikipedia.org//wiki/Wikipedia:COinS',LABEL:2}),
# (n64:NODE{link:'https://en.wikipedia.org//wiki/Template_talk:Sun_spacecraft',LABEL:2}),
# (n65:NODE{link:'https://en.wikipedia.org//wiki/Brian_Mulroney',LABEL:2}),
# (n66:NODE{link:'https://en.wikipedia.org//wiki/Medium_spiny_neuron',LABEL:3}),
# (n67:NODE{link:'https://en.wikipedia.org//wiki/Stein%27s_lemma',LABEL:0}),
# (n68:NODE{link:'https://en.wikipedia.org//wiki/File:Onde_cisaillement_impulsion_1d_30_petit.gif',LABEL:2}),
# (n69:NODE{link:'https://en.wikipedia.org//wiki/File:Box_with_scene_depicting_Roman_hero_Gaius_Mucius_Scaevola_before_the_Etruscan_king_Lars_Porsena_MET_DP170836_(cropped).jpg',LABEL:3}),
# (n70:NODE{link:'https://en.wikipedia.org//wiki/Special:BookSources/978-3-319-12102-4',LABEL:1}),
# (n71:NODE{link:'https://en.wikipedia.org//wiki/Willem_de_Sitter',LABEL:2}),
# (n72:NODE{link:'https://en.wikipedia.org//wiki/Trustee_Savings_Bank',LABEL:0}),
# (n73:NODE{link:'https://en.wikipedia.org//wiki/McDonnell_Douglas_F/A-18_Hornet_in_Australian_service',LABEL:1}),
# (n74:NODE{link:'https://en.wikipedia.org//wiki/Lucan',LABEL:2}),
# (n76:NODE{link:'https://en.wikipedia.org//wiki/Pyramidal_number',LABEL:1}),
# (n77:NODE{link:'https://en.wikipedia.org//wiki/Norman_Borlaug',LABEL:1}),
# (n78:NODE{link:'https://en.wikipedia.org//wiki/File:Pharmacy_Green_Cross.svg',LABEL:3}),
# (n79:NODE{link:'https://en.wikipedia.org//wiki/Southeastern_Iberian_script',LABEL:3}),
# (n80:NODE{link:'https://en.wikipedia.org//wiki/Zettabit',LABEL:1}),
# (n81:NODE{link:'https://en.wikipedia.org//wiki/Paleoclimatology',LABEL:1}),
# (n82:NODE{link:'https://en.wikipedia.org//wiki/Cognitive_computing',LABEL:1}),
# (n83:NODE{link:'https://en.wikipedia.org//wiki/Foot-pound_(energy)',LABEL:1}),
# (n84:NODE{link:'https://en.wikipedia.org//wiki/Private_aviation',LABEL:2}),
# (n85:NODE{link:'https://en.wikipedia.org//wiki/Special:BookSources/978-1-78699-382-3',LABEL:2}),
# (n86:NODE{link:'https://en.wikipedia.org//wiki/Time_series',LABEL:0}),
# (n87:NODE{link:'https://en.wikipedia.org//wiki/Control_hazard',LABEL:1}),
# (n88:NODE{link:'https://en.wikipedia.org//wiki/Ancient_philosophy',LABEL:1}),
# (n89:NODE{link:'https://en.wikipedia.org//wiki/NCAA_Division_I_Men%27s_Basketball_Tournament',LABEL:2}),
# (n90:NODE{link:'https://en.wikipedia.org//wiki/California_Psychological_Inventory',LABEL:3}),
# (n91:NODE{link:'https://en.wikipedia.org//wiki/Shizuo_Kakutani',LABEL:1}),
# (n92:NODE{link:'https://en.wikipedia.org//wiki/List_of_military_aircraft_of_Germany',LABEL:2}),
# (n93:NODE{link:'https://en.wikipedia.org//wiki/Equal-tempered',LABEL:1}),
# (n94:NODE{link:'https://en.wikipedia.org//wiki/Canonical_coordinates',LABEL:1}),
# (n95:NODE{link:'https://en.wikipedia.org//wiki/Taqi_ad-Din_Muhammad_ibn_Ma%27ruf',LABEL:3}),
# (n96:NODE{link:'https://en.wikipedia.org//wiki/Klein_quadric',LABEL:3}),
# (n97:NODE{link:'https://en.wikipedia.org//wiki/Category:Articles_with_failed_verification_from_November_2021',LABEL:2}),
# (n98:NODE{link:'https://en.wikipedia.org//wiki/Special:BookSources/978-0-415-24242-4',LABEL:1}),
# (n99:NODE{link:'https://en.wikipedia.org//wiki/Holomorphic_functional_calculus',LABEL:1}),
# (n100:NODE{link:'https://en.wikipedia.org//wiki/Book_sales_club',LABEL:1}),
#
# ;
